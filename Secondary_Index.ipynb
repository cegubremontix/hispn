# %% [markdown]
# <a href="https://colab.research.google.com/github/dbremont/Notas/blob/main/Secondary_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Secondary Index
#
# - A Collection of Blog Post,
# - Articles, Notebooks

# %% [markdown]
# # Matematicas

# %% [markdown]
# - [Parametric equation](https://en.wikipedia.org/wiki/Parametric_equation)
#
# - [0.999...](https://en.wikipedia.org/wiki/0.999...)
#
# - [Lattice (order)](https://en.wikipedia.org/wiki/Lattice_(order))
#
# - [Spectral method](https://en.wikipedia.org/wiki/Spectral_method)
#
# - [Permutation](https://en.wikipedia.org/wiki/Permutation)
#
#
# - [Mathematical structure](https://en.wikipedia.org/wiki/Mathematical_structure)
#
# - [Mathematics](https://en.wikipedia.org/wiki/Mathematics)
#
# - [Mean absolute difference](https://en.wikipedia.org/wiki/Mean_absolute_difference)
#
# * [Hilbert space](https://en.wikipedia.org/wiki/Hilbert_space)
#
# - [Applied mathematics](https://en.wikipedia.org/wiki/Applied_mathematics)
#
# - [Geometric Brownian motion](https://en.wikipedia.org/wiki/Geometric_Brownian_motion)
#
# - [Kalman filter](https://en.wikipedia.org/wiki/Kalman_filter)
#
# - [Combination](https://en.wikipedia.org/wiki/Combination)
#
# - [Elementary Calculus: An Infinitesimal Approach](https://people.math.wisc.edu/~keisler/calc.html)
#
# - [Algebraic](https://en.wikipedia.org/wiki/Algebraic)
#
# - [Algebraic structure](https://en.wikipedia.org/wiki/Algebraic_structure)
#
# - [Analysis of variance](https://en.wikipedia.org/wiki/Analysis_of_variance)
#
# * [Convolution](https://en.wikipedia.org/wiki/Convolution)

# %% [markdown]
# * [Explaining probability to a jury](https://www.johndcook.com/blog/explaining-probability-to-a-jury/)
#
#
# * [Use Shannong Entropy Outside Computer Science and Eng](http://www.dp-pmi.org/uploads/3/8/1/3/3813936/6._figueiredo_2016.pdf)
#
# * [A brief introduction to the beauty of Information Theory](https://notamonadtutorial.com/a-brief-introduction-to-the-beauty-of-information-theory-8357f5b6a355)
#
# * [Rediscovering Hamming code](https://blog.digital-horror.com/rediscovering-hamming-code/)
#
# * [Calculus](https://en.wikipedia.org/wiki/Calculus)
#
# * [Mathematical analysis](https://en.wikipedia.org/wiki/Mathematical_analysis)
#
# * [Algebra](https://en.wikipedia.org/wiki/Algebra)
#
# * [Mathematical structure](https://en.wikipedia.org/wiki/Mathematical_structure)
#
# * [Metric space](https://en.wikipedia.org/wiki/Metric_space)
#
# * [Sobolev space](https://en.wikipedia.org/wiki/Sobolev_space)
#
# * [Spectral theory](https://en.wikipedia.org/wiki/Spectral_theory)
#
# * [Estimation theory](https://en.wikipedia.org/wiki/Estimation_theory)
#
# * [How to write mathematics clearly](http://www.learningideas.me.uk/clearmaths/)
#
# * [Mathematical structure](https://en.wikipedia.org/wiki/Mathematical_structure)
#
# * (D) [How to write proof a quick guide](http://0.0.0.0:8000/1%20Matematicas/Articulos/How%20to%20write%20proofs%20a%20quick%20guide.pdf)
#
# * [How to write mathematics clearly](http://www.learningideas.me.uk/clearmaths/)
#
# * [Introduction to Linear Algebra for Applied Machine Learning with Python](https://pabloinsente.github.io/intro-linear-algebra)
#
# * [Relearning Matrices as Linear Functions](https://dhruvp.netlify.app/2018/12/31/matrices/)
#
# * [You Could Have Come Up With Eigenvectors - Here’s How](https://www.dhruvonmath.com/2019/02/25/eigenvectors)
#
# * [Monte Carlo method](https://en.wikipedia.org/wiki/Monte_Carlo_method)
#
# * [Applications of randomness](https://en.wikipedia.org/wiki/Applications_of_randomness)
#
# * [Stochastic procress](https://en.wikipedia.org/wiki/Stochastic_process)
#
# * [Mathematical structure](https://en.wikipedia.org/wiki/Mathematical_structure)
#
# * [Space (mathematics)](https://en.wikipedia.org/wiki/Space_(mathematics))
#
# * [Manifolds: A Gentle Introduction](https://bjlkeng.github.io/posts/manifolds/)
#
# * [Zipf's law](https://en.wikipedia.org/wiki/Zipf's_law)
#
# * [Applications of randomness](https://en.wikipedia.org/wiki/Applications_of_randomness)
#
# * [Interactive Visualization of Why Eigenvectors Matter](https://www.dhruvonmath.com/2020/07/26/who-cares-about-eigenvectors/)
#
# * [A Visual Introduction to Function Kernels](https://www.dhruvonmath.com/2019/04/04/kernels/)
#
# * [PageRank - How Eigenvectors Power the Algorithm Behind Google Search](https://www.dhruvonmath.com/2019/03/20/pagerank/)
#
# * [You Could Have Come Up With Eigenvectors - Here's How](https://www.dhruvonmath.com/2019/02/25/eigenvectors/)
#
# * [Relearning Matrices as Linear Functions](https://www.dhruvonmath.com/2018/12/31/matrices/)
#
# * [A hacker's guide to numerical analysis](http://bollu.github.io/a-hackers-guide-to-numerical-analysis.html)
#
# * [How to Study Mathematics](https://www.math.uh.edu/~dblecher/pf2.html)
#
# * [Combinatorial explosion - Wikipedia](https://en.wikipedia.org/wiki/Combinatorial_explosion)
#
#
# * [Counterfactuals](https://plato.stanford.edu/entries/counterfactuals/)
#
# * [Coupling (probability)](https://en.wikipedia.org/wiki/Coupling_(probability))
#
# * [The Tensor Product, Demystified](https://www.math3ma.com/blog/the-tensor-product-demystified)
# * [Applied Category Theory 2020](https://www.math3ma.com/blog/applied-category-theory-2020)
# * [Learning How to Learn Math](https://www.math3ma.com/blog/learning-math)
# * [Some Notes on Taking Notes](https://www.math3ma.com/blog/some-notes-on-taking-notes)
# * [Good Reads: Visual Complex Analysis](https://www.math3ma.com/blog/good-reads-visual-complex-analysis)
#
# * [Good Reads: Real Analysis by N. L. Carothers](https://www.math3ma.com/blog/good-reads-real-analysis-by-n-l-carothers)
# * [Good Reads: The Princeton Companion to Mathematics](https://www.math3ma.com/blog/good-reads-the-princeton-companion-to-mathematics)
# * [Ways to Show a Group is Abelian](https://www.math3ma.com/blog/ways-to-show-a-group-is-abelian)
# * [The Integral Domain Hierarchy, Part 1](https://www.math3ma.com/blog/the-integral-domain-hierarchy-part-1)
# * [The Integral Domain Hierarchy, Part 2](https://www.math3ma.com/blog/the-integral-domain-hierarchy-part-2)
# * [Constructing the Tensor Product of Modules](https://www.math3ma.com/blog/constructing-the-tensor-product-of-modules)
# * [Algebraic Elements Are Like Limit Points!](https://www.math3ma.com/blog/algebraic-elements-are-like-limit-points)
# * [4 Ways to Show a Group is Not Simple](https://www.math3ma.com/blog/4-ways-to-show-a-group-is-not-simple)
# * [Noetherian Rings = Generalization of PIDs](https://www.math3ma.com/blog/noetherian-rings-generalization-of-pids)
# * [Two Tricks Using Eisenstein's Criterion](https://www.math3ma.com/blog/two-tricks-using-eisensteins-criterion)
# * [A Little Fact From Group Actions](https://www.math3ma.com/blog/a-little-fact-from-group-actions)
# * [Finitely Generated Modules Over a PID](https://www.math3ma.com/blog/finitely-generated-modules-over-a-pid)
# * [Rational Canonical Form: A Summary](https://www.math3ma.com/blog/rational-canonical-form-a-summary)
# * [Rational Canonical Form: Example #1](https://www.math3ma.com/blog/rational-canonical-form-example-1)
# * [Rational Canonical Form: Example #2 (with Galois Theory)](https://www.math3ma.com/blog/rational-canonical-form-example-2-with-galois-theory)
# * [What is Galois Theory Anyway?](https://www.math3ma.com/blog/what-is-galois-theory-anyway)
# * [Transitive Group Actions: "Where There's a Will, There's a Way!"](https://www.math3ma.com/blog/transitive-group-actions-where-theres-a-will-theres-a-way)
# * [What's a Quotient Group, Really? Part 1](https://www.math3ma.com/blog/whats-a-quotient-group-really-part-1)
# * [What's a Quotient Group, Really? Part 2](https://www.math3ma.com/blog/whats-a-quotient-group-really-part-2)
# * [The First Isomorphism Theorem, Intuitively](https://www.math3ma.com/blog/the-first-isomorphism-theorem-intuitively)
# * [A Group and Its Center, Intuitively](https://www.math3ma.com/blog/a-group-and-its-center-intuitively)
# * [A Quotient of the General Linear Group, Intuitively](https://www.math3ma.com/blog/a-quotient-of-the-general-linear-group-intuitively)
#
# * [What is an Operad? Part 1](https://www.math3ma.com/blog/what-is-an-operad-part-1)
# * [What is an Operad? Part 2](https://www.math3ma.com/blog/what-is-an-operad-part-2)
# * [Matrices as Tensor Network Diagrams](https://www.math3ma.com/blog/matrices-as-tensor-network-diagrams)
# * [Understanding Entanglement With SVD](https://www.math3ma.com/blog/understanding-entanglement-with-svd)
# * [Viewing Matrices & Probability as Graphs](https://www.math3ma.com/blog/matrices-probability-graphs)
# * [Language Modeling with Reduced Densities](https://www.math3ma.com/blog/language-modeling-with-reduced-densities)
#
# * [At the Interface of Algebra and Statistics](https://www.math3ma.com/blog/at-the-interface-of-algebra-and-statistics)

# %% [markdown]
# # Computacion

# %% [markdown]
# - [tmuxcheatsheet](https://tmuxcheatsheet.com/)
#
# * [Programming paradigm](https://en.wikipedia.org/wiki/Programming_paradigm)
#
# - [A resource for use of computational physics with Python, covering many topics in physics](https://www.numfys.net/)
#
# - [Anatomy of a Linux DNS Lookup – Part I](https://zwischenzugs.com/2018/06/08/anatomy-of-a-linux-dns-lookup-part-i/)
#
# - [Dope vector](https://en.wikipedia.org/wiki/Dope_vector)
#
# - [LabVIEW](https://en.wikipedia.org/wiki/LabVIEW)
#   - For dataflow programming
#
# - [Flow-based Programming](https://jpaulm.github.io/fbp/index.html)
#
# - [Can programming be liberated from the von Neumann style?: a functional style and its algebra of programs](https://dl.acm.org/doi/10.1145/359576.359579)
#
# - [Git for Computer Scientists](https://eagain.net/articles/git-for-computer-scientists/)
#
# - [Leaky Abstractions](https://textslashplain.com/2021/06/02/leaky-abstractions/)
#
# - [Learn R through examples](https://gexijin.github.io/learnR/index.html)
#
# - [List of LaTeX mathematical symbols](https://oeis.org/wiki/List_of_LaTeX_mathematical_symbols)
#
# - [Real-time web](https://en.wikipedia.org/wiki/Real-time_web)
#
# - [Reducing Python String Memory Use in Apache Arrow 0.12](https://arrow.apache.org/blog/2019/02/05/python-string-memory-0.12/)
#
# - [Non-fungible token](https://en.wikipedia.org/wiki/Non-fungible_token)
#
# - []()
#
# - [Non-fungible token](https://en.wikipedia.org/wiki/Non-fungible_token)

# %% [markdown]
# * [5 ways to build real-time apps with JavaScript](https://www.freecodecamp.org/news/5-ways-to-build-real-time-apps-with-javascript-5f4d8fe259f7/)
#
# * [Data type object](https://docs.scipy.org/doc/numpy-1.13.0/reference/arrays.dtypes.html)
#
# * [Indexing and selecting data](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html)
#
# * [How to Filter Pandas DataFrame Based on Index](https://datatofish.com/filter-pandas-dataframe/)
#
# - [Webcal](https://en.wikipedia.org/wiki/Webcal)
#
# - [PEP 427 -- The Wheel Binary Package Format 1.0](https://www.python.org/dev/peps/pep-0427/)
#
# - [What is the difference between Type and Class?](https://stackoverflow.com/questions/468145/what-is-the-difference-between-type-and-class)
#
# * [Why I prefer making useless stuff](https://web.eecs.utk.edu/~azh/blog/makinguselessstuff.html)
#
# * [The Architecture of Uber’s API gateway](https://eng.uber.com/architecture-api-gateway/)
#
# * [JWT should not be your default for sessions](https://evertpot.com/jwt-is-a-bad-default/)
#
# * [Lookup table - Wikipedia](https://en.wikipedia.org/wiki/Lookup_table)
#
# * [Using Pattern Languages for Object-Oriented Programs](http://c2.com/doc/oopsla87.html)
#
# * [Intro to AspectJ | Baeldung](https://www.baeldung.com/aspectj)
#
# * [Raft Consensus Algorithm](https://raft.github.io/)
#
# * [Replacing Elasticsearch with Rust and SQLite](https://nickb.dev/blog/replacing-elasticsearch-with-rust-and-sqlite)
#
# * [Students' Guide to Raft :: Jon Gjengset](https://thesquareplanet.com/blog/students-guide-to-raft/)
#
# * [Tmux cheat sheet | Opensource.com](https://opensource.com/downloads/tmux-cheat-sheet)
#
# * [Pipeline (software) - Wikipedia](https://en.wikipedia.org/wiki/Pipeline_(software))
#
# * [Optical character recognition - Wikipedia](https://en.wikipedia.org/wiki/Optical_character_recognition)
#
# * [Linux Nohup Command | Linuxize](https://linuxize.com/post/linux-nohup-command/)
#
# * []()
#
# * [Android Runtime](https://en.wikipedia.org/wiki/Android_Runtime)
#
# * [As We May Think](https://www.theatlantic.com/magazine/archive/1945/07/as-we-may-think/303881/)
#
# * [Ask HN: Multiprocessing & concurrency: C, Python, Clojure (& Go :))](https://news.ycombinator.com/item?id=1825063)
#
# * [Barcode](https://en.wikipedia.org/wiki/Barcode)
#
# * [Beyond bytebuffers – Inside.java](https://inside.java/2019/11/08/beyondbytebuffers/)
#
# * [Big list of http static server one-liners](https://gist.github.com/willurd/5720255)
#
# * [Building the JDK](https://openjdk.java.net/groups/build/doc/building.html)
#
# * [Business logic](https://en.wikipedia.org/wiki/Business_logic)
#
# * [Common Gateway Interface](https://en.wikipedia.org/wiki/Common_Gateway_Interface)
#
# * [Conversational user interface](https://en.wikipedia.org/wiki/Conversational_user_interface)
#
# * [What GDB is and why you need to use it](http://www.eecs.harvard.edu/~cs161/resources/gdb.html)
#
# * [Ctags](https://en.wikipedia.org/wiki/Ctags)
#
# * [Dalvik Virtual Machine](https://en.wikipedia.org/wiki/Dalvik_(software))
#
# * [Difference between 'java' and 'libjvm.so' (Linux) or 'jvm.dll' (Windows)?](https://stackoverflow.com/questions/6134350/difference-between-java-and-libjvm-so-linux-or-jvm-dll-windows)
#
# * [domain driven design](https://martinfowler.com/tags/domain%20driven%20design.html)
#
# * [Domain-Driven Design: Everything You Always Wanted to Know About it, But Were Afraid to Ask](https://medium.com/ssense-tech/domain-driven-design-everything-you-always-wanted-to-know-about-it-but-were-afraid-to-ask-a85e7b74497a)
#
# * [environment variables - How to link a c++ program to jvm (java virtual machine)?](https://askubuntu.com/questions/1215613/how-to-link-a-c-program-to-jvm-java-virtual-machine)
#
# * [Eventual consistency](https://en.wikipedia.org/wiki/Eventual_consistency)
#
# * [Extreme programming](https://en.wikipedia.org/wiki/Extreme_programming)
#
# * [Generic Types (The Java™ Tutorials > Learning the Java Language > Generics (Updated))](https://docs.oracle.com/javase/tutorial/java/generics/types.html)
#
# * [WildFly Docs](https://docs.wildfly.org/20/Getting_Started_Developing_Applications_Guide.html)
#
# * [How to Deploy Spring Boot Application in Wildfly Application Server | by Somnath Musib | The Startup | Medium](https://medium.com/swlh/how-to-deploy-spring-boot-application-in-wildfly-application-server-b3670c031ad4)
#
# * [WildFly Documentation](https://docs.wildfly.org/20/)
#
# * [How to display JSP with WildFly](https://stackoverflow.com/questions/34023527/how-to-display-jsp-with-wildfly)
#
# * [Guide into OpenMP: Easy multithreading programming for C++](https://bisqwit.iki.fi/story/howto/openmp/)
#
# * [Hex editor](https://en.wikipedia.org/wiki/Hex_editor)
#
# * [How to Save a File in Vi / Vim Editor & Quit](https://phoenixnap.com/kb/how-to-vim-save-quit-exit)
#
# * [How to Set Environment Variables in Linux - Serverlab](https://www.serverlab.ca/tutorials/linux/administration-linux/how-to-set-environment-variables-in-linux/)
#
# * [Internals - GDB Wiki](https://sourceware.org/gdb/wiki/Internals)
#
# * [Jakarta EE](https://en.wikipedia.org/wiki/Jakarta_EE)
#
# * [JAR File Specification](https://docs.oracle.com/javase/7/docs/technotes/guides/jar/jar.html)
#
# - [Lets Build a Compiler  - locals-and-conditionals](https://generalproblem.net/lets_build_a_compiler/03-locals-and-conditionals/)
# - [Lets Build a Compiler  - starting-out](https://generalproblem.net/lets_build_a_compiler/01-starting-out/)
# - [Lets Build a Compiler  - function-calls](https://generalproblem.net/lets_build_a_compiler/04-function-calls/)
# - [Lets Build a Compiler  - primitives](https://generalproblem.net/lets_build_a_compiler/02-primitives/)

# %% [markdown]
# * [What is the LD_PRELOAD / LD-PRELOAD trick?](https://stackoverflow.com/questions/426230/what-is-the-ld-preload-trick)
#
# * [mmap](https://en.wikipedia.org/wiki/Mmap)
#
# * [	But how, exactly, do databases use mmap? (brunocalza.me)](https://news.ycombinator.com/item?id=25881911)
#
# * [Why is mmap considered bad while designing a database system?](https://www.quora.com/Why-is-mmap-considered-bad-while-designing-a-database-system)
#
# * [what the heck is a NetBSD?](https://www.netbsd.org/gallery/presentations/nia/campplusplus2020/slides.html)
#
# * [Homework: running and debugging xv6](https://www.cse.iitd.ernet.in/~sbansal/os/previous_years/2014/lec/l3-hw1.html)
#
# * [How To Use QEMU To Test Operating Systems & Distributions](https://fosspost.org/use-qemu-test-operating-systems-distributions/)
#
# * [What Is the Difference between QEMU and KVM?](https://www.packetflow.co.uk/what-is-the-difference-between-qemu-and-kvm/)
#
# * [Spawn (computing)](https://en.wikipedia.org/wiki/Spawn_(computing))
#
# * [Domain-driven design](https://en.wikipedia.org/wiki/Domain-driven_design)
#
# * [Teeing, a hidden gem in the Java API](https://blog.frankel.ch/teeing-java-api/)
#
# * [The Best Refactoring You've Never Heard Of](http://www.pathsensitive.com/2019/07/the-best-refactoring-youve-never-heard.html)
#
# * [My Strange Loop talk: You are a Program Synthesizer (video + transcript)](http://www.pathsensitive.com/2018/12/my-strange-loop-talk-you-are-program.html)
#
# * [Making Wrong Code Look Wrong](https://www.joelonsoftware.com/2005/05/11/making-wrong-code-look-wrong/)
#
# * [John Carmack on Inlined Code](http://number-none.com/blow/blog/programming/2014/09/26/carmack-on-inlined-code.html)
#
# * [Poor Disk Performance](http://www.brendangregg.com/blog/2021-05-09/poor-disk-performance.html)
#
# * [Coding Standards and Conventions](https://www.spinellis.gr/ismr/conv/index.htm)
#
# * [Inspection and Testing](https://www.spinellis.gr/ismr/test/index.htm)
#
# * [Performance Measurement and Management](https://www.spinellis.gr/ismr/pmes/index.htm)
#
# * [General Purpose Tools](https://www.spinellis.gr/ismr/uxtools/index.htm)
#
# * [Version Control](https://www.spinellis.gr/ismr/vcs/index.htm)
#
# * [The Open Source Landscape](https://www.spinellis.gr/ismr/oss/index.htm)
#
# * [Code as Part of the Software Development Process](https://www.spinellis.gr/ismr/code/index.htm)
#
# * [Maintainability](https://www.spinellis.gr/ismr/maint/index.htm)
#
# * [Documentation](https://www.spinellis.gr/ismr/doc/index.htm)
#
# * [Build Management](https://www.spinellis.gr/ismr/build/index.htm)
#
# * [Appendix: Basic Programming Elements](https://www.spinellis.gr/ismr/prog/index.htm)
#
# * [Appendix: Data Structures in C](https://www.spinellis.gr/ismr/data/index.htm)
#
# * [Reading the FreeBSD Kernel](http://www.watson.org/~robert/freebsd/reading/)
#
# * [Program Synthesis Explained](https://www.cs.utexas.edu/~bornholt/post/synthesis-explained.html)
#
# * [Building a Program Synthesizer](https://www.cs.utexas.edu/~bornholt/post/building-synthesizer.html)
#
# * [Program Synthesis is Possible](https://www.cs.cornell.edu/~asampson/blog/minisynth.html)
#
# * [Email explained from first principles](https://explained-from-first-principles.com/email/)
#
# * [Inefficient Efficiency](https://medium.com/@kentbeck_7670/inefficient-efficiency-5b3ab5294791)
#
# * [Hosting SQLite databases on Github Pages](https://phiresky.github.io/blog/2021/hosting-sqlite-databases-on-github-pages/)
#
# * [Bloom filter](https://en.wikipedia.org/wiki/Bloom_filter)
#
# * [The Art of Command Line](https://github.com/jlevy/the-art-of-command-line)
#
# * [Unikernel](https://en.wikipedia.org/wiki/Unikernel)
#
# * [How programs get run: ELF binaries](https://lwn.net/Articles/631631/)
#
# * [Instruction level just-in-time programming](https://blog.asrpo.com/jit_programming)
#
#
# * [Software designers, not engineers An interview from alternative universe](http://tomasp.net/blog/2021/software-designers/)
#
# * [Software as a service](https://en.wikipedia.org/wiki/Software_as_a_service)
#
# * [On-premises software](https://en.wikipedia.org/wiki/On-premises_software)
#
# * [Software Architecture & Design Tutorial](https://www.tutorialspoint.com/software_architecture_design/index.htm)
#
# * [Deep Diving Into the Strengths of Free](https://klarasystems.com/articles/deep-diving-into-the-strengths-of-freebsd/)
#
# * [Branchless Coding in Go](https://mattnakama.com/blog/go-branchless-coding/)
#
# * [Efficiency is the Enemy](https://fs.blog/2021/05/slack/)
#
# * [Competitive Analysis For Product Engineers](https://staysaasy.com/product/2021/05/02/competition.html)
#
# * [Declarative Validation](https://blog.drewolson.org/declarative-validation)
#
# * [Instant replay: Debugging C and C++ programs with rr](https://developers.redhat.com/blog/2021/05/03/instant-replay-debugging-c-and-c-programs-with-rr/)
#
# * [Programming in Z3 by learning to think like a compiler](https://bellmar.medium.com/programming-in-z3-by-learning-to-think-like-a-compiler-401fd46828d5)
#
# * [The compiler will optimize that away](https://blog.royalsloth.eu/posts/the-compiler-will-optimize-that-away/)
#
# * [The art of solving problems with Monte Carlo simulations](https://ggcarvalho.dev/posts/montecarlo/)
#
# * [Introduce BIO: A Simple Streaming Abstraction](https://z.haskell.world/design/2021/04/20/introduce-BIO-a-simple-streaming-abstraction.html)
#
# * [Hosting SQLite databases on Github Pages](https://cybergibbons.com/security-2/what3words-the-algorithm/)
#
# * [What3Words – The Algorithm](https://cybergibbons.com/security-2/what3words-the-algorithm/)
#
# * [Query Engines: Push vs. Pull](http://justinjaffray.com/query-engines-push-vs.-pull/)
#
# * [Computational science](https://en.wikipedia.org/wiki/Computational_science)
#
# * [System Design Primer](https://github.com/donnemartin/system-design-primer)
#
# * [Everything you need to know about Design Systems](https://uxdesign.cc/everything-you-need-to-know-about-design-systems-54b109851969)
#
# * [Micro Frontends Martin Folwer](https://martinfowler.com/articles/micro-frontends.html)
#
# * [Micro Frontends](https://micro-frontends-es.org/)
#
# * [CSS Generators](https://markodenic.com/css-generators/)
#
# * [User Interface Design Basics](https://www.usability.gov/what-and-why/user-interface-design.html)
#
# * [FastCGI](https://en.wikipedia.org/wiki/FastCGI)
#
# * [Interfaces and Protocols](https://glyph.twistedmatrix.com/2021/03/interfaces-and-protocols.html)
#
# * [Parsing Protobuf at 2+GB/s: How I Learned To Love Tail Calls in C](https://blog.reverberate.org/2021/04/21/musttail-efficient-interpreters.html)
#
# * [Preparing the Netflix API for Deployment](https://netflixtechblog.com/preparing-the-netflix-api-for-deployment-786d8f58090d)
#
# * ["The COW filesystem for Linux that won't eat your data".](https://bcachefs.org/)
#
# * [Heroku-style deployments with Docker and git tags](https://ricardoanderegg.com/posts/git-push-deployments-docker-tags/)
#
# * [How to create and mount filesystems in Linux](https://www.thegeekdiary.com/how-to-create-and-mount-filesystems-in-linux/)
#
# * [Alternative to Thread.suspend() and .resume()](https://stackoverflow.com/questions/28922040/alternative-to-thread-suspend-and-resume)
#
# * [Arrays of Wisdom of the Ancients](https://shipilev.net/blog/2016/arrays-wisdom-ancients/)
#
# * [What ever happened to Aspect Oriented Programming? [closed](https://stackoverflow.com/questions/316132/what-ever-happened-to-aspect-oriented-programming)
#
# * [File System](https://en.wikipedia.org/wiki/File_system)
#
# * [Why a computer buffer is called a buffer](https://www.johndcook.com/blog/2010/10/25/buffers/)
#
# * []()
#
# * [Ask HN: Feature Flags?](https://news.ycombinator.com/item?id=3028814)
#
# * [Canary Launches: How and Why to Canary Release](https://launchdarkly.com/blog/canary-launches-how-and-why-to-canary-release/)
#
# * [Feature Toggles (aka Feature Flags)](https://martinfowler.com/articles/feature-toggles.html)
#
# * [How does Etsy manage development and operations?](https://codeascraft.com/2011/02/04/how-does-etsy-manage-development-and-operations/)
#
# * [Example RISC-V Assembly Programs](https://marz.utk.edu/my-courses/cosc230/book/example-risc-v-assembly-programs/)
#
# * [CSS Tips](https://markodenic.com/css-tips/)
#
# * [How Etsy Deploys More Than 50 Times a Day](https://www.infoq.com/news/2014/03/etsy-deploy-50-times-a-day/)
#
# * [QEMU internals](https://airbus-seclab.github.io/qemu_blog/)
#
# * [What’s wrong with Git? A conceptual design analysis](https://blog.acolyer.org/2016/10/24/whats-wrong-with-git-a-conceptual-design-analysis/)
#
# * [CEO, KeyDB - a multi-threaded high-performance fork of Redis.](https://console.dev/qa/keydb-john-sully/)
#
# * [Using a disk-based Redis clone to reduce AWS S3 bill](https://wakatime.com/blog/45-using-a-diskbased-redis-clone-to-reduce-aws-s3-bill)
#
# * [Real-time operating system](https://en.wikipedia.org/wiki/Real-time_operating_system)
#
# * [Let's build a simple interpreter for APL - part 1](https://mathspp.com/blog/lsbasi-apl-part1)
#
# * [Tiny Container Challenge: Building a 6kB Containerized HTTP Server!](https://devopsdirective.com/posts/2021/04/tiny-container-image/)
#
# * [Landauer's principle](https://en.wikipedia.org/wiki/Landauer%27s_principle)
#
# * [Instrumentation](https://en.wikipedia.org/wiki/Instrumentation)
#
# * [Telecommand](https://en.wikipedia.org/wiki/Telecommand)
#
# * [Radio control](https://en.wikipedia.org/wiki/Radio_control)
#
# * [Teleoperation](https://en.wikipedia.org/wiki/Teleoperation)
#
# * [Telerobotics](https://en.wikipedia.org/wiki/Telerobotics)
#
# * [Telemetry](https://en.wikipedia.org/wiki/Telemetry)
#
# * [API Versioning Has No "Right Way"](https://apisyouwonthate.com/blog/api-versioning-has-no-right-way)
#
# * [My programming setup - Daniel Lemire](https://lemire.me/blog/2021/04/04/my-programming-setup/)
#
# * [Some useful regular expressions for programmers - Daniel Lemire](https://lemire.me/blog/2021/04/22/some-useful-regular-expressions-for-programmers/)
#
# * [Why Specifications Don't Compose](https://www.hillelwayne.com/post/spec-composition/)
#
# * [An opinionated map of incremental and streaming systems](https://scattered-thoughts.net/writing/an-opinionated-map-of-incremental-and-streaming-systems)
#
# * [Actor model](https://en.wikipedia.org/wiki/Actor_model)
#
# * [Dataflow programming](https://en.wikipedia.org/wiki/Dataflow_programming)
#
# * [The GPars Project - Reference Documentation](http://gpars.org/0.12/guide/guide/)
#
# * [Debunking the Myths of RPC & REST](https://etherealbits.com/2012/12/debunking-the-myths-of-rpc-rest/)
#
# * [Action item](https://en.wikipedia.org/wiki/Action_item)
#
# * [Information system](https://en.wikipedia.org/wiki/Information_system)
#
# * [Internal consistency in streaming systems](https://scattered-thoughts.net/writing/internal-consistency-in-streaming-systems/)
#
# * [How often do people actually copy and paste from Stack Overflow? Now we know](https://stackoverflow.blog/2021/04/19/how-often-do-people-actually-copy-and-paste-from-stack-overflow-now-we-know/)
#
# * [What is “Linearizability”?](https://stackoverflow.com/questions/9762101/what-is-linearizability/50653833)
#
# * [A Universal I/O Abstraction for C++](https://cor3ntin.github.io/posts/iouring/)
#
#
#
# * [Difference between forward slash (/) and backslash (\) in file path](https://stackoverflow.com/questions/38428561/difference-between-forward-slash-and-backslash-in-file-path/38428899)
#
# * [What is a programming idiom?](https://stackoverflow.com/questions/302459/what-is-a-programming-idiom)
#
# * [Programming idiom](https://en.wikipedia.org/wiki/Programming_idiom)
#
# * [Replace Google Analytics with a shell script](https://www.go350.com/posts/replace-google-analytics-with-a-shell-script/)
#
# * [Currying](https://en.wikipedia.org/wiki/Currying)
#
# * [Computation](https://en.wikipedia.org/wiki/Computation)
#
# * [Model of computation](https://en.wikipedia.org/wiki/Model_of_computation)
#
# * [Limits of computation](https://en.wikipedia.org/wiki/Limits_of_computation)
#
# * [Lateral computing](https://en.wikipedia.org/wiki/Lateral_computing)
#
# * [Computational problem](https://en.wikipedia.org/wiki/Computational_problem)
#
# * [Real computation](https://en.wikipedia.org/wiki/Real_computation)
#
# * [Computational theory of mind](https://en.wikipedia.org/wiki/Computational_theory_of_mind)
#
# * [Reversible computing](https://en.wikipedia.org/wiki/Reversible_computing)
#
# * [Representational state transfer](https://en.wikipedia.org/wiki/Representational_state_transfer)
#
# * [Clean URL](https://en.wikipedia.org/wiki/Clean_URL)
#
# * [Métodos de petición HTTP](https://developer.mozilla.org/es/docs/Web/HTTP/Methods)
#
# * [Re: How to Design (Declarative) Programming Languages](http://people.csail.mit.edu/gregs/ll1-discuss-archive-html/msg04323.html)
#
# * [A Brief Introduction to CI/CD](https://dzone.com/articles/the-complete-introduction-to-cicd-1)
#
# * [SQLite the only database you will ever need in most cases](https://unixsheikh.com/articles/sqlite-the-only-database-you-will-ever-need-in-most-cases.html)
#
# * [Virtual Memory in Operating System](https://www.geeksforgeeks.org/virtual-memory-in-operating-system/)
#
# * [Where does SVN store the data on the server side?](https://stackoverflow.com/questions/2132947/where-does-svn-store-the-data-on-the-server-side)
#
# * [Software design pattern](https://en.wikipedia.org/wiki/Software_design_pattern)
#
# * [Windows domain](https://en.wikipedia.org/wiki/Windows_domain)
#
# * [CAPTCHA](https://en.wikipedia.org/wiki/CAPTCHA)
#
#
#
#
# * [The Architecture Behind A One-Person Tech Startup](https://anthonynsimon.com/blog/one-man-saas-architecture/)
#
# * [SciPy Cookbook](https://scipy-cookbook.readthedocs.io/index.html)
#
# * [SciPy Lectures](https://scipy-lectures.org/)
#
# * [Token no fungible](https://es.wikipedia.org/wiki/Token_no_fungible)
#   * [Rigid Designators](https://plato.stanford.edu/entries/rigid-designators/) - Get this from Taleb.
#
# * [Sparse distributed memory](https://en.wikipedia.org/wiki/Sparse_distributed_memory)
#
# * [Unconventional computing](https://en.wikipedia.org/wiki/Unconventional_computing)
#
# * [Reversible computing](https://en.wikipedia.org/wiki/Reversible_computing)
#
# * [Evolutionary computation](https://en.wikipedia.org/wiki/Evolutionary_computation)
#
# * [Computers can be understood](https://blog.nelhage.com/post/computers-can-be-understood/)
#
# * [Choose Boring Technology](https://mcfunley.com/choose-boring-technology)
#
# * [Falsehoods Programmers Believe About Names](https://www.kalzumeus.com/2010/06/17/falsehoods-programmers-believe-about-names/)
#
# * [The Law of Leaky Abstractions](https://www.joelonsoftware.com/2002/11/11/the-law-of-leaky-abstractions/)
#
# * [Reflections on software performance](https://blog.nelhage.com/post/reflections-on-performance/)
#
# * [Notes on Distributed Systems for Young Bloods](https://www.somethingsimilar.com/2013/01/14/notes-on-distributed-systems-for-young-bloods/)
#
# * [How Unix Works: Become a Better Software Engineer](https://neilkakkar.com/unix.html)
#
# * [Rob Pike's 5 Rules of Programming](http://users.ece.utexas.edu/~adnan/pike.html)
#   * [Hacker News Comments](https://news.ycombinator.com/item?id=24135189)
#
# * [Performace Stack Exchange](https://stackexchange.com/performance)
#
# * [The Wrong Abstraction](https://www.sandimetz.com/blog/2016/1/20/the-wrong-abstraction)
#
# * [Cache Oblivious Algorithms](https://jiahai-feng.github.io/posts/cache-oblivious-algorithms/)
#
#
#
# * [Why you shouldn’t use ENV variables for secret data](https://diogomonica.com/2017/03/27/why-you-shouldnt-use-env-variables-for-secret-data/)
#
# * [I test in production](https://increment.com/testing/i-test-in-production/)
#
# * [Memory Consistency Models: A Tutorial](https://www.cs.utexas.edu/~bornholt/post/memory-models.html)
#
# * [The myth of NoSQL (vs. RDBMS) “joins don’t scale”](https://blog.dbi-services.com/the-myth-of-nosql-vs-rdbms-joins-dont-scale/)
#
# * [Distill: Why do we need Flask, Celery, and Redis? (with McDonalds in Between)](https://ljvmiranda921.github.io/notebook/2019/11/08/flask-redis-celery-mcdo/)
#
# * [Write code that is easy to delete, not easy to extend](https://programmingisterrible.com/post/139222674273/write-code-that-is-easy-to-delete-not-easy-to)
#
# * [Stripe: Building a Developer Cult](https://subvert.substack.com/p/stripe-building-a-developer-cult)
#
# * [Everything You Need to Know About OAuth (2.0)](https://gravitational.com/blog/everything-you-need-to-know-about-oauth/)
#
# * [Unit Testing is Overrated](https://tyrrrz.me/blog/unit-testing-is-overrated)
#
# * [Against Testing](https://flak.tedunangst.com/post/against-testing)
#
# * [Systems design for advanced beginners](https://robertheaton.com/2020/04/06/systems-design-for-advanced-beginners/)
#
# * [Monitoring demystified: A guide for logging, tracing, metrics](https://techbeacon.com/enterprise-it/monitoring-demystified-guide-logging-tracing-metrics)
#
# * [Unofficial guide to Datomic internals](https://tonsky.me/blog/unofficial-guide-to-datomic-internals/)
#
# * [Introducing Domain-Oriented Microservice Architecture](https://eng.uber.com/microservice-architecture/)
#
# * [Powering inheritance in C using structure composition](https://arpitbhayani.me/blogs/inheritance-c)
#
# * [Complexity Has to Live Somewhere](https://ferd.ca/complexity-has-to-live-somewhere.html)
#
#
#
# * [Software 2.0](https://medium.com/@karpathy/software-2-0-a64152b37c35)
#
# * [Scalable System Design](http://horicky.blogspot.com/2008/02/scalable-system-design.html)
#
# * [Software Metrics PDF](http://sunnyday.mit.edu/16.355/metrics.pdf)
#
# * [Education of a Programmer](http://www.cwsei.ubc.ca/Files/Bjork_Seven_Study_Techniques.pdf)
#
# * [RESTful APIs (PDF)](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-170-software-studio-spring-2013/lecture-notes/MIT6_170S13_13-restful-ser.pdf)
#
# * [Por qué y cuándo usar las claves de API](https://cloud.google.com/endpoints/docs/openapi/when-why-api-key)
#
#
#
# * [Glossary of Terms Special Issue on Applications of Machine Learning and the Knowledge Discovery Process](http://robotics.stanford.edu/~ronnyk/glossary.html)
#
# * [Let's implement a Bloom Filter](https://onatm.dev/2020/08/10/let-s-implement-a-bloom-filter/)
#
# * [Things I Wished More Developers Knew About Databases](https://medium.com/@rakyll/things-i-wished-more-developers-knew-about-databases-2d0178464f78)
#
# * [Notes to Myself on Software Engineering](https://medium.com/s/story/notes-to-myself-on-software-engineering-c890f16f4e4d)
#
# * [NOSQL Patterns](http://horicky.blogspot.com/2009/11/nosql-patterns.html)
#
# * [Session replay](https://en.wikipedia.org/wiki/Session_replay)
#
# * [Dataframe Visualization with Pandas Plot](https://kanoki.org/2019/09/16/dataframe-visualization-with-pandas-plot/)
#
# * [Web Design in 4 minutes](https://jgthms.com/web-design-in-4-minutes/)
#
# * [How to Improve a Legacy Codebase](https://jacquesmattheij.com/improving-a-legacy-codebase/)
#
#
# * [The SOLID Principles of Object-Oriented Programming Explained in Plain English](https://www.freecodecamp.org/news/solid-principles-explained-in-plain-english/)
#
# * [Design Principles Behind Smalltalk](https://www.cs.virginia.edu/~evans/cs655/readings/smalltalk.html)
#
# * [A Thorough Introduction to Distributed Systems](https://www.freecodecamp.org/news/a-thorough-introduction-to-distributed-systems-3b91562c9b3c/)
#
# * [The Legacy of Computer Science](http://0.0.0.0:8000/3%20Computacion/Articulos/The%20Legacy%20of%20Computer%20Science.pdf)
#
# * [How Docker Can Help You Become A More Effective Data Scientist](https://towardsdatascience.com/how-docker-can-help-you-become-a-more-effective-data-scientist-7fc048ef91d5)
#
# * [The log/event processing pipeline you can't have](https://apenwarr.ca/log/20190216)
#
# * [Memory model (programming)](https://en.wikipedia.org/wiki/Memory_model_(programming))
#
# * [Unicode In Five Minutes](https://richardjharris.github.io/unicode-in-five-minutes.html)
#
# * [Notes on A Philosophy of Software Design](https://www.lethain.com/notes-philosophy-software-design/)
#
# * [Peter Norvig's 9 Master Steps To Improving A Program](http://highscalability.com/blog/2014/2/25/peter-norvigs-9-master-steps-to-improving-a-program.html)
#
# * [A Thorough Introduction to Distributed Systems](https://www.freecodecamp.org/news/a-thorough-introduction-to-distributed-systems-3b91562c9b3c/)
#
# * [Mastering Programming](https://www.prod.facebook.com/notes/kent-beck/mastering-programming/1184427814923414)
#
# * [What Every Programmer Absolutely, Positively Needs To Know About Encodings And Character Sets To Work With Text](https://kunststube.net/encoding/)
#
# * [So you want to be a wizard](https://jvns.ca/blog/so-you-want-to-be-a-wizard/)
#
#
# * [Notes on A Philosophy of Software Design](https://www.lethain.com/notes-philosophy-software-design/)
#
# * [What Great .NET Developers Ought To Know (More .NET Interview Questions)](https://www.hanselman.com/blog/WhatGreatNETDevelopersOughtToKnowMoreNETInterviewQuestions.aspx)
#
# * [Concurrent programming, with examples](https://begriffs.com/posts/2020-03-23-concurrent-programming.html)
#
# * [Introduction to Concurrency](https://cs.lmu.edu/~ray/notes/introconcurrency)
#
# * [12 Favorite AutoHotKey Scripts You Can Use to Make Life Easier](https://www.maketecheasier.com/favorite-autohotkey-scripts/)
#
# * [Design Patterns for Humans](https://github.com/kamranahmedse/design-patterns-for-humans/blob/master/README.md)
#
# * [Sattolo's algorithm](https://danluu.com/sattolo/)
#
# * [What Is a Computational Essay?](https://writings.stephenwolfram.com/2017/11/what-is-a-computational-essay/)
#
# * [Computational science](https://en.wikipedia.org/wiki/Computational_science)
#
# * [A Concurrency Cost Hierarchy](https://travisdowns.github.io/blog/2020/07/06/concurrency-costs.html)
#
# * [Under Deconstruction: The State of Shopify’s Monolith](https://engineering.shopify.com/blogs/engineering/shopify-monolith)
#
# * [Data-oriented Programming in Python](https://www.moderndescartes.com/essays/data_oriented_python/)
#
# * [Memory model (programming)](https://en.wikipedia.org/wiki/Memory_model_(programming))
#
# - [The C10K problem](http://www.kegel.com/c10k.html)
#
# - [A Brief Totally Accurate History Of Programming Languages](https://medium.com/commitlog/a-brief-totally-accurate-history-of-programming-languages-cd93ec806124)
#
# - [REST APIs must be hypertext-driven](https://roy.gbiv.com/untangled/2008/rest-apis-must-be-hypertext-driven)
#
# - [HOW HTTPS WORKS](https://howhttps.works/)
#
# - [The First Few Milliseconds of an HTTPS Connection](http://www.moserware.com/2009/06/first-few-milliseconds-of-https.html)
#
# - [Things I Learned to Become a Senior Software Engineer](https://neilkakkar.com/things-I-learned-to-become-a-senior-software-engineer.html)
#
# - [Skills of a Software Engineer](https://neilkakkar.com/senior-software-engineer-summary.html)
#
# - [How Many Ways To Start An Xserver](https://nixers.net/Thread-How-Many-Ways-To-Start-An-Xserver)
#
# - [Why it is Important that Software Projects Fail](https://www.berglas.org/Articles/ImportantThatSoftwareFails/ImportantThatSoftwareFails.html)
#
# - [How Do Computers Generate Random Numbers?](https://digitalbunker.dev/2020/09/08/how-do-computers-generate-random-numbers/)
#
# - [State of Self-Serve Website Building in 2020](https://sprune.com/blog/state-of-self-serve-website-building-in-2020/)
#
# - [Raspberry Pi as a local server for self hosting applications](https://cri.dev/posts/2020-09-12-Raspberry-Pi-as-a-local-server-for-self-hosting-applications/)
#
# - (D) [How to Design a Good API and Why it Matters](http://0.0.0.0:8000/3%20Computacion/Articulos/How%20to%20Design%20a%20Good%20API%20and%20Why%20it%20Matters.pdf)
#
# - [Unicode In Five Minutes](https://richardjharris.github.io/unicode-in-five-minutes.html)
#
# * [Beginner’s Guide To Abstraction](https://jesseduffield.com/beginners-guide-to-abstraction/)
#
# * [Compounding Knowledge in Programming](https://www.agundy.com/2019/02/11/compounding-knowledge.html)
#
# * [Gathering Requirements Checklist for System Design](https://neilkakkar.com/requirements-checklist.html)
#
#
# * [Whats a proper way to design a GUI event system?](https://softwareengineering.stackexchange.com/questions/401661/whats-a-proper-way-to-design-a-gui-event-system)
# * [So you want to be a wizard](https://jvns.ca/blog/so-you-want-to-be-a-wizard/)
#
#
#
# * [Code to Read When Learning Go](https://www.somethingsimilar.com/2013/12/26/code-to-read-when-learning-go/)
# * [Type System Explained](https://thevaluable.dev/type-system-explained/)
# * [Repurposing my old Chromebook to a low power home server](https://tamas.dev/repurpose/asus/c300/chromebook/home/server/chromeos/linux/docker/containers/2020/09/28/repurpose-chromebook-low-power-home-server.html)
# * [An Illustrated Guide to OAuth and OpenID Connect](https://developer.okta.com/blog/2019/10/21/illustrated-guide-to-oauth-and-oidc)
# * Data Structures for Collaborative Computing:
#     - [I was wrong. CRDTs are the future](https://josephg.com/blog/crdts-are-the-future/)
#     - [Operational transformation (OT)](https://en.wikipedia.org/wiki/Operational_transformation)
# * [Software design pattern](https://en.wikipedia.org/wiki/Software_design_pattern)
# * [Simulated annealing](https://en.wikipedia.org/wiki/Simulated_annealing)
#
#
# * [Git Exercises](https://gitexercises.fracz.com/)
#
# - [Assessing Abstractions](https://stopa.io/post/245)
# - [Inventing Monads](https://stopa.io/post/247)
# - [Systems](https://stopa.io/post/186)
#
#
#
# - [Fibers, Oh My!](https://graphitemaster.github.io/fibers/)
#
# - [My Principles for Building Software](https://kevinmahoney.co.uk/articles/my-principles-for-building-software/)
#
# - [The Twelve-Factor App](https://12factor.net/)
#
# - [Is your programming language unreasonable? r, why predictability is important](https://fsharpforfunandprofit.com/posts/is-your-language-unreasonable/)
#
# - [How to Build a Highly Available System Using Consensus](http://bwlampson.site/58-Consensus/WebPage.html)
#
#
# - [Oct 11, 2020 - A review of consensus protocols](https://thomasvilhena.com/2020/10/a-review-of-consensus-protocols)
#
# - [Applying Textbook Data Structures for Real Life Wins](https://heap.io/blog/engineering/applying-textbook-data-structures-for-real-life-wins)
#
#
#
# * [What's in a Linux executable?](https://fasterthanli.me/series/making-our-own-executable-packer/part-1)
# * [Anatomy of a Binary Executable](https://oswalt.dev/2020/11/anatomy-of-a-binary-executable/)
#
#
# * [Notes on Paxos](https://matklad.github.io/2020/11/01/notes-on-paxos.html)
#
#
# * [Time Loop Software](https://marak.com/blog/2013-05-13-time-loop-software)
#
# * [REST APIs must be hypertext-driven](https://roy.gbiv.com/untangled/2008/rest-apis-must-be-hypertext-driven)
#
#
# * [Which tools and technologies are used to build the Stack Exchange Network?](https://meta.stackexchange.com/questions/10369/which-tools-and-technologies-are-used-to-build-the-stack-exchange-network)
#
# * [Stack Exchange Performace](https://stackexchange.com/performance)
#
#
# * [Filesystem and Database are not cutting the problem space right](https://boomla.com/blog/filesystem-and-database-are-not-cutting-the-problem-space-right)
#
#
# * [The Future of Programming](http://worrydream.com/dbx/)
#
#
# * [Linux Applications Performance: Introduction](https://unixism.net/2019/04/linux-applications-performance-introduction/)
#
# * [How fast does interpolation search converge?](https://lemire.me/blog/2020/11/25/how-fast-does-interpolation-search-converge/)
#
#
#
# * [What is a Turing machine?](https://www.cl.cam.ac.uk/projects/raspberrypi/tutorials/turing-machine/one.html)
#
#
#
#
#
#
# * [Readme Driven Development](https://tom.preston-werner.com/2010/08/23/readme-driven-development.html)
#
#
#
#
#
#
#
#
#
#
# * (D) [Computer Systems Research Past and Future](http://0.0.0.0:8000/3%20Computacion/Articulos/Computer%20Systems%20Research%20Past%20and%20Future.pdf)
# * (D) [What Do Computer Scientists Do](http://0.0.0.0:8000/3%20Computacion/Articulos/What%20Do%20Computer%20Scientists%20Do.pdf)
#
#
#
# * [Ant colony optimization algorithms](https://en.wikipedia.org/wiki/Ant_colony_optimization_algorithms)
#
#
# * [Building Web Applications](http://0.0.0.0:8000/3%20Computacion/Articulos/Building%20Web%20Applications.pdf)
# * [Controller - server communication](http://0.0.0.0:8000/3%20Computacion/Articulos/Controller%20-%20server%20communication.pdf)
#
# * [Future Web App Technologies](http://0.0.0.0:8000/3%20Computacion/Articulos/Future%20Web%20App%20Technologies.pdf)
# * [Hypertext Transport Protocol (HTTP)](http://0.0.0.0:8000/3%20Computacion/Articulos/Hypertext%20Transport%20Protocol%20%28HTTP%29.pdf)
# * [Large-Scale Web Applications](http://0.0.0.0:8000/3%20Computacion/Articulos/Large-Scale%20Web%20Applications.pdf)
#
# * [Security Network Attacks](http://0.0.0.0:8000/3%20Computacion/Articulos/Security%20Network%20Attacks.pdf)
# * [Session Attacks](http://0.0.0.0:8000/3%20Computacion/Articulos/Session%20Attacks.pdf)
# * [Sessions](http://0.0.0.0:8000/3%20Computacion/Articulos/Sessions.pdf)
# * [Single Page Applications](http://0.0.0.0:8000/3%20Computacion/Articulos/Single%20Page%20Applications.pdf)
# * [State Management](http://0.0.0.0:8000/3%20Computacion/Articulos/State%20Management.pdf)
# * [Storage Tier](http://0.0.0.0:8000/3%20Computacion/Articulos/Storage%20Tier.pdf)
# * [Web App Security Browser Isolation](http://0.0.0.0:8000/3%20Computacion/Articulos/Web%20App%20Security%20Browser%20Isolation.pdf)
# * [Web Servers](http://0.0.0.0:8000/3%20Computacion/Articulos/Web%20Servers.pdf)
#
# * (D) [Large Scale Deep Learning](http://0.0.0.0:8000/3%20Computacion/Articulos/Large%20Scale%20Deep%20Learning.pdf)
#
# * (D) [Evaluation of expressions](http://0.0.0.0:8000/3%20Computacion/Articulos/Evaluation%20of%20expressions.txt)
#
# * [The Missing Shell Scripting Crash Course](https://dev.to/godcrampy/the-missing-shell-scripting-crash-course-37mk)
#
# * [Raft Understandable Distributed Consensus](http://thesecretlivesofdata.com/raft/)
#
#
# * [Networking Tools Every Developer Needs to Know](https://martinheinz.dev/blog/38)
#
#
# * [Sockets In Your Shell](https://who23.github.io/2020/12/03/sockets-in-your-shell.html)
#
#
# * [Inversion of Control Containers and the Dependency Injection pattern](https://www.martinfowler.com/articles/injection.html)
#
#
# * [How Unix Works: Become a Better Software Engineer](https://neilkakkar.com/unix.html)
#
#
# * [Things I Learnt from a Senior Software Engineer](https://neilkakkar.com/things-I-learnt-from-a-senior-dev.html)
#
#
# * [How To Understand Systems](https://neilkakkar.com/understanding-systems.html)
#
#
# * [Introduction to the UNIX Shell (Bash)](https://pabloinsente.github.io/intro-unix-shell)
#
#
# * [Introduction to Jupyter Notebooks - set-up, user-guide, and best practices](https://pabloinsente.github.io/intro-jupyter-ide)
#
#
# *  [Needle in a haystack: efficient storage of billions of photos](https://engineering.fb.com/2009/04/30/core-data/needle-in-a-haystack-efficient-storage-of-billions-of-photos/)
#
#
# *  [John Carmack: Career Advice (twitter.com/id_aa_carmack)](https://news.ycombinator.com/item?id=25465579)
#
#
# * [To the brain, reading computer code is not the same as reading language
# ](https://news.mit.edu/2020/brain-reading-computer-code-1215)
#
#
#
# * [A Hacker's Introduction to Partial Evaluation](http://cybertiggyr.com/peval.html#further_reading)
#
# * [Write your Own Virtual Machine](https://justinmeiners.github.io/lc3-vm/)
#
# * [Yet another](https://en.wikipedia.org/wiki/Yet_another)
#
# * [Library (computing)](https://en.wikipedia.org/wiki/Library_(computing))
#
# * [Five Common Data Stores and When to Use Them](https://shopify.engineering/five-common-data-stores-usage)
#
# * [Incremental - Library for incremental computations](https://opensource.janestreet.com/incremental/)
#
# * [The Big Little Guide to Message Queues](https://sudhir.io/the-big-little-guide-to-message-queues/)
#
# * [The Dining Philosophers Problem](https://pages.mtu.edu/~shene/NSF-3/e-Book/MUTEX/TM-example-philos-1.html)
#
# * [Searching for RH Counterexamples — Deploying with Docker](https://jeremykun.com/2021/01/04/searching-for-rh-counterexamples-deploying-with-docker/)
#
# * [API pagination design](https://solovyov.net/blog/2020/api-pagination-design/)
#
# * [APIs All the Way Down](https://notboring.substack.com/p/apis-all-the-way-down)
#
# * [How much math you need for programming](https://lispmachine.wordpress.com/2014/12/05/how-much-math-you-need-for-programming/)
#
# * [How the Bitcoin protocol actually works](https://michaelnielsen.org/ddi/how-the-bitcoin-protocol-actually-works/)
#
# * [Lateral computing](https://en.wikipedia.org/wiki/Lateral_computing)
#
# * [Memory-mapped I/O](https://en.wikipedia.org/wiki/Memory-mapped_I/O)
#
# * [Partial evaluation](https://en.wikipedia.org/wiki/Partial_evaluation)
#
# * [QEMU](https://en.wikipedia.org/wiki/QEMU)
#
# * [Recursive acronym](https://en.wikipedia.org/wiki/Recursive_acronym)
#
# * [Solving Algorithmic Problems in Python with Pytest](https://adamj.eu/tech/2019/04/21/solving-algorithmic-problems-in-python-with-pytest/)
#
# * [Data Structures - Sparse Matrices](https://matteding.github.io/2019/04/25/sparse-matrices/)
#
#
# * [Web Authentication Methods Compared](https://testdriven.io/blog/web-authentication-methods/)
#
# * [Computational problem](https://en.wikipedia.org/wiki/Computational_problem)
#
# * [Highly useful Linux commands & configurations](https://www.dedoimedo.com/computers/linux_commands.html)
#
# * [Understanding Connections & Pools](https://sudhir.io/understanding-connections-pools/)
#
# * [A Visual Guide to Regular Expression](https://amitness.com/regex/)
#
# * [What I’ve Learned in 45 Years in the Software Industry](https://www.bti360.com/what-ive-learned-in-45-years-in-the-software-industry/)
#
#
# * [CLR Threading Support](https://flylib.com/books/en/4.453.1.62/1/)
#
# * [User experience design for APIs](https://blog.keras.io/category/essays.html)
#
# * [Is it possible to create threads without system calls in Linux x86 GAS assembly?](https://stackoverflow.com/questions/714905/is-it-possible-to-create-threads-without-system-calls-in-linux-x86-gas-assembly)
#
# * (D) [R Internals](http://0.0.0.0:8000/3%20Computacion/Articulos/R%20Internals.pdf)
#
# * (D) [Applied Software Engineering](http://0.0.0.0:8000/3%20Computacion/Articulos/Applied%20Software%20Engineering.pdf)
#
# * (D) [What Software Reality Is Really About](http://0.0.0.0:8000/3%20Computacion/Articulos/What%20Software%20Reality%20Is%20Really%20About.pdf)
#
# * (D) [Software Architecture Patterns](http://0.0.0.0:8000/3%20Computacion/Articulos/Software%20Architecture%20Patterns.pdf)
#
# * (D) [Large-Scale Web Applications](http://0.0.0.0:8000/3%20Computacion/Articulos/Large-Scale%20Web.pdf)
#
# * (D) [Object Oriented Design Heuristics](http://0.0.0.0:8000/3%20Computacion/Articulos/Object%20Oriented%20Design%20Heuristics.pdf)
#
#
# * (D) [Do You Want to A Wizard](http://0.0.0.0:8000/3%20Computacion/Articulos/Do%20You%20Want%20to%20A%20Wizard.pdf)
#
#  * [Kolmogorov complexity](https://en.wikipedia.org/wiki/Kolmogorov_complexity)
#
#  * [Visualizing Algorithms](https://bost.ocks.org/mike/algorithms/)
#
#  * [Fundamentals of Optimal Code Style](https://optimal-codestyle.github.io/)
#
#  * [Get better at programming by learning how things work](https://jvns.ca/blog/learn-how-things-work/)
#
#
#
#     * [Array Databases: Concepts, Standards, Implementations](https://rd-alliance.org/system/files/Array-Databases_final-report.pdf)
#
# * [REST vs. GraphQL vs. gRPC](https://www.danhacks.com/software/grpc-rest-graphql.html)
#
# * [Dataflow programming](https://en.wikipedia.org/wiki/Dataflow_programming)
#
# * [Event Sourcing](https://arkwright.github.io/event-sourcing.html)
#
# * [Streaming 101: The world beyond batch](https://www.oreilly.com/radar/the-world-beyond-batch-streaming-101/)
#
# * [In-Stream Big Data Processing](https://highlyscalable.wordpress.com/2013/08/20/in-stream-big-data-processing/)
#
# * [What's new in SQLite 3.35](https://nalgeon.github.io/sqlite-3-35/)
#
# * [An introduction to lockless algorithms](https://lwn.net/Articles/844224/)
#
# * [An open source alternative to Wolfram Alpha](https://softwarerecs.stackexchange.com/questions/21336/an-open-source-alternative-to-wolfram-alpha)
#
# * [Amdahl's law](https://en.wikipedia.org/wiki/Amdahl%27s_law)
#
# * [An Interactive Guide to CSS Transitions](https://www.joshwcomeau.com/animation/css-transitions/)
#
# * [RethinkDB: why we failed](https://www.defmacro.org/2017/01/18/why-rethinkdb-failed.html)
#
# * [.NET GC Internals mini-series](https://tooslowexception.com/net-gc-internals-mini-series/)
#
# * [10 essential Vim plugins. Vim remains a powerful and ubiquitous… | by Alex Hunt | Medium](https://medium.com/@huntie/10-essential-vim-plugins-for-2018-39957190b7a9)
#
# * [7 bite-sized tips for reliable web automation and scraping selectors | by Todd Schiller | Brick by Brick | Medium](https://medium.com/brick-by-brick/7-bite-sized-tips-for-reliable-web-automation-and-scraping-selectors-2612bc4de2a1)
#
# * [5 reasons why I love coding on Linux](https://opensource.com/article/21/2/linux-programming)
#
# * [A Complete Guide to Neovim Configuration for Python Development on Linux - jdhao's blog](https://jdhao.github.io/2018/12/24/centos_nvim_install_use_guide_en/)
#
# * [Application-specific integrated circuit](https://en.wikipedia.org/wiki/Application-specific_integrated_circuit)
#
# * [Applications of Hash Table](https://afteracademy.com/blog/applications-of-hash-table)
#
# * [A Silicon Person](https://geohot.github.io/blog/jekyll/update/2020/08/20/a-silicon-person.html)
#
# * [Bash Reference Manual](http://www.gnu.org/software/bash/manual/bash.html)
#
# * [Berkeley DB - Architecture](https://www.aosabook.org/en/bdb.html)
#
# * [Best practices for REST API design](https://stackoverflow.blog/2020/03/02/best-practices-for-rest-api-design/)
#
# * [Bluetooth](https://en.wikipedia.org/wiki/Bluetooth)
#
# * [Brandolini's law](https://en.wikipedia.org/wiki/Brandolini%27s_law)
#
# * [async function](https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/async_function)
#
# * [Async/await](https://en.wikipedia.org/wiki/Async/await)
#
# * [Build an 8-bit computer | Ben Eater](https://eater.net/8bit/)
#
# * [Complexity no Bar to AI](https://www.gwern.net/Complexity-vs-AI)
#
# * [Computational complexity of mathematical operations](https://en.m.wikipedia.org/wiki/Computational_complexity_of_mathematical_operations)
#
# * [Computational problem](https://en.wikipedia.org/wiki/Computational_problem)
#
# * [Computational Reducibility](https://mathworld.wolfram.com/ComputationalReducibility.html)
#
# * [Computer science](https://en.wikipedia.org/wiki/Computer_science#Fields)
#
# * [Window System Design: If I had it to do over again in 2002](https://hack.org/mc/texts/gosling-wsd.pdf)
#
# * [Windowing system](https://en.wikipedia.org/wiki/Windowing_system)
#
# * [ZeroMQ - Architecture](https://www.aosabook.org/en/zeromq.html)
#
# * [Why software projects take longer than you think: a statistical model](https://erikbern.com/2019/04/15/why-software-projects-take-longer-than-you-think-a-statistical-model.html#)
#
# * [Download jq](https://stedolan.github.io/jq/download/)
#
# * [Dynamic dispatch](https://en.wikipedia.org/wiki/Dynamic_dispatch)
#
# * [Dynamic programming](https://en.wikipedia.org/wiki/Dynamic_programming)
#
# * [Create a custom URL Protocol Handler](https://unix.stackexchange.com/questions/497146/create-a-custom-url-protocol-handler)
#
# * [Designing a RISC-V CPU, Part 1: Learning hardware design as a software engineer](https://mcla.ug/blog/risc-v-cpu-part-1.html)
#
# * [Developer-Y/cs-video-courses: List of Computer Science courses with video lectures.](https://github.com/Developer-Y/cs-video-courses#systems-programming)
#
# * [Data parallelism](https://en.wikipedia.org/wiki/Data_parallelism)
#
# * [Event dispatching thread](https://en.wikipedia.org/wiki/Event_dispatching_thread)
#
# * [Event-driven architecture](https://en.wikipedia.org/wiki/Event-driven_architecture)
#
# * [Model of computation](https://en.wikipedia.org/wiki/Model_of_computation)
#
# * [Lambda handbook for new employees](https://github.com/lambdaclass/lambda_handbook_for_new_employees)
#
# * ["Design Patterns" Aren't](https://perl.plover.com/yak/design/)
#
# * [Best practices can slow your application down - Stack Overflow Blog](https://stackoverflow.blog/2021/03/03/best-practices-can-slow-your-application-down/?cb=1&_ga=2.145693744.523477250.1614802183-1247573525.1613934766)
#
# * [FastAPI](https://fastapi.tiangolo.com/)
#
# * [Field-programmable gate array](https://en.wikipedia.org/wiki/Field-programmable_gate_array)
#
# * [File system](https://en.wikipedia.org/wiki/File_system)
#
# * [Escape character](https://en.wikipedia.org/wiki/Escape_character)
#
# * [Firmware](https://en.wikipedia.org/wiki/Firmware)
#
# * [Foundational distributed systems papers](http://muratbuffalo.blogspot.com/2021/02/foundational-distributed-systems-papers.html)
#
# * [Don't use functions as callbacks unless they're designed for it](https://jakearchibald.com/2021/function-callback-risks/)
#
#
# * [Functional Programming and Event Sourcing with Jérémie Chassaing](https://www.youtube.com/watch?v=kgYGMVDHQHs)
#
# * [GDB - Architecture](https://www.aosabook.org/en/gdb.html)
#
# * [Hotwire: a radical new old way to build web apps | Medium](https://delitescere.medium.com/hotwire-html-over-the-wire-2c733487268c)
#
# * [How .NET Regular Expressions Really Work](http://www.moserware.com/2009/03/how-net-regular-expressions-really-work.html)
#
# * [VIM and Python – A Match Made in Heaven – Real Python](https://realpython.com/vim-and-python-a-match-made-in-heaven/)
#
# * [Vim Splits - Move Faster and More Naturally](https://thoughtbot.com/blog/vim-splits-move-faster-and-more-naturally)
#
# * [vim-cheatsheet.pdf](https://www.cs.cmu.edu/~15131/f17/topics/vim/vim-cheatsheet.pdf)
#
# * [Virtual file system](https://en.wikipedia.org/wiki/Virtual_file_system)
#
# * [Visual Information Theory -- colah's blog](http://colah.github.io/posts/2015-09-Visual-Information/)
#
# * [Web Spreadsheet - 500L](https://www.aosabook.org/en/500L/web-spreadsheet.html)
#
# * [Web traffic](https://en.wikipedia.org/wiki/Web_traffic)
#
# * [What are some practical applications of hashing? - Quora](https://www.quora.com/What-are-some-practical-applications-of-hashing)
#
# * [What does this print, #1](https://blog.kevmod.com/2014/06/what-does-this-print-1/)
#
# * [What every programmer should know about memory](https://lwn.net/Articles/250967/)
#
# * [What is a language binding?](https://stackoverflow.com/questions/25865/what-is-a-language-binding)
#
# * [What is a Turing machine?](https://www.cl.cam.ac.uk/projects/raspberrypi/tutorials/turing-machine/one.html)
#
# * [What is an application binary interface (ABI)?](https://stackoverflow.com/questions/2171177/what-is-an-application-binary-interface-abi)
#
# * [Aspect-oriented programming](https://en.wikipedia.org/wiki/Aspect-oriented_programming)
#
# * [Heroic Programming](https://wiki.c2.com/?HeroicProgramming)
#
#
#
#
# * [Software development is a loser’s game](https://thehosk.medium.com/software-development-is-a-losers-game-fc68bb30d7eb)
#
#
# * [On Cache Invalidation](https://yihui.org/en/2018/06/cache-invalidation/)

# %% [markdown]
# # Computational Learning

# %% [markdown]
# - [Algorithmic Information Theory](http://www.hutter1.net/ait.htm)
#
# - [Deep reinforcement learning will transform manufacturing as we know it](https://techcrunch.com/2021/06/17/deep-reinforcement-learning-will-transform-manufacturing-as-we-know-it/)
#   - [Discussion](https://news.ycombinator.com/item?id=27557856)
#
# - [t-statistic](https://en.wikipedia.org/wiki/T-statistic)
#
# - [Understanding p-values Through Simulations](https://rpsychologist.com/pvalue/)
#
# - [Understanding Q-Q Plots](https://data.library.virginia.edu/understanding-q-q-plots/)
#
# - [Student's t-distribution](https://en.wikipedia.org/wiki/Student's_t-distribution)
#
# - [Summary statistics](https://en.wikipedia.org/wiki/Summary_statistics)
#
# - [Survivorship bias](https://en.wikipedia.org/wiki/Survivorship_bias)
#
# - [Zoom In: An Introduction to Circuits](https://distill.pub/2020/circuits/zoom-in/)
#
# - [Standard deviation](https://en.wikipedia.org/wiki/Standard_deviation)
#
# - [Statistical dispersion](https://en.wikipedia.org/wiki/Statistical_dispersion)
#
# - [Why I've lost faith in p values](https://lucklab.ucdavis.edu/blog/2018/4/19/why-i-lost-faith-in-p-values)
#
# - [What is P-Value? – Understanding the meaning, math and methods](https://www.machinelearningplus.com/what-is-p-value/)
#
# - [Robust statistics](https://en.wikipedia.org/wiki/Robust_statistics)
#
# - [Simpson's paradox](https://en.wikipedia.org/wiki/Simpson%27s_paradox)
#
# - [Skewness](https://en.wikipedia.org/wiki/Skewness)
#
# - [Open-high-low-close chart](https://en.wikipedia.org/wiki/Open-high-low-close_chart)
#
# - [P Values](https://www.statsdirect.com/help/basics/p_values.htm)
#
# - [p-values are inconsistent](https://www.johndcook.com/blog/2010/03/03/p-values-are-inconsistent/)
#
# - [How to test my data against an specific normal distribution?](https://stats.stackexchange.com/questions/56106/how-to-test-my-data-against-an-specific-normal-distribution)
#
# - [Moving Average](https://en.wikipedia.org/wiki/Moving_average)
#
# - [Misinterpretations and misuses of p-values](https://web.ma.utexas.edu/users/mks/statmistakes/misinterppvalues.html)
#
# * [Kolmogorov–Smirnov test](https://en.wikipedia.org/wiki/Kolmogorov%E2%80%93Smirnov_test)
#
# - [Ecological fallacy](https://en.wikipedia.org/wiki/Ecological_fallacy)
#
# - [Good, mediocre, and bad p-values](https://statmodeling.stat.columbia.edu/2015/04/30/good-mediocre-bad-p-values/)
#
# * [Kernel (statistics)](https://en.wikipedia.org/wiki/Kernel_(statistics))
#
# - [Deviation (statistics)](https://en.wikipedia.org/wiki/Deviation_(statistics))
#
# - [A Litany of Problems With p-values](https://www.fharrell.com/post/pval-litany/)
#
# - [Accuracy and precision](https://en.wikipedia.org/wiki/Accuracy_and_precision)
#
# - [Data-generating probability distribution, probability distribution of a dataset, in ML](https://datascience.stackexchange.com/questions/54346/data-generating-probability-distribution-probability-distribution-of-a-dataset)
#   - How can i used a  probability distribution to generate data.
#
# - [Explaining p-values with puppies](https://hackernoon.com/explaining-p-values-with-puppies-af63d68005d0)
#
# - [Friends don’t let friends calculate p-values (without fully understanding them)](http://www.scottbot.net/HIAL/index.html@p=24697.html)
#
# - [Generative model](https://en.wikipedia.org/wiki/Generative_model)
#
# - [Statistical model](https://en.wikipedia.org/wiki/Statistical_model)
#
# - [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet)
#
# - [Average](https://en.wikipedia.org/wiki/Average)
#
# - [Average absolute deviation](https://en.wikipedia.org/wiki/Average_absolute_deviation)
#
# - [Box plot](https://en.wikipedia.org/wiki/Box_plot)
#
# - [Coefficient of variation](https://en.wikipedia.org/wiki/Coefficient_of_variation)

# %% [markdown]
# * [Statistics (scipy.stats)](https://docs.scipy.org/doc/scipy/reference/tutorial/stats.html#t-test-and-ks-test)
#
# * [scipy.stats.ttest_1samp](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_1samp.html)
#
# * [p-value](https://en.wikipedia.org/wiki/P-value)
#
# * [Exclusion of the null hypothesis](https://en.wikipedia.org/wiki/Exclusion_of_the_null_hypothesis)
#
# * [Standard error](https://en.wikipedia.org/wiki/Standard_error)
#
# * [t-statistic](https://en.wikipedia.org/wiki/T-statistic)
#
# * [A Visual Exploration of Gaussian Processes](https://distill.pub/2019/visual-exploration-gaussian-processes/)
#
# * [Standard deviation](https://en.wikipedia.org/wiki/Standard_deviation)
#
# * [Log-normal distribution](https://en.wikipedia.org/wiki/Log-normal_distribution)
#
# * [Fat-tailed distribution](https://en.wikipedia.org/wiki/Fat-tailed_distribution)
#
# * [Taleb distribution](https://en.wikipedia.org/wiki/Taleb_distribution)
#
# * [Normal distribution](https://en.wikipedia.org/wiki/Normal_distribution)
#
# * [Forecasting at Uber: An Introduction](https://eng.uber.com/forecasting-introduction/)
#
# * [Introducing Ludwig, a Code-Free Deep Learning Toolbox](https://eng.uber.com/introducing-ludwig/)
#
# * [Why are neural networks so powerful?](https://towardsdatascience.com/why-are-neural-networks-so-powerful-bc308906696c)
#
# * [EigenGame maps out a new approach to solve fundamental ML problems](https://deepmind.com/blog/article/EigenGame)
#
# * [An Introduction to Knowledge Graphs](http://ai.stanford.edu/blog/introduction-to-knowledge-graphs/)
#
# * [Resources | The Little Dataset](https://thelittledataset.com/data_code/)
#
# * [Knowledge Graph](https://en.wikipedia.org/wiki/Knowledge_graph)
#
# * [Andrew Ng X-Rays the AI Hype](https://arstechnica.com/gadgets/2021/05/apple-hires-yet-another-ex-google-ai-leader/)
#
# * [Hopfield Networks is All You Need](http://justinjaffray.com/query-engines-push-vs.-pull/)
#
# * [Principal Component Analysis](https://setosa.io/ev/principal-component-analysis/)
#
# * [ML beyond Curve Fitting: An Intro to Causal Inference and do-Calculus](https://www.inference.vc/untitled/)
#
# * [No free lunch theorem](https://en.wikipedia.org/wiki/No_free_lunch_theorem)
#
# * [Automated machine learning (AutoML)](https://en.wikipedia.org/wiki/Automated_machine_learning)
#
# * [Search: Query Matching via Lexical, Graph, and Embedding Methods](https://eugeneyan.com/writing/search-query-matching/)
#
# * [Geometric foundations of Deep Learning](https://towardsdatascience.com/geometric-foundations-of-deep-learning-94cdd45b451d)
#
# * [A recommender system for scientific papers](https://statmodeling.stat.columbia.edu/2021/04/16/a-recommender-system-for-scientific-papers/)
#
# * [Machine Learning 101](https://docs.google.com/presentation/d/1kSuQyW5DTnkVaZEjGYCkfOxvzCqGEFzWBy4e9Uedd9k/preview?pru=AAABdHL9X3A*1T5cE4vF1wtY7TY9Pe5d5A&slide=id.g168a3288f7_0_58)
#
# * [Brian Kihoon Lee -  My Path to Machine Learning](https://www.moderndescartes.com/essays/my_ml_path/)
#
# * [How I taught myself Deep Learning: Vanilla NNs](https://www.kaggle.com/andradaolteanu/how-i-taught-myself-deep-learning-vanilla-nns)
#
# * [Why is machine learning 'hard'?](http://ai.stanford.edu/~zayd/why-is-machine-learning-hard.html)
#
# * [The Data Science Tree of Knowledge - What is Data Science and How to Educate Data Scientists](https://pabloinsente.github.io/ds-tree-knowledge)
#
# * Machine Learning Crash course
#   - [Part 1 - The basics of machine learning - regression, cost functions, and gradient descent.](https://ml.berkeley.edu/blog/posts/crash-course/part-1/)
#   - [Part 2 - Perceptrons, logistic regression, and SVMs.](https://ml.berkeley.edu/blog/posts/crash-course/part-2/)
#   - [Part 3 - Neural networks.](https://ml.berkeley.edu/blog/posts/crash-course/part-3/)
#   - [Part 4 - The Bias-Variance Dilemma.](https://ml.berkeley.edu/blog/posts/crash-course/part-4/)
#   - [Part 5 - Decision trees and ensemble models.](https://ml.berkeley.edu/blog/posts/crash-course/part-5/)
#
# * [Python Numpy Tutorial](https://cs231n.github.io/python-numpy-tutorial/)
# * [NumPy Fundamentals for Data Science and Machine Learning](https://pabloinsente.github.io/intro-numpy-fundamentals)
#
# * [Google Colab Tips for Power Users](https://amitness.com/2020/06/google-colaboratory-tips)
#
#
# * [An introduction to reinforcement learning](https://colab.research.google.com/github/psc-g/intro_to_rl/blob/master/Introduction_to_reinforcement_learning.ipynb)
#
# * [Using NLP to allow for flatter organizations](https://middle-out.io/posts/nlp_orgs)
#
# * [Universal approximation theorem](https://en.wikipedia.org/wiki/Universal_approximation_theorem)
#
# * [Multilayer perceptron](https://en.wikipedia.org/wiki/Multilayer_perceptron)
#
#
# * [Modern Deep Learning Techniques Applied to Natural Language Processing ](https://nlpoverview.com/)
#
#
# * [Backpropagation](https://brilliant.org/wiki/backpropagation/)
#
#
# * [Statistical model](https://en.wikipedia.org/wiki/Statistical_model)
#
# * [Statistics](https://en.wikipedia.org/wiki/Statistics)
#
# * [User modeling](https://en.wikipedia.org/wiki/User_modeling)
#
# * [Introduction to Bayesian Inference](https://www.kaggle.com/philippsinger/introduction-to-bayesian-inference)
#
# * [Approaching (Almost) Any NLP Problem on Kaggle](https://www.kaggle.com/abhishek/approaching-almost-any-nlp-problem-on-kaggle)
#
#
# * [Pattern recognition](https://en.wikipedia.org/wiki/Pattern_recognition)
#
# * (D) [AI Data Architecture](http://0.0.0.0:8000/2%20Aprendisaje%20Automatico/Articulos/AI%20Data%20Architecture.pdf)
#
# * (D) [Artificial Intelligence and Machine Learning](http://0.0.0.0:8000/2%20Aprendisaje%20Automatico/Articulos/Artificial%20Intelligence%20and%20Machine%20Learning.pdf)
#
#
# * [A simple solution for monitoring ML systems](https://www.jeremyjordan.me/ml-monitoring/)
#
# * [What does a data-generating process (DGP) actually mean?](https://stats.stackexchange.com/questions/443320/what-does-a-data-generating-process-dgp-actually-mean)
#
# * [Simple PyTorch Transformer Example with Greedy Decoding](https://colab.research.google.com/drive/1swXWW5sOLW8zSZBaQBYcGQkQ_Bje_bmI#scrollTo=b6eCpl-ne7tj)
#
# * [The limitations of deep learning](https://blog.keras.io/the-limitations-of-deep-learning.html)
#
# * [The future of deep learning](https://blog.keras.io/the-future-of-deep-learning.html)
#
# * [Baselines ML](https://madewithml.com/courses/applied-ml/baselines/)
#
#
# * [What does a data-generating process (DGP) actually mean?](https://stats.stackexchange.com/questions/443320/what-does-a-data-generating-process-dgp-actually-mean)
#
#
# * [Question answering](https://en.wikipedia.org/wiki/Question_answering)
#
# * [Can I use Deep Learning for that?](https://marksaroufim.medium.com/can-deep-learning-solve-my-problem-a-type-theoretic-heuristic-e57f4d1658f)
#
# * [Inference engine](https://en.wikipedia.org/wiki/Inference_engine)
#
# * [5 Open Problems In NLP](https://deeps.site/blog/2019/09/09/nlp-problems/)
#
# * [A Computational Model for Intelligent Manufacturin](https://industrytoday.com/a-computational-model-for-intelligent-manufacturing/)
#
# * [A top-down, practical guide to learn AI, Deep learning and Machine Learning](https://github.com/emilwallner/How-to-learn-Deep-Learning)
#
# * [AMA: Michael I Jordan](https://www.reddit.com/r/MachineLearning/comments/2fxi6v/ama_michael_i_jordan/)
#
# * [An Introduction to Hierarchical Modeling](http://mfviz.com/hierarchical-models/)
#
# * [An Overview of Deep Learning for Curious People](https://lilianweng.github.io/lil-log/2017/06/21/an-overview-of-deep-learning.html)
#
# * [An overview of gradient descent optimization algorithms](https://ruder.io/optimizing-gradient-descent/)
#
# * [Analyze your WhatsApp Chat](https://community.wolfram.com/groups/-/m/t/2063174)
#
# * [Artificial Neural Nets Finally Yield Clues to How Brains Learn](https://www.quantamagazine.org/artificial-neural-nets-finally-yield-clues-to-how-brains-learn-20210218/)
#
# * [Attention and Memory in Deep Learning and NLP](http://www.wildml.com/2016/01/attention-and-memory-in-deep-learning-and-nlp/)
#
# * [Auto training and fast deployement for state-of-the-art NLP models](https://huggingface.co/autonlp)
#
# * [Automating My Job with GPT-3](https://blog.seekwell.io/gpt3)
#
# * [Cancer can be precisely diagnosed using a urine test with artificial intelligence](https://phys.org/news/2021-01-cancer-precisely-urine-artificial-intelligence.html)
#
# * [Cannes: How ML saves us $1.7M a year on document previews](https://dropbox.tech/machine-learning/cannes--how-ml-saves-us--1-7m-a-year-on-document-previews)
#
#
# * [Categorical Foundations of Gradient-Based Learning](https://www.brunogavranovic.com/posts/2021-03-03-Towards-Categorical-Foundations-Of-Neural-Networks.html)
#
# * [Causal model](https://en.wikipedia.org/wiki/Causal_model)
#
# * [Cellular automaton](https://en.wikipedia.org/wiki/Cellular_automaton)
#
# * [Centrifugal governor](https://en.wikipedia.org/wiki/Centrifugal_governor)
#
# * [Ceteris paribus](https://en.wikipedia.org/wiki/Ceteris_paribus)
#
# * [Color model](https://en.wikipedia.org/wiki/Color_model)
#
# * [Cheap PCB story](https://github.com/hardenedlinux/cheap-pcb/blob/main/cheap-pcb-story.md)
#
# * [Chinese restaurant process](https://en.wikipedia.org/wiki/Chinese_restaurant_process)
#
# * [CLIP: Connecting Text and Images](https://openai.com/blog/clip/)
#
# * [Relations and differences between time-series analysis and statistical signal processing? - Cross Validated](https://stats.stackexchange.com/questions/52270/relations-and-differences-between-time-series-analysis-and-statistical-signal-pr)
# * [Keynesian beauty contest](https://en.wikipedia.org/wiki/Keynesian_beauty_contest)
# * [Time series](https://en.wikipedia.org/wiki/Time_series)
# * [What's the point of time series analysis?](https://stats.stackexchange.com/questions/367590/whats-the-point-of-time-series-analysis)
# * [How to Write a Neurips Paper 1. voodoo rituals to procure research… | by Evan Pu | Jan, 2021 | Medium](https://evanthebouncy.medium.com/how-to-write-a-neurips-paper-1-5b25a64d1d03)
# * [Machine Learning: The Great Stagnation - Breaking the Stagnation](https://marksaroufim.substack.com/p/machine-learning-the-great-stagnation)
# * [The Sovereign Student - Breaking the Stagnation](https://marksaroufim.substack.com/p/the-sovereign-student)
# * [No BS Machine Learning News - Breaking the Stagnation](https://marksaroufim.substack.com/p/coming-soon)
#
# * [Word Embeddings: The Good, the Bad, and the Ugly](https://medium.com/ontologik/word-embeddings-the-good-the-bad-and-the-ugly-ad67ada0e688)
#
# * [NLU and Natural Language Interfaces to Databases](https://medium.com/ontologik/nlu-and-natural-language-interfaces-to-databases-d04c3f032949)
#
# * [Data, Information, Knowledge, and GPT-3](https://medium.com/ontologik/data-information-knowledge-and-gpt-3-5e422107b46b)
#
# * [Semantics, Ambiguity, and the role of Probability in NLU](https://medium.com/ontologik/semantics-ambiguity-and-the-role-of-probability-in-nlu-e8e92fc7e8ed)
#
# * [Language & Cognition: re-reading Jerry Fodor](https://medium.com/ontologik/language-cognition-re-reading-jerry-fodor-53e98c9933f4)
#
# * [What we learn vs. what we know](https://medium.com/ontologik/what-we-learn-vs-what-we-know-1569e3fac3c9)
#
# * [Time to put an end to BERTology (or, ML/DL is not even relevant to NLU)](https://medium.com/ontologik/time-to-put-an-end-to-bertology-or-ml-dl-is-not-even-relevant-to-nlu-e5ba6fc53403)
#
# * [In NLU, you ignore intenSion at your peril](https://medium.com/ontologik/in-nlu-you-ignore-intension-at-your-peril-dd173670660d)
#
# * [Cognitive and Universal Primitives of the Language of Thought](https://medium.com/ontologik/cognitive-and-universal-primitives-of-the-language-of-thought-4be67096f9bc)
#
# * [Memorizing vs. Understanding (read: Data vs. Knowledge)](https://medium.com/ontologik/memorizing-vs-understanding-read-data-vs-knowledge-d27c5c756740)
#
# * [How the Tech Giants are Hampering Progress in Artificial Intelligence and Cognitive Computing](https://medium.com/ontologik/how-the-tech-giants-are-hampering-progress-in-artificial-intelligence-and-cognitive-computing-6a7ece7c9623)
#
# * [Learning from Data/Observations is Overrated](https://medium.com/ontologik/learning-from-data-observations-is-overrated-329a20d9fac1)
#
# * [The ‘transfer learning’ problem in DL: a NN is a hardware implementation of a specific algorithm](https://medium.com/ontologik/the-transferability-problem-in-neural-networks-a-nn-is-just-the-hardware-that-implements-a-6e3e54d00172)
#
# * [An Embarrassing Challenge for So-Called AI ‘Experts’ (of the ML/DL Ilk)](https://medium.com/ontologik/an-embarrassing-challenge-for-so-called-ai-experts-of-the-ml-dl-ilk-430541838d0a)
#
# * [Progressives Beware: Vote for the Neoliberals is a Vote for the Fascists and the Far-Right](https://medium.com/@ontologik/progressives-beware-vote-for-the-neoliberals-is-a-vote-for-the-fascists-and-the-far-right-c87551f6c5b3)
#
# * [No Walls in the Global Village](https://medium.com/platopia/no-walls-in-the-global-village-7968afd9a2a8)
#
# * [NLU is not NLP++](https://medium.com/ontologik/nlu-is-not-nlp-617f7535a92e)
#
# * [Data Science? All we Did is Just Replace the ‘Knowledge Bottleneck’ With a ‘Data Bottleneck’](https://medium.com/ontologik/data-science-all-we-did-is-just-replace-the-knowledge-bottleneck-with-a-data-bottleneck-b40c0e642541)
#
# * [Let’s Not Forget the ‘Science’ in ‘Computer Science’](https://medium.com/ontologik/lets-not-forget-the-science-in-computer-science-239d04f4d9a8)
#
# * [(Almost) Automatic Programming: Recursive Thinking as the Easiest Problem Solving Method](https://medium.com/ontologik/almost-automatic-programming-recursive-thinking-as-the-easiest-problem-solving-method-c4204beb01b0)
#
# * [Why Ambiguity is Necessary, and why Natural Language is not Learnable](https://medium.com/ontologik/why-ambiguity-is-necessary-and-why-natural-language-is-not-learnable-79f0e719ac78)
#
# * [Types, Ontology, and a Solution to the (so-called) Paradox of the Ravens](https://medium.com/ontologik/a-solution-to-the-so-called-paradox-of-the-ravens-defdf1ff9b13)
#
# * [The Unrelenting Ghosts of Fodor and Frege: 4 Technical Reasons why Data-Driven and Machine Learning NLU is a Myth](https://medium.com/ontologik/the-unrelenting-ghosts-of-fodor-and-frege-4-technical-reasons-why-data-driven-and-machine-d72698c22775)
#
# * [A Knowledge Graph?](https://medium.com/ontologik/a-knowledge-graph-981d4b7bc605)
#
# * [Must-read papers on graph neural networks (GNN)](https://github.com/thunlp/GNNPapers)
#
# * [The Unrelenting Ghosts of Fodor and Frege: 4 Technical Reasons why Data-Driven and Machine Learning NLU is a Myth](https://medium.com/@ontologik/the-unrelenting-ghosts-of-fodor-and-frege-4-technical-reasons-why-data-driven-and-machine-c2d02be144e9)
#
# * [(Almost) Automatic Programming: Recursion is a lot easier than you think](https://medium.com/@ontologik/almost-automatic-programming-recursion-is-a-lot-easier-than-you-think-49aa4efb6de)
#
# * [A Solution to the so-called Paradox of the Ravens](https://medium.com/@ontologik/a-solution-to-the-so-called-paradox-of-the-ravens-e257d051d0f0)
#
# * [Are NNs Just Fuzzy Hashtables? A Revealing Experiment on MNIST Data](https://medium.com/@ontologik)
#
# * [You Don't Really Need Another MOOC](https://eugeneyan.com/writing/you-dont-need-another-mooc/)
#
# * [Your Thinking Rate Is Fixed](https://fs.blog/2021/03/thinking-rate-fixed/)
#
# * [Zero to Hero (Machine Learning)](https://www.notes2tree.com/published_tree/?publish_tree=caiMJEsnCQ)
#
#
#
# * [Convolution](https://en.wikipedia.org/wiki/Convolution)
#
# * [Cross-correlation](https://en.wikipedia.org/wiki/Cross-correlation)
#
# * [Probabilistic Programming](https://simons.berkeley.edu/sites/default/files/docs/5675/talkprintversion.pdf)
#
# * [Basics statistics](http://www.mit.edu/~6.s085/notes/lecture1.pdf)
#
# * [Confidence intervals and hypothesis tests](http://www.mit.edu/~6.s085/notes/lecture2.pdf)
#
# * [Linear Regression](http://www.mit.edu/~6.s085/notes/lecture3.pdf)
#
# * [Regression Diagnostics and Advanced Regression Topics](http://www.mit.edu/~6.s085/notes/lecture4.pdf)
#
# * [Nonparametric statistics and model selection](http://www.mit.edu/~6.s085/notes/lecture5.pdf)
#
# * [Categorical data](http://www.mit.edu/~6.s085/notes/lecture6.pdf)
#
# * [Experimental Design](http://www.mit.edu/~6.s085/notes/lecture7.pdf)
#
# * [Dark Patterns at Scale: Findings from a Crawl of 11K Shopping Websites](https://webtransparency.cs.princeton.edu/dark-patterns/)
#
#
#
# * [Data-generating probability distribution, probability distribution of a dataset, in ML](https://datascience.stackexchange.com/questions/54346/data-generating-probability-distribution-probability-distribution-of-a-dataset)
#
#
#
# * [Declarative Graphing](https://srush.github.io/dex-lang/examples/plotting.html)
#
# * [Deep Learning: Our Miraculous Year 1990-1991](https://people.idsia.ch/~juergen/deep-learning-miraculous-year-1990-1991.html)
#
# * [ebhy/budgetml: Deploy a ML inference service on a budget in less than 10 lines of code.](https://github.com/ebhy/budgetml)
#
#
# * [Feature learning](https://en.wikipedia.org/wiki/Feature_learning)
#
#
# * [Gary Marcus -  What Nate Silver Gets Wrong](https://www.newyorker.com/books/page-turner/what-nate-silver-gets-wrong)
#
# * [Gaussian process](https://en.wikipedia.org/wiki/Gaussian_process)
#
# * [Generalized Language Models](https://lilianweng.github.io/lil-log/2019/01/31/generalized-language-models.html)
#
#
# * [graph - Generating statistics from Git repository - Stack Overflow](https://stackoverflow.com/questions/1828874/generating-statistics-from-git-repository)
#
# * [Graph theory, graph convolutional networks, knowledge graphs](https://albertazout.substack.com/p/gradient-ascent-10)
#
# * [Graphics processing unit](https://en.wikipedia.org/wiki/Graphics_processing_unit)
#
# * [Graphite - Architecture](https://www.aosabook.org/en/graphite.html)
#
# * [THE UNIVERSAL APPROXIMATION THEOREM FOR NEURAL NETWORKS](https://mcneela.github.io/machine_learning/2017/03/21/Universal-Approximation-Theorem.html)
#
# * [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
#
# * [Threat Modeling Manifesto](http://www.threatmodelingmanifesto.org/)
#
# * [Time series](https://en.wikipedia.org/wiki/Time_series#Models)
#
# * [Translating lost languages using machine learning](https://news.mit.edu/2020/
# translating-lost-languages-using-machine-learning-1021)
#
# * [Understanding Convolutional Neural Networks for NLP](http://www.wildml.com/2015/11/understanding-convolutional-neural-networks-for-nlp/)
#
# * [Understanding LSTM Networks](https://colah.github.io/posts/2015-08-Understanding-LSTMs/)
#
#
# * [Automated scientific research](https://www.youtube.com/watch?v=uLx0gyhVWDo)
#
# * [Nonparametric statistics](https://en.wikipedia.org/wiki/Nonparametric_statistics)
#
# * [Deep Learning: mathematics and neuroscience](http://cbmm.mit.edu/sites/default/files/publications/Deep%20Learning-%20mathematics%20and%20neuroscience.pdf)
#
# * [What are the connections between machine learning and signal processing?](https://www.quora.com/What-are-the-connections-between-machine-learning-and-signal-processing)
#
# * [The Genesis Enterprise: Taking Artificial Intelligence to another Level via a Computational Account of Human Story Understanding.pdf](https://dspace.mit.edu/bitstream/handle/1721.1/119651/CMHI-Report-1.pdf?sequence=1&isAllowed=y)
#
# * [Frontiers in Natural Language Processing Expert Responses](https://docs.google.com/document/d/18NoNdArdzDLJFQGBMVMsQ-iLOowP1XXDaSVRmYN0IyM/edit#)
#
# * [Statistic](https://en.wikipedia.org/wiki/Statistic)
#
#
#
# * [The Fibonacci Sequence as a Functor](https://www.math3ma.com/blog/fibonacci-sequence)
#
# * [Offline Reinforcement Learning:  From Algorithms to Practical Challenges](https://sites.google.com/view/offlinerltutorial-neurips2020/home)
#
# * [Free energy principle](https://en.wikipedia.org/wiki/Free_energy_principle)
#
# * [Markov blanket](https://en.wikipedia.org/wiki/Markov_blanket)
#
# * [Generative model](https://en.wikipedia.org/wiki/Generative_model)
#
# * [Discriminative model](https://en.wikipedia.org/wiki/Discriminative_model)
#
# * [Markov model](https://en.wikipedia.org/wiki/Markov_model)
#
# * [Markov Chains](https://brilliant.org/wiki/markov-chains/)
#
# * [Markov Model of Natural Language](https://www.cs.princeton.edu/courses/archive/spr05/cos126/assignments/markov.html)
# * [List of datasets for machine-learning research](https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning_research#Signal_data)
#
# * [Inductive bias](https://en.wikipedia.org/wiki/Inductive_bias)
#
# * [Abductive reasoning](https://en.wikipedia.org/wiki/Abductive_reasoning)
#
# * [Inductive reasoning](https://en.wikipedia.org/wiki/Inductive_reasoning)
#
# * [Deductive reasoning](https://en.wikipedia.org/wiki/Deductive_reasoning)
#
# * [Variational inference in Bayesian neural networks](http://krasserm.github.io/2019/03/14/bayesian-neural-networks/)
#
# * [Bayes by Backprop from scratch (NN, classification)](https://gluon.mxnet.io/chapter18_variational-methods-and-uncertainty/bayes-by-backprop.html)
#
# * [World Models Can agents learn inside of their own dreams?](https://worldmodels.github.io/)
#
# * [Andre Gelman -  Reflections on Breiman’s Two Cultures of Statistical Modeling](https://www.youtube.com/watch?v=10OV3mucmqc)
#
# * [GitHub - thunlp/PLMpapers: Must-read Papers on pre-trained language models.](https://github.com/thunlp/PLMpapers)
#
# * [Decoded: GNU coreutils](https://www.maizure.org/projects/decoded-gnu-coreutils/)
#
# * [How Difficult is your Programming Project?](https://www.maizure.org/projects/how-difficult-is-your-programming-project.html)
#
# * [I don't want to learn your garbage query language](https://erikbern.com/2018/08/30/i-dont-want-to-learn-your-garbage-query-language.html)
#
# * [Maximum likelihood estimation](https://en.wikipedia.org/wiki/Maximum_likelihood_estimation)
#
# * [Statistical Mistakes and How to Avoid Them](https://www.cs.cornell.edu/~asampson/blog/statsmistakes.html)
#
# * [The Control Group Is Out Of Control](https://slatestarcodex.com/2014/04/28/the-control-group-is-out-of-control/)
#
# * [The Control Group Is Out Of Control - HN](https://news.ycombinator.com/item?id=13025496)
#
# * [Road Map for Choosing Between Statistical Modeling and Machine Learning](https://www.fharrell.com/post/stat-ml/)
#
#
#
# * [Diffusion of innovations](https://en.wikipedia.org/wiki/Diffusion_of_innovations)
#
# * [Adaptive system](https://en.wikipedia.org/wiki/Adaptive_system)
#
# * [Co-occurrence](https://en.wikipedia.org/wiki/Co-occurrence)
#
# * [Distributional semantics](https://en.wikipedia.org/wiki/Distributional_semantics)
#
# * [Sparse distributed memory](https://en.wikipedia.org/wiki/Sparse_distributed_memory)
#
# * [Hamming distance](https://en.wikipedia.org/wiki/Hamming_distance)
#
# * [Information theory](https://en.wikipedia.org/wiki/Information_theory)
#
# * [Exponential distribution - Wikipedia](https://en.wikipedia.org/wiki/Exponential_distribution)
#
#
#
# * [Technical Perspective: Why Don't Today's Deep Nets Overfit to Their Training Data?](https://cacm.acm.org/magazines/2021/3/250716-technical-perspective-why-dont-todays-deep-nets-overfit-to-their-training-data/fulltext)
#
# * [Zooko's triangle](https://en.wikipedia.org/wiki/Zooko%27s_triangle)
#
#
#
# * [Never a dill moment: Exploiting machine learning pickle files](https://blog.trailofbits.com/2021/03/15/never-a-dill-moment-exploiting-machine-learning-pickle-files/)
#
# * [Density estimation](https://en.wikipedia.org/wiki/Density_estimation)
#
# * [A Recipe for Training Neural Networks](https://karpathy.github.io/2019/04/25/recipe/)
#
# * [* [Predictive Coding has been Unified with Backpropagation](https://www.lesswrong.com/posts/JZZENevaLzLLeC3zn/predictive-coding-has-been-unified-with-backpropagation)](https://wiki.c2.com/?HeroicProgramming)
#
# * [Language model](https://en.wikipedia.org/wiki/Language_model)

# %% [markdown]
# # Ingenieria

# %% [markdown]
# * [Breadboard](https://en.wikipedia.org/wiki/Breadboard)
#
# * [Active noise control](https://en.wikipedia.org/wiki/Active_noise_control)
#
# * [Control system](https://en.wikipedia.org/wiki/Control_system)
#
# * [My self-study plan for electrical engineering](https://i-kh.net/2021/03/20/electrical-engineering-study-plan/)
#
# * [Internal Combustion Engine](https://ciechanow.ski/internal-combustion-engine/)
#
# * [Reverse-engineering a vintage comparator chip](http://www.righto.com/2021/04/reverse-engineering-vintage-comparator.html)
#
# * [Digital Audio 101: Playing Audio From A Microcontroller](https://blog.tarkalabs.com/digital-audio-101-playing-audio-from-a-microcontroller-5df1463616c)
#
# * [Personal Fabrication -  MIT](https://hcie.csail.mit.edu/fabpub/)
#
# * [Personal Fabrication](https://www.edge.org/conversation/neil_gershenfeld-personal-fabrication)
#
# * [Continuous Integration - Architecture](https://www.aosabook.org/en/integration.html)
#
# * [Control system](https://en.wikipedia.org/wiki/Control_system)
#
# * [Signal processing is key to embedded Machine Learning](https://www.edgeimpulse.com/blog/dsp-key-embedded-ml)
#
# * [Signal Processing](https://en.wikipedia.org/wiki/Signal_processing)
#
# * [How is Signal Processing is related to Machine Learning? : learnmachinelearning](https://www.reddit.com/r/learnmachinelearning/comments/7p7a0o/how_is_signal_processing_is_related_to_machine/)
#
# * [Sonar](https://en.wikipedia.org/wiki/Sonar)
#
# * [Noise reduction](https://en.wikipedia.org/wiki/Noise_reduction)
#
#
# * [Why Electricity So Hard to Understand? A collection of  various ideas](http://amasci.com/miscon/whyhard2.html)
#
# * [Kalman filter](https://en.wikipedia.org/wiki/Kalman_filter)
#
# * [Kalman Filter (wikipedia.org) (HN)](https://news.ycombinator.com/item?id=26363347)
#
#
# * [Kullback–Leibler divergence](https://en.wikipedia.org/wiki/Kullback%E2%80%93Leibler_divergence)
#
# * [Fisher information](https://en.wikipedia.org/wiki/Fisher_information)

# %% [markdown]
# # Ciencia

# %% [markdown]
# - [Ising model](https://en.wikipedia.org/wiki/Ising_model)
#
# - [Phase transition](https://en.wikipedia.org/wiki/Phase_transition)
#
# - [Quantum mechanics](https://en.wikipedia.org/wiki/Quantum_mechanics)
#
# - [Quantum statistical mechanics](https://en.wikipedia.org/wiki/Quantum_statistical_mechanics)
#
# - [Recommended Data Repositories](https://www.nature.com/sdata/policies/repositories)
#
# - [Renormalization](https://en.wikipedia.org/wiki/Renormalization)
#
# - [The Crisis of Computational Neuroscience](https://sapienlabs.org/the-crisis-of-computational-neuroscience/)
#
# - [Toy model](https://en.wikipedia.org/wiki/Toy_model)

# %% [markdown]
# * [The Nature of Explanation](https://fs.blog/2013/05/the-nature-of-explanation/)
#
# * [Quantum gravity](https://en.wikipedia.org/wiki/Quantum_gravity)
#
# * [Kinematic Self-Replicating Machines](http://www.molecularassembler.com/KSRM.htm)
#
# * [This is your brain on code: Researchers decipher neural mechanics of computer programming](https://medicalxpress.com/news/2020-12-brain-code-decipher-neural-mechanics.html)
#
# * [Spacetime](https://en.wikipedia.org/wiki/Spacetime)
#
# * [	Ask HN: What under-the-radar technology are you excited about?](https://news.ycombinator.com/item?id=26780866)
#
# * [Every Theory Is Held Inside a Physical Substrate](https://nav.al/substrate)
#
# * [DNA digital data storage](https://en.m.wikipedia.org/wiki/DNA_digital_data_storage)
#
# * [Predator-Prey Relationships - The Lotka-Volterra Model](https://aubreymoore.github.io/ALBI345F17/pdfs/Lotka-Volterra-Model.html)
#
# * [Matplotlib: lotka volterra tutorial](https://scipy-cookbook.readthedocs.io/items/LoktaVolterraTutorial.html)
#
# * [Modelling biological systems](https://en.wikipedia.org/wiki/Modelling_biological_systems)
#
# * [Ion](https://es.wikipedia.org/wiki/Ion)
#
# * [Effective theory](https://en.wikipedia.org/wiki/Effective_theory)
#
# * [Entropy Explained, With Sheep](https://aatishb.com/entropy/)
#
# * [How to (seriously) read a scientific paper](https://www.sciencemag.org/careers/2016/03/how-seriously-read-scientific-paper)
#
# * [Mise en place](https://en.wikipedia.org/wiki/Mise_en_place)
#
# * [Polytely](https://en.wikipedia.org/wiki/Polytely)
#
# * [Morphogenesis](https://en.wikipedia.org/wiki/Morphogenesis)
#
# * [I should have loved biology](https://jsomers.net/i-should-have-loved-biology/)
#
# * [Molecular machine](https://en.wikipedia.org/wiki/Molecular_machine)
#
# * [Computational science](https://en.wikipedia.org/wiki/Computational_science)
#
# * (D) [15 pieces of advice I wish my PhD advisor had given me](http://0.0.0.0:8000/5%20Ciencia/Articulos/15%20pieces%20of%20advice%20I%20wish%20my%20PhD%20advisor%20had%20given%20me.pdf)
#
# * (D) [Gestalt principles (Part 1)](http://0.0.0.0:8000/5%20Ciencia/Articulos/Gestalt%20principles%20%28Part%201%29.pdf)
#
# * (D) [Gestalt principles (Part 2)](http://0.0.0.0:8000/5%20Ciencia/Articulos/Gestalt%20principles%20%28Part%202%29.pdf)
#
# * (D) [How To Choose a Good Scientific Problem](http://0.0.0.0:8000/5%20Ciencia/Articulos/How%20To%20Choose%20a%20Good%20Scientific%20Problem.pdf)
#
# * (D) [How to navigate a scientific paper with time constraints - A graphical approach](http://0.0.0.0:8000/5%20Ciencia/Articulos/How%20to%20navigate%20a%20scientific%20paper%20wit%20htime%20constraints%20-%20A%20graphical%20approach.pdf)
#
# * (D) [On the Process of Becoming a Great Scientist](http://0.0.0.0:8000/5%20Ciencia/Articulos/On%20the%20Process%20of%20Becoming%20a%20Great%20Scientist.pdf)
#
# * (D) [Ten Simple Rules for Doing Your Best Research, According to Hamming](http://0.0.0.0:8000/5%20Ciencia/Articulos/Ten%20Simple%20Rules%20for%20Doing%20Your%20Best%20Research%2C%20According%20to%20Hamming.PDF)
#
# * [List of unsolved problems in physics](https://en.wikipedia.org/wiki/List_of_unsolved_problems_in_physics)
#
# * [Fluid](https://en.wikipedia.org/wiki/Fluid)
#
# * [The Precision Of Sensory Evidence](https://astralcodexten.substack.com/p/the-precision-of-sensory-evidence)_
#
# * [Covariant Electrodynamics the Easy Way, Part I: Vector Triple Products in Minkowski Spacetime](https://michaelallenwarner.github.io/physics/2019/07/16/vector-triple-products-in-minkowski-spacetime.html)
#
# * [Covariant Electrodynamics the Easy Way, Part II: “Electrodyadics” (Tensors Lite)](https://michaelallenwarner.github.io/physics/2020/03/31/electrodyadics.html)

# %% [markdown]
# # Otros

# %% [markdown]
# -  [The Anatomy of Trading Breakouts](https://www.investopedia.com/articles/trading/08/trading-breakouts.asp)
#
# - [The Quant Project](https://quantgirl.blog/quant-project/)
#
# - [Ticker symbol](https://en.wikipedia.org/wiki/Ticker_symbol)
#
# - [Sense and reference](https://en.wikipedia.org/wiki/Sense_and_reference)
#
# - [Signal](https://en.wikipedia.org/wiki/Signal)
#
# - [Structure](https://en.wikipedia.org/wiki/Structure)
#
# - [Noun](https://en.wikipedia.org/wiki/Noun)
#
# - [On Denoting](https://en.wikipedia.org/wiki/On_Denoting)
#
# - [ON INDUCTION](http://www.ditext.com/russell/rus6.html)
#
# - [Philosophy of language](https://en.wikipedia.org/wiki/Philosophy_of_language)
#
# - [Philosophy of statistics](https://en.wikipedia.org/wiki/Philosophy_of_statistics)
#
# - [Philosophy of Statistics](https://plato.stanford.edu/entries/statistics/)
#
# - [Rate of return](https://en.wikipedia.org/wiki/Rate_of_return)
#
# - [Why Model?](http://jasss.soc.surrey.ac.uk/11/4/12.html)
#
# - [Nominal (linguistics)](https://en.wikipedia.org/wiki/Nominal_(linguistics))
#
# - [Naming and Necessity](https://en.wikipedia.org/wiki/Naming_and_Necessity)
#
# - [A Treatise Concerning the Principles of Human Knowledge](https://en.wikisource.org/wiki/A_Treatise_Concerning_the_Principles_of_Human_Knowledge)
#
# - [Abstract and concrete](https://en.wikipedia.org/wiki/Abstract_and_concrete)
#
# - [An Enquiry Concerning Human Understanding](https://en.wikisource.org/wiki/An_Enquiry_Concerning_Human_Understanding)
#
# - [Connotation](https://en.wikipedia.org/wiki/Connotation)
#
# - [Denotation](https://en.wikipedia.org/wiki/Denotation)
#
# - [Abraham Wald](https://en.wikipedia.org/wiki/Abraham_Wald)
#
# - [Exchange-traded fund](https://en.wikipedia.org/wiki/Exchange-traded_fund)
#
# - [Factor analysis](https://en.wikipedia.org/wiki/Factor_analysis)
#
# - [Fama–French three-factor model](https://en.wikipedia.org/wiki/Fama%E2%80%93French_three-factor_model)
#
# - [Financial market](https://en.wikipedia.org/wiki/Financial_market)
#
# - [Category:Financial models](https://en.wikipedia.org/wiki/Category:Financial_models)
#
# - [Glossary of economics](https://en.wikipedia.org/wiki/Glossary_of_economics)
#
# - [Glossary of probability and statistics](https://en.wikipedia.org/wiki/Glossary_of_probability_and_statistics)
#
# - [Imputation (statistics)](https://en.wikipedia.org/wiki/Imputation_%28statistics%29)
#
# - [Is Justified True Belief Knowledge?](http://www.ditext.com/gettier/gettier.html)
#
# - [Equity (finance)](https://en.wikipedia.org/wiki/Equity_(finance))
#
# - [Market (economics)](https://en.wikipedia.org/wiki/Market_(economics))
#
# - [Modality (natural language)](https://en.wikipedia.org/wiki/Modality_(natural_language))

# %% [markdown]
# * [Technical analysis](https://en.wikipedia.org/wiki/Technical_analysis)
#
# * [A Philosophical Notebook, by Nassim Nicholas Taleb](https://www.fooledbyrandomness.com/notebook.htm)
#
# * [Junker (Prussia)](https://en.wikipedia.org/wiki/Junker_(Prussia))
#
# * [Prussian Army](https://en.wikipedia.org/wiki/Prussian_Army)
#
# * [Git Submodules basic explanation](https://gist.github.com/gitaarik/8735255)
#
# * [Indicative planning](https://en.wikipedia.org/wiki/Indicative_planning)
#
# * [Intelligence amplification](https://en.wikipedia.org/wiki/Intelligence_amplification)
#
# * [Memex - Wikipedia](https://en.wikipedia.org/wiki/Memex)
#
# * [Peter Thiel’s Religion](https://perell.com/essay/peter-thiel/)
#
# * [Claude Shannon’s “Creative Thinking” Speech: A Genius Reveals How To Be Creative](https://medium.com/the-mission/a-genius-explains-how-to-be-creative-claude-shannons-long-lost-1952-speech-fbbcb2ebe07f)
#
# * [How to Think: The Skill You’ve Never Been Taught](https://fs.blog/2015/08/how-to-think/)
#
# * [Are some personalities just better?](https://dynomight.net/better-personalities/)
#
# * [The Wrong Abstraction](https://sandimetz.com/blog/2016/1/20/the-wrong-abstraction)
#
# * [Sapir-Whorf Hypothesis](http://zimmer.csufresno.edu/~johnca/spch100/4-9-sapir.htm)
#
# * [The 10 Best Practices for Remote Software Engineering](https://cacm.acm.org/opinion/articles/252174-the-10-best-practices-for-remote-software-engineering/fulltext)
#
# * [Beginner’s Guide to Mechanical Keyboards](https://coolgadget.substack.com/p/beginners-guide-to-mechanical-keyboards)
#
# * [A theory of how developers seek information](https://web.eecs.utk.edu/~azh/blog/informationforaging.html)
#
#
# * [How Should We Critique Research?](https://www.gwern.net/Research-criticism)
#
# * [Software infrastructure 2.0: a wishlist](https://erikbern.com/2021/04/19/software-infrastructure-2.0-a-wishlist.html)
#
# * [Ad Hoc](https://es.wikipedia.org/wiki/Ad_hoc)
#
# * [Abstraction](https://en.wikipedia.org/wiki/Abstraction)
#
# * [Humanistic intelligence](https://en.wikipedia.org/wiki/Humanistic_intelligence)
#
# * [Heuristic](https://en.wikipedia.org/wiki/Heuristic)
#
# * [Cognition](https://en.wikipedia.org/wiki/Cognition)
#
# * [Augmenting Long-term Memory](http://augmentingcognition.com/ltm.html)
#
# * [An Intuitive Explanation of Solomonoff Induction](https://www.lesswrong.com/posts/Kyc5dFDzBg4WccrbK/an-intuitive-explanation-of-solomonoff-induction)
#
# * [A Semitechnical Introductory Dialogue on Solomonoff Induction](https://www.lesswrong.com/posts/EL4HNa92Z95FKL9R2/a-semitechnical-introductory-dialogue-on-solomonoff-1)
#
# * [Conceptual model](https://en.wikipedia.org/wiki/Conceptual_model)
#
# * [Theory of mind](https://en.wikipedia.org/wiki/Theory_of_mind)
#
# * [Goals vs. Systems](https://www.scottadamssays.com/2013/11/18/goals-vs-systems/)
#
#
# * [Adding is favoured over subtracting in problem solving](https://www.nature.com/articles/d41586-021-00592-0)
#
# * [Design thinking](https://en.wikipedia.org/wiki/Design_thinking)
#
# * [How People Get Rich Now](http://paulgraham.com/richnow.html)
#
# * [Currency](https://en.wikipedia.org/wiki/Currency)
#
# * [Money](https://en.wikipedia.org/wiki/Money)
#
# * [Book Recommendations from Nassim Taleb](https://fs.blog/2012/02/book-recommendations-from-nassim-taleb/)
#
# * [Fluid dynamics](https://en.wikipedia.org/wiki/Fluid_dynamics)
#
# * [Adding is favoured over subtracting in problem solving](https://www.nature.com/articles/d41586-021-00592-0)
#
#
# * [Bean Machine](https://en.wikipedia.org/wiki/Bean_machine)
#
#
# * [Why Model?](http://jasss.soc.surrey.ac.uk/11/4/12.html)
#
# * [Living Things Are Not (20th Century) Machines: Updating Mechanism Metaphors in Light of the Modern Science of Machine Behavior](https://www.frontiersin.org/articles/10.3389/fevo.2021.650726/full)
#
#
# * [Don't End The Week With Nothing](https://training.kalzumeus.com/newsletters/archive/do-not-end-the-week-with-nothing)
#
# * [Politics](https://en.wikipedia.org/wiki/Politics)
#
# * [The Missing Semester of Your CS Education](https://missing.csail.mit.edu/2020)
#
# * [The Six Levels of Interaction with a System](https://www.charlieharrington.com/the-six-levels-of-interaction-with-a-system)
#
# * [Five Percent Better: The Compounding of Consistent Incremental Progress](https://fs.blog/2016/03/five-percent-better/)
#
# * [The Psychology of Design: 101 Cognitive Biases & Principles That Affect Your UX](https://growth.design/psychology/)
#
# * [Principles for better design](https://reflexio.debec.eu/principles-for-better-design)
#
# * [Ludic fallacy](https://en.wikipedia.org/wiki/Ludic_fallacy)
#
# * [Black swan theory](https://en.wikipedia.org/wiki/Black_swan_theory)
#
# * [Dragon king theory](https://en.wikipedia.org/wiki/Dragon_king_theory)
#
# * [Six Ways to Think Long-term: A Cognitive Toolkit for Good Ancestors](https://blog.longnow.org/02020/07/20/six-ways-to-think-long-term-a-cognitive-toolkit-for-good-ancestors/)
#
# * [Write a rapid prototype first](https://terrytao.wordpress.com/advice-on-writing-papers/write-a-rapid-prototype-first/)
#
# * [My strategy for wealth and personal finance](https://stopa.io/post/225)
#
# * [The SaaS Financial Model You’ll Actually Use (Updated 2020)](https://baremetrics.com/blog/saas-financial-model)
#
# * [The Cadence: How to Operate a SaaS Startup](https://medium.com/craft-ventures/the-cadence-how-to-operate-a-saas-startup-436aa8099e8)
#
# * [Gödel Incompleteness For Startups](https://skibinsky.com/godel-incompleteness-for-startups/)
#
# * [Myths about Patents and Trademarks in startups](https://hitstartup.com/myths-about-patents-and-trademarks-in-startups/)
#
# * [The Phsychology Behind TikTok's Addictive Feed](https://growth.design/case-studies/tiktok-feed-psychology/)
#
# * [Andrew Wilkinson & Tiny Capital Operating Manual](https://colinkeeley.com/blog/andrew-wilkinson-tiny-capital-operating-manual)
#
# * [How to hire smarter than the market: a toy model](https://erikbern.com/2020/01/13/how-to-hire-smarter-than-the-market-a-toy-model.html)
#
# * [How to build great products](https://www.defmacro.org/2013/09/26/products.html)
#
# * [When to Copy Ideas, When to Steal Ideas](https://davnicwil.com/when-to-copy-ideas-when-to-steal-ideas/)
#
# * [Team Improvement Techniques](http://www.dcaulfield.com/team-improvement-techniques/)
#
# * [Wasting Time Solving Not Important Problems](https://adamashwal.com/waste)
#
# * [Power law](https://en.wikipedia.org/wiki/Power_law)
#
# * [Six months of Tiny Projects](https://tinyprojects.dev/posts/six_months_of_tiny_projects)
#
# * [5 second feedback](https://critter.blog/2020/11/26/5-second-feedback/)
#
# * [Heuristic](https://en.wikipedia.org/wiki/Heuristic)
#
# * [Engineer](https://en.m.wikipedia.org/wiki/Engineer)
#
#
# * [The Anti-Mac Interface](https://www.nngroup.com/articles/anti-mac-interface/)
#
# * [The Personality Loop](https://neilkakkar.com/personality-loop.html)
#
# * [Law of Tech - Commoditize your Complement](https://www.gwern.net/Complement)
#
#
# * [A Simple and Dynamic Method for Consistent Productivity](https://matthewsaltz.wordpress.com/2020/11/24/a-simple-and-dynamic-method-for-consistent-productivity/)
#
# * (D) [Startup Guide](http://0.0.0.0:8000/6%20Otros/Articulos/Startup%20Guide.txt)
#
# * [My First Year as a Freelance AI Engineer](http://masatohagiwara.net/202002-my-first-year-as-a-freelance-ai-engineer.html)
#
# * [Double Entry Accounting for Developers](https://django-hordak.readthedocs.io/en/latest/accounting-for-developers.html)
#
# * (D)[The Skeptic and the Dogmatist.pdf](http://0.0.0.0:8000/6%20Otros/Articulos/The%20Skeptic%20and%20the%20Dogmatist.pdf)
#
# * [Wartime Innovation: Lessons From the Office of Scientific R&D](https://www.aaas.org/news/wartime-innovation-lessons-office-scientific-rd)
#
# * [Soft skills](https://es.wikipedia.org/wiki/Soft_skills)
#
# * [You probably don’t need A/B testing](https://oliverpalmer.com/blog/you-probably-dont-need-ab-testing)
#
# * [Case method](https://en.wikipedia.org/wiki/Case_method)
#
# * [Trapped Priors As A Basic Problem Of Rationality](https://astralcodexten.substack.com/p/trapped-priors-as-a-basic-problem)
#
#
#
# * [10,000 Hours With Claude Shannon: How A Genius Thinks, Works, and Lives](https://medium.com/the-mission/10-000-hours-with-claude-shannon-12-lessons-on-life-and-learning-from-a-genius-e8b9297bee8f)
#
# * [A Scientist’s Mind, a Poet’s Soul](https://www.thenewatlantis.com/publications/a-scientists-mind-a-poets-soul)
#
# * [Account (bookkeeping)](https://en.wikipedia.org/wiki/Account_(bookkeeping))
#
# * [Adoption and adaptation: A computational case study of the spread of Granovetter's weak ties hypothesis](https://www.sciencedirect.com/science/article/pii/S0378873321000010)
#
# * [Agency plus automation: Designing artificial intelligence into interactive systems](https://www.pnas.org/content/pnas/116/6/1844.full.pdf)
#
# * [All about thread-local storage | MaskRay](https://maskray.me/blog/2021-02-14-all-about-thread-local-storage)
#
# * [Alternative periodic tables](https://en.wikipedia.org/wiki/Alternative_periodic_tables)
#
# * [Ancient economic thought - Wikipedia](https://en.wikipedia.org/wiki/Ancient_economic_thought)
#
# * [Argument map](https://en.wikipedia.org/wiki/Argument_map)
#
# * [Ark Invest](https://en.wikipedia.org/wiki/Ark_Invest)
#
# * [Augmented reality](https://en.wikipedia.org/wiki/Augmented_reality)
#
# * [Business model - Wikipedia](https://en.wikipedia.org/wiki/Business_model)
#
# * [Capitalism](https://en.wikipedia.org/wiki/Capitalism)
#
# * [Book Review: Antifragile](https://astralcodexten.substack.com/p/book-review-antifragile)
#
# * [More Antifragile, Diversity Libertarianism, And Corporate Censorship](https://astralcodexten.substack.com/p/more-antifragile-diversity-libertarianism)
#
# * [Conceptual model - Wikipedia](https://en.wikipedia.org/wiki/Conceptual_model)
#
# * [Gaze heuristic](https://en.wikipedia.org/wiki/Gaze_heuristic)
#
# * [Gestalt psychology - Wikipedia](https://en.wikipedia.org/wiki/Gestalt_psychology)
#
# * [Galimatías](https://es.wikipedia.org/wiki/Galimat%C3%ADas#:~:text=Un%20galimat%C3%ADas%20es%20un%20t%C3%A9rmino,expresarse%20de%20una%20forma%20complicada.)
#
# * [Five whys - Wikipedia](https://en.wikipedia.org/wiki/Five_whys)
#
# * [Experience curve effects](https://en.wikipedia.org/wiki/Experience_curve_effects)
#
# * [‎Exponential View with Azeem Azhar: China’s Technology Transformation with Kai-Fu Lee on Apple Podcasts](https://podcasts.apple.com/us/podcast/chinas-technology-transformation-with-kai-fu-lee/id1172218725?i=1000501106358)
#
# * [Feedback](https://en.wikipedia.org/wiki/Feedback)
#
# * [Economies of scale](https://en.wikipedia.org/wiki/Economies_of_scale)
#
# * [El Farol Bar problem - Wikipedia](https://en.wikipedia.org/wiki/El_Farol_Bar_problem)
#
#
# * [Electoral system](https://en.wikipedia.org/wiki/Electoral_system)
#
# * [Dialectic](https://en.wikipedia.org/wiki/Dialectic)
#
# * [Diminishing returns](https://en.wikipedia.org/wiki/Diminishing_returns)
#
# * [Dixit–Stiglitz model](https://en.wikipedia.org/wiki/Dixit%E2%80%93Stiglitz_model)
#
# * [Cybernetics](https://en.wikipedia.org/wiki/Cybernetics)
#
# * [Cynefin framework](https://en.wikipedia.org/wiki/Cynefin_framework)
#
# * [Delphi method](https://en.wikipedia.org/wiki/Delphi_method)
#
# * [Barbell strategy](https://en.wikipedia.org/wiki/Barbell_strategy)
#
#
# * [Using Artificial Intelligence to Augment Human Intelligence](https://distill.pub/2017/aia/)
#
#
# * [What is Complexity Science?](https://complexityexplained.github.io/)
#
# * [History of economic thought](https://en.wikipedia.org/wiki/History_of_economic_thought)
#
# * [History of money](https://en.wikipedia.org/wiki/History_of_money)
#
# * [HN: How to Think Clearly?](https://news.ycombinator.com/item?id=24896237)
#
# * [Homoiconicity](https://en.wikipedia.org/wiki/Homoiconicity)
#
# * [Homophily](https://en.wikipedia.org/wiki/Homophily)
#
#
# * [Enterprise resource planning](https://en.wikipedia.org/wiki/Enterprise_resource_planning)
#
# * [Every mathematician has only a few tricks](https://mathoverflow.net/questions/363119/every-mathematician-has-only-a-few-tricks#:~:text=In%20Gian%2DCarlo%20Rota's%20%22Ten,use%20over%20and%20over%20again.)
#
#
#
#
# * [Double-entry bookkeeping](https://en.wikipedia.org/wiki/Double-entry_bookkeeping)
#
#
# * [Wicked problem](https://en.wikipedia.org/wiki/Wicked_problem)
#
#
# * [Decision support system - Wikipedia](https://en.wikipedia.org/wiki/Decision_support_system)
#
# * [Decision-making](https://en.wikipedia.org/wiki/Decision-making)
#
# * [Engine](https://en.wikipedia.org/wiki/Engine)
#
#
#
# * [Dining philosophers problem](https://en.wikipedia.org/wiki/Dining_philosophers_problem)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * [Getting started in Robotics | Arthur Allshire](https://allshire.org/getting-started-robotics/)
#
#
#
#
#
#
#
#
# * [How and why should we study ‘economic complexity’?](https://ourworldindata.org/how-and-why-econ-complexity)
#
# * [How can I develop a GUI for a C language program without GTK in Linux? - Quora](https://www.quora.com/How-can-I-develop-a-GUI-for-a-C-language-program-without-GTK-in-Linux)
#
# * [How I Build JavaScript Apps In 2021](https://timdaub.github.io/2021/01/16/web-principles/)
#
# * [How the Taxonomy of Products Drives the Economic Development of Countries](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0113770)
#
# * [How to Build an Open-Domain Question Answering System?](https://lilianweng.github.io/lil-log/2020/10/29/open-domain-question-answering.html)
#
# * [How to Build Good Software](https://www.csc.gov.sg/articles/how-to-build-good-software)
#
# * [How to Create a man Page on Linux](https://www.howtogeek.com/682871/how-to-create-a-man-page-on-linux/)
#
#
# * [How to fit an elephant](https://www.johndcook.com/blog/2011/06/21/how-to-fit-an-elephant/)
#
# * [How to lose money 💸 | Revue](https://www.getrevue.co/profile/andrewtye/issues/how-to-lose-money-323332)
#
# * [How to Read a Book: The Ultimate Guide by Mortimer Adler](https://fs.blog/how-to-read-a-book/)
#
# * [How to Read Assembly Language](https://wolchok.org/posts/how-to-read-assembly-language/)
#
# * [How to Start a Biotech Company on a Budget](https://blog.ycombinator.com/how-to-start-a-biotech-company-on-a-budget/)
#
# * [How to Understand ML Papers Quickly](https://blog.evjang.com/2021/01/understanding-ml.html)
#
# * [Implementing Data Replication in Memgraph](https://memgraph.com/blog/implementing-data-replication)
#
# * [In-Q-Tel](https://en.wikipedia.org/wiki/In-Q-Tel)
#
# * [Including Assembly code in a C program | One Step! Code](https://onestepcode.com/assembly-code-in-c/)
#
# * [Incremental search](https://en.wikipedia.org/wiki/Incremental_search)
#
# * [Inferential Models](https://www4.stat.ncsu.edu/~rmartin/martin_ipschool.pdf)
#
# * [Information bottleneck method](https://en.wikipedia.org/wiki/Information_bottleneck_method)
#
# * [Information processor](https://en.wikipedia.org/wiki/Information_processor)
#
# * [Inline caching](https://bernsteinbear.com/blog/inline-caching/)
#
# * [Intelligence, Complexity, and the Failed “Science” of IQ](https://seanamcclure.medium.com/intelligence-complexity-and-the-failed-science-of-iq-4fb17ce3f12)
#
# * [Interactive whiteboard](https://en.wikipedia.org/wiki/Interactive_whiteboard)
#
# * [Introduction](https://cs231n.github.io/optimization-2/)
#
# * [Introduction to Numba](https://nyu-cds.github.io/python-numba/05-cuda/)
#
# * [Inverse problem](https://en.wikipedia.org/wiki/Inverse_problem)
#
# * [Jailbreaking](https://en.wikipedia.org/wiki/IOS_jailbreaking)
#
#
#
# * [Jeremy Mikkola - How to write readable code](http://jeremymikkola.com/posts/2021_02_02_how_to_write_readable_code.html)
#
# * [Joukowsky transform](https://en.wikipedia.org/wiki/Joukowsky_transform)
#
# * [Judge–advisor system](https://en.wikipedia.org/wiki/Judge%E2%80%93advisor_system)
#
# * [Just-in-time learning](https://en.wikipedia.org/wiki/Just-in-time_learning)
#
# * [keyboard shortcuts - What are the most-used vim commands/keypresses? - Stack Overflow](https://stackoverflow.com/questions/5400806/what-are-the-most-used-vim-commands-keypresses/5400978#5400978)
#
# * [Language Models](http://veredshwartz.blogspot.com/2015/09/language-models.html)
#
# * [Lateral computing](https://en.wikipedia.org/wiki/Lateral_computing)
#
# * [Learning curve](https://en.wikipedia.org/wiki/Learning_curve)
#
#
# * [Lectio Divina](https://en.wikipedia.org/wiki/Lectio_Divina)
#
# * [Let's Not Dumb Down the History of Computer Science](https://cacm.acm.org/opinion/articles/250078-lets-not-dumb-down-the-history-of-computer-science/fulltext)
#
# * [Limits of statistics](https://www.johndcook.com/blog/2012/09/07/limits-of-statistics/)
#
# * [Linear Classification](https://cs231n.github.io/linear-classify/)
#
# * [Linear Map](https://en.wikipedia.org/wiki/Linear_map)
#
# * [Linear programming](https://en.wikipedia.org/wiki/Linear_programming)
#
# * [linux - How do I detach a process from Terminal, entirely? - Super User](https://superuser.com/questions/178587/how-do-i-detach-a-process-from-terminal-entirely)
#
# * [Linux Capabilities in a nutshell - K3A](https://k3a.me/linux-capabilities-in-a-nutshell/)
#
# * [Linux framebuffer - Wikipedia](https://en.wikipedia.org/wiki/Linux_framebuffer)
#
# * [Linux Tutorial](https://ryanstutorials.net/linuxtutorial/)
#
# * [List of build automation software](https://en.wikipedia.org/wiki/List_of_build_automation_software)
#
# * [List of cognitive biases](https://en.wikipedia.org/wiki/List_of_cognitive_biases)
#
# * [List of emerging technologies](https://en.wikipedia.org/wiki/List_of_emerging_technologies)
#
# * [List of forms of government](https://en.wikipedia.org/wiki/List_of_forms_of_government)
#
# * [List of genetic algorithm applications](https://en.wikipedia.org/wiki/List_of_genetic_algorithm_applications)
#
# * [List of stochastic processes topics - Wikipedia](https://en.wikipedia.org/wiki/List_of_stochastic_processes_topics)
#
# * [List of URI schemes - Wikipedia](https://en.wikipedia.org/wiki/List_of_URI_schemes)
#
# * [LLVM - Architecture](https://www.aosabook.org/en/llvm.html)
#
# * [Lorentz group](https://en.wikipedia.org/wiki/Lorentz_group)
#
# * [Low Earth Orbit Visualization](https://platform.leolabs.space/visualization)
#
# * [Machine learning](https://en.wikipedia.org/wiki/Machine_learning#Models)
#
# * [Mandate of Heaven](https://en.wikipedia.org/wiki/Mandate_of_Heaven)
#
# * [Markov chain](https://en.wikipedia.org/wiki/Markov_chain)
#
# * [Markov decision process](https://en.wikipedia.org/wiki/Markov_decision_process)
#
# * [Mathematical problem](https://en.wikipedia.org/wiki/Mathematical_problem)
#
# * [Mathematical statistics](https://en.wikipedia.org/wiki/Mathematical_statistics)
#
# * [Mathematics of Sudoku](https://en.wikipedia.org/wiki/Mathematics_of_Sudoku)
#
# * [matplotlib - Architecture](https://www.aosabook.org/en/matplotlib.html)
#
# * [Matrix](https://en.wikipedia.org/wiki/Matrix_(mathematics))
#
# * [meaning - Semantic difference between "engine" and "motor" - English Language & Usage Stack Exchange](https://english.stackexchange.com/questions/42027/semantic-difference-between-engine-and-motor)
#
# * [Memristor](https://en.wikipedia.org/wiki/Memristor)
#
# * [Meshtastic](https://meshtastic.letstalkthis.com/)
#
# * [Mitos y verdades de la complejidad económica](https://www.ciperchile.cl/2020/09/01/mitos-y-verdades-de-la-complejidad-economica/)
#
# * [ML Career Advice And Reading Papers](https://deeps.site/blog/2019/10/14/reading-research-papers-career-advice/)
#
# * [Modern Text Features in R](https://www.tidyverse.org/blog/2021/02/modern-text-features/)
#
# * [Modules, monoliths, and microservices](https://tailscale.com/blog/modules-monoliths-and-microservices/)
#
# * [Money](https://en.wikipedia.org/wiki/Money)
#
# * [Monoid](https://en.wikipedia.org/wiki/Monoid)
#
# * [Monolith First](https://news.ycombinator.com/item?id=26190584)
#
# * [MonolithFirst](https://martinfowler.com/bliki/MonolithFirst.html)
#
# * [Multimodal Neurons in Artificial Neural Networks](https://openai.com/blog/multimodal-neurons/)
#
# * [Musings on typicality](https://benanne.github.io/2020/09/01/typicality.html#right-level)
#
# * [MVC vs. OOP](https://www.yegor256.com/2016/12/13/mvc-vs-oop.html)
#
# * [My Ordinary Life: Improvements Since the 1990s · Gwern.net](https://www.gwern.net/Improvements)
#
# * [My Third Year as a Solo Developer · mtlynch.io](https://mtlynch.io/solo-developer-year-3/)
#
# * [Natural language processing](https://en.wikipedia.org/wiki/Natural_language_processing)
#
# * [Negative feedback](https://en.wikipedia.org/wiki/Negative_feedback)
#
# * [Neural Networks 1](https://cs231n.github.io/neural-networks-1/)
#
# * [Neural Networks Case Study](https://cs231n.github.io/neural-networks-case-study/)
#
# * [Neuroevolution](https://en.wikipedia.org/wiki/Neuroevolution#:~:text=Neuroevolution%2C%20or%20neuro%2Devolution%2C,game%20playing%20and%20evolutionary%20robotics.)
#
# * [new codebase, who dis? (How to Join a Team and Learn a Codebase)](https://www.samueltaylor.org/articles/how-to-learn-a-codebase.html)
#
# * [New metamaterial merges magnetic memory and physical changes](https://arstechnica.com/science/2021/01/new-metamaterial-merges-magnetic-memory-and-physical-changes/)
#
# * [nginx - Architecture](https://www.aosabook.org/en/nginx.html)
#
# * [Non-Fungible Tokens and ERC721 Tokens – A Simple Explanation](https://www.coingecko.com/buzz/non-fungible-tokens-and-erc721-tokens-a-simple-explanation)
#
# * [Nonlinear system](https://en.wikipedia.org/wiki/Nonlinear_system)
#
# * [Numerical control](https://en.wikipedia.org/wiki/Numerical_control)
#
# * [Oeconomicus](https://en.wikipedia.org/wiki/Oeconomicus)
#
# * [Optimization 1](https://cs231n.github.io/optimization-1/)
#
# * [Ora et labora](https://es.wikipedia.org/wiki/Ora_et_labora)
#
# * [Outline of thought](https://en.wikipedia.org/wiki/Outline_of_thought)
#
# * [Overview | Relay Computer](https://relaycomputer.co.uk/pages/overview.html)
#
# * [Parallel programming model](https://en.wikipedia.org/wiki/Parallel_programming_model)
#
# * [Parsing](https://en.wikipedia.org/wiki/Parsing)
#
# * [Pattern Matching in Python](https://github.com/gvanrossum/patma/blob/master/README.md#tutorial)
#
# * [Pattern recognition](https://en.wikipedia.org/wiki/Pattern_recognition)
#
# * [Patterns of Distributed Systems](https://martinfowler.com/articles/patterns-of-distributed-systems/)
#
# * [Pensamiento](https://es.wikipedia.org/wiki/Pensamiento)
#
# * [perf (Linux)](https://en.wikipedia.org/wiki/Perf_(Linux))
#
# * [Persistent data structure](https://en.wikipedia.org/wiki/Persistent_data_structure)
#
# * [Philosophy of physics](https://en.wikipedia.org/wiki/Philosophy_of_physics)
#
# * [Philosophy of science](https://en.wikipedia.org/wiki/Philosophy_of_science#Philosophy_of_statistics)
#
# * [Philosophy of statistics](https://en.wikipedia.org/wiki/Philosophy_of_statistics)
#
# * [Physical chemistry](https://en.wikipedia.org/wiki/Physical_chemistry)
#
# * [Pivotal discovery in quantum and classical information processing](https://www.anl.gov/article/pivotal-discovery-in-quantum-and-classical-information-processing)
#
# * [Plain Text Protocols](https://blainsmith.com/articles/plain-text-protocols/)
#
# * [Plane (geometry)](https://en.wikipedia.org/wiki/Plane_(geometry))
#
# * [Plane (geometry)](https://en.wikipedia.org/wiki/Plane_(geometry)#Representation)
#
# * [Plotnine: Grammar of Graphics for Python](https://datascienceworkshops.com/blog/plotnine-grammar-of-graphics-for-python/)
#
# * [Point estimation](https://en.wikipedia.org/wiki/Point_estimation)
#
# * [Political structure](https://en.wikipedia.org/wiki/Political_structure)
#
# * [Political system](https://en.wikipedia.org/wiki/Political_system)
#
# * [Polity](https://en.wikipedia.org/wiki/Polity)
#
# * [Positive feedback](https://en.wikipedia.org/wiki/Positive_feedback)
#
# * [POSIX Threads Programming](https://computing.llnl.gov/tutorials/pthreads/)
#
# * [Practical Color Theory for People Who Code](http://tallys.github.io/color-theory/)
#
# * [Predictive analytics](https://en.wikipedia.org/wiki/Predictive_analytics)
#
# * [Pricing strategies](https://en.wikipedia.org/wiki/Pricing_strategies)
#
# * [Printed circuit board](https://en.wikipedia.org/wiki/Printed_circuit_board)
#
# * [PyPy - Architecture](https://www.aosabook.org/en/pypy.html)
#
# * [Python Concurrency: The Tricky Bits](https://python.hamel.dev/concurrency/)
#
# * [Quantum electrodynamics](https://en.wikipedia.org/wiki/
# Quantum_electrodynamics)
#
# * [Reaction fingerprints, maps and classification](https://github.com/rxn4chemistry/rxnfp/tree/master/)
#
# * [Reactive programming](https://en.wikipedia.org/wiki/Reactive_programming)
#
# * [Realpolitik](https://en.wikipedia.org/wiki/Realpolitik)
#
# * [Report on Manufactures](https://en.wikipedia.org/wiki/Report_on_Manufactures)
#
# * [Representing and Editing JSON with Spreadsheets](https://medium.com/@donhopkins/representing-and-editing-json-with-spreadsheets-8f8832db5239)
#
# * [República](https://es.wikipedia.org/wiki/Rep%C3%BAblica)
#
# * [Requests for Research](https://ruder.io/requests-for-research/)
#
# * [Rethinking ML Papers - ICLR 2021 Workshop](https://rethinkingmlpapers.github.io/)
#
# * [Retiring Economic Growth. Think about our economy in terms of… | by Cesar A. Hidalgo](https://medium.com/@cesifoti/retiring-economic-growth-9057965cb2d5)
#
# * [Returns to scale](https://en.wikipedia.org/wiki/Returns_to_scale)
#
# * [Reversible computing](https://en.wikipedia.org/wiki/Reversible_computing)
#
# * [Rope (data structure)](https://en.wikipedia.org/wiki/Rope_(data_structure))
#
# * [Scalable Extensibility via Nested Inheritance](https://people.seas.harvard.edu/~chong/pubs/oopsla04.pdf)
#
# * [Science](https://en.wikipedia.org/wiki/Science)
#
# * [Scientific law](https://en.wikipedia.org/wiki/Scientific_law)
#
# * [Scientific modelling](https://en.wikipedia.org/wiki/Scientific_modelling)
#
# * [Semantic Versioning Will Not Save You](https://hynek.me/articles/semver-will-not-save-you/)
#
# * [Sequencing your DNA with a USB dongle and open source code - Stack Overflow Blog](https://stackoverflow.blog/2021/02/03/sequencing-your-dna-with-a-usb-dongle-and-open-source-code/)
#
# * [Servomotor](https://en.wikipedia.org/wiki/Servomotor)
#
# * [Setting up the data and the model](https://cs231n.github.io/neural-networks-2/)
#
# * [Shebang (Unix)](https://en.wikipedia.org/wiki/Shebang_(Unix))
#
# * [Simple Stock Market Models with Python](https://www.lucaspauker.ml/articles/simple-stock-market-models-with-python#like)
#
# * [Simpson's paradox](https://en.wikipedia.org/wiki/Simpson%27s_paradox)
#
# * [Simulated annealing](https://en.wikipedia.org/wiki/Simulated_annealing)
#
# * [Sistema Contable](https://es.wikipedia.org/wiki/Sistema_contable)
#
# * [Sovereignty](https://en.wikipedia.org/wiki/Sovereignty)
#
# * [SQLAlchemy - Architecture](https://www.aosabook.org/en/sqlalchemy.html)
#
# * [Stanford Seminar - Stephan Wolfram of Wolfram Research](https://en.wikipedia.org/wiki/Semiring)
#
# * [State-of-the-Art Image Generative Models](https://arankomatsuzaki.wordpress.com/2021/03/04/state-of-the-art-image-generative-models/)
#
#
#
# * [Static dispatch](https://en.wikipedia.org/wiki/Static_dispatch)
#
# * [Statistical model](https://en.wikipedia.org/wiki/Statistical_model)
#
# * [Statistical+Concepts+Explained+in+Simple+English+Part](https://www.datasciencecentral.com/page/search?q=Statistical+Concepts+Explained+in+Simple+English+Part)
#
# * [Steam engine](https://en.wikipedia.org/wiki/Steam_engine)
#
# * [String metric](https://en.wikipedia.org/wiki/String_metric)
#
# * [Study reveals immune driver of brain aging | News Center | Stanford Medicine](https://med.stanford.edu/news/all-news/2021/01/study-reveals-immune-driver-of-brain-aging.html)
#
# * [Suggestions on implementing an efficient instruction set simulator in LuaJIT2](http://lua-users.org/lists/lua-l/2011-02/msg00742.html)
#
# * [Systemantics](https://en.wikipedia.org/wiki/Systemantics)
#
# * [Systems theory in political science](https://en.wikipedia.org/wiki/Systems_theory_in_political_science)
#
# * [Tag cloud](https://en.wikipedia.org/wiki/Tag_cloud#:~:text=A%20tag%20cloud%20(word%20cloud,with%20font%20size%20or%20color.)
#
# * [Technological stagnation Why I came around](https://rootsofprogress.org/technological-stagnation)
#
# * [Teleology](https://en.wikipedia.org/wiki/Teleology)
#
# * [Ten computer codes that transformed science](https://www.nature.com/articles/d41586-021-00075-2)
#
# * [Ten Rules for Good Code - Hintjens.com](http://hintjens.com/blog:96)
#
# * [Tensor Processing Unit](https://en.wikipedia.org/wiki/Tensor_Processing_Unit)
#
# * [The 4 Biggest Open Problems in NLP](https://ruder.io/4-biggest-open-problems-in-nlp/)
#
# * [The 50 Most Important Economic Theories](https://dmarron.com/2009/08/17/the-50-most-important-economic-theories/)
#
# * [The architecture of my life](https://blog.nntn.nl/architecture-of-my-life-2021)
#
# * [The Art of Reading More Effectively and Efficiently](https://aliabdaal.com/read-more-effectively/)
#
# * [The Bourne-Again Shell - Architecture](https://www.aosabook.org/en/bash.html)
#
# * [The Computer Revolution Hasn't Happened Yet](https://catonmat.net/videos/the-computer-revolution-hasnt-happened-yet)
#
# * [The Database Inside Your Codebase](https://feifan.blog/posts/the-database-inside-your-codebase)
#
# * [The Definitive Glossary of Higher Mathematical Jargon](https://mathvault.ca/math-glossary/#structure)
#
# * [The Hadoop Distributed File System - Architecture](https://www.aosabook.org/en/hdfs.html)
#
# * [The High Price of Mistrust](https://fs.blog/2021/01/mistrust/)
#
# * [The Illustrated Transformer](http://jalammar.github.io/illustrated-transformer/)
#
# * [The Lucene Full-Text Search Engine](https://sites.fas.harvard.edu/~cs165/notes/lucene-notes.pdf)
#
# * [The Microwave Economy](https://perell.com/essay/the-microwave-economy/)
#
# * [The Nested Chinese Restaurant Process and Bayesian Nonparametric Inference of Topic Hierarchies](https://cocosci.princeton.edu/tom/papers/ncrp.pdf)
#
# * [The PGM-index](https://pgm.di.unipi.it/)
#
# * [The Pros and Cons of DRY Code](https://qvault.io/2021/01/25/the-pros-and-cons-of-dry-code/)
#
# * [The Spies Who Launched America’s Industrial Revolution](https://www.history.com/news/industrial-revolution-spies-europe)
#
# * [The Tyranny of Stuctureless](https://www.jofreeman.com/joreen/tyranny.htm)
#
# * [Thought](https://en.wikipedia.org/wiki/Thought)
#
#
#
# * [Translational symmetry](https://en.wikipedia.org/wiki/Translational_symmetry)
#
# * [Trie](https://en.wikipedia.org/wiki/Trie)
#
# * [TrueSkill -  Computing Your Skill](http://www.moserware.com/2010/03/computing-your-skill.html)
#
# * [Tutorial - Write a Shell in C • Stephen Brennan](https://brennan.io/2015/01/16/write-a-shell-in-c/)
#
# * [Ugly duckling theorem](https://en.wikipedia.org/wiki/Ugly_duckling_theorem)
#
# * [Under the Hood — The Computational Engine of Economic Development | by Cesar A. Hidalgo | Medium](https://medium.com/@cesifoti/under-the-hood-the-computational-engine-of-economic-development-49bce1a7b151#.l0we5aiy1)
#
# * [Underactuation](https://en.wikipedia.org/wiki/Underactuation)
#
#
#
# * [UNDERSTANDING IS A POOR SUBSTITUTE FOR CONVEXITY (ANTIFRAGILITY)](https://www.edge.org/conversation/nassim_nicholas_taleb-understanding-is-a-poor-substitute-for-convexity-antifragility)
#
#
#
# * [Uniform Resource Identifier](https://en.wikipedia.org/wiki/Uniform_Resource_Identifier)
#
#
#
#
# * [What can startups learn from Koch Industries?](https://erikbern.com/2019/12/19/what-can-startups-learn-from-koch-industries.html)
#
# * [What data on myself I collect and why? | beepb00p](https://beepb00p.xyz/my-data.html#what)
#
# * [What does it mean for the training data to be generated by a probability distribution over datasets](https://stats.stackexchange.com/questions/320375/what-does-it-mean-for-the-training-data-to-be-generated-by-a-probability-distrib)
#
#
# * [What Is the Difference between Bluetooth Receiver & Bluetooth Transmit – LAYEN](https://layen-uk.com/blogs/layen-blog/what-is-the-difference-between-bluetooth-receiver-bluetooth-transmitter)
#
# * [What is the difference between docker and docker-compose](https://stackoverflow.com/questions/37966552/what-is-the-difference-between-docker-and-docker-compose)
#
# * [What more is needed for Democratically Accountable Modelling?](http://cfpm.org/discussionpapers/254/dam)
#
# * [What You Don't Know About Non Fungible Tokens (NFTs) and Decentralized Finance (DeFi)](https://hackernoon.com/what-you-dont-know-about-non-fungible-tokens-nfts-and-decentralized-finance-defi-bq5g3zpa)
#
# * [Why I Built Litestream - Litestream](https://litestream.io/blog/why-i-built-litestream/)
# * [Why study linear algebra?](https://math.stackexchange.com/questions/256682/why-study-linear-algebra)
#
#
# * [The Emergence of Inequality (Scoot Page)](https://sites.google.com/view/scottepagestructuralinequality/home)
#
#
# * [The Robot Overlord Manual](https://marksaroufim.medium.com/the-robot-overlord-manual-d4ee709155bc)
#
# * [Animated Engines - Home](http://animatedengines.com/)
#
# * [The Entrepreneurial State: The case of the iPhone (II)](https://nintil.com/mazzucato-and-the-iphone-ii-the-myth-of-the-entrepreneurial-state)
#
#
# * [Information](https://en.wikipedia.org/wiki/Information)
#
#
# * [Ecosystem](https://en.wikipedia.org/wiki/Ecosystem)
#
#
# * [Common data model mistakes made by startups](https://www.metabase.com/learn/data-diet/analytics/data-model-mistakes.html)

# %% [markdown]
# ### Economy

# %% [markdown]
# * [Currency](https://en.wikipedia.org/wiki/Currency)
#
# * [Money](https://en.wikipedia.org/wiki/Money)
#
# * [¿Qué hacer para crecer más y mejor?](https://www.elfinancierocr.com/opinion/que-hacer-para-crecer-mas-y-mejor/LBEM532SFVGKDJXBA6ZM4MZ3K4/story/)
#
# * [Arrow's impossibility theorem](https://en.wikipedia.org/wiki/Arrow%27s_impossibility_theorem)
#
# * [What are the returns to R&D?](https://mattsclancy.substack.com/p/what-are-the-returns-to-r-and-d?token=eyJ1c2VyX2lkIjoyNTAyNTg4NSwicG9zdF9pZCI6MzYzMTQ4OTMsIl8iOiJxVkdOUiIsImlhdCI6MTYyMDkzODc1NSwiZXhwIjoxNjIwOTQyMzU1LCJpc3MiOiJwdWItMjI1NzQiLCJzdWIiOiJwb3N0LXJlYWN0aW9uIn0.lZqvEYTj_BTrFrKoYPq8QPjI7td7CsGf6xmparVS1cU)
#
# * [American School (economics)](https://en.wikipedia.org/wiki/American_School_(economics))
#
# * [Market (economics)](https://en.wikipedia.org/wiki/Market_(economics))
#
# * [Your Book Review: The Accidental Superpower](https://astralcodexten.substack.com/p/your-book-review-the-accidental-superpower?token=eyJ1c2VyX2lkIjoyNTAyNTg4NSwicG9zdF9pZCI6MzY3MDEyNzgsIl8iOiJDUEN4ciIsImlhdCI6MTYyMTc4MjQwNSwiZXhwIjoxNjIxNzg2MDA1LCJpc3MiOiJwdWItODkxMjAiLCJzdWIiOiJwb3N0LXJlYWN0aW9uIn0.qGpZo7UftF8n-hv17xwR4sLpsVLbFP1MK-xCmliOero)
#
# * [Bitcoin Transaction Network](https://graphs4sci.substack.com/p/bitcoin-transaction-network)
#
# * [An example of high returns to publicly funded R&D](https://mattsclancy.substack.com/p/an-example-of-high-returns-to-publicly?token=eyJ1c2VyX2lkIjoyNTAyNTg4NSwicG9zdF9pZCI6MzY2NjkyNDcsIl8iOiJDUEN4ciIsImlhdCI6MTYyMTc4MjQzNiwiZXhwIjoxNjIxNzg2MDM2LCJpc3MiOiJwdWItMjI1NzQiLCJzdWIiOiJwb3N0LXJlYWN0aW9uIn0.GbZDiMWWyjFL1XynJOx6NcELJSKbHoqzaZueuKSdec8)
#
# * []()

# %% [markdown]
# # Notebooks

# %% [markdown]
# * [Notebooks of the week: Hidden Gems - Vol. 45](https://www.kaggle.com/general/226469)

# %% [markdown]
# Script for Some Interactivity if it gets converter to html
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/mousetrap/1.6.5/mousetrap.min.js" integrity="sha512-+Jg3Ynmj9hse704K48H6rBBI3jdNBjReRGBCxUWFfOz3yVurnJFWtAWssDAsGtzWYw89xFWPxShuj2T6E9EOpg==" crossorigin="anonymous"></script>
#
# <script>
#
# var items = Array.from(document.querySelectorAll("li"))
#
# items.forEach(function(a, index){
#     a.setAttribute("tabindex", index)
# })
#
# // Help
# Mousetrap.bind('?', function() { alert('Todo write the help of this.') });
#
# // Focus some random thing.
# Mousetrap.bind('r', function() {
#   var item = items[Math.floor(Math.random()*items.length)];
#   item.focus()
# });
#
# </script>
