# %% [markdown]
# ## Information Theory
#
# - Concepts

# %% [markdown]
# ### Cursos

# %% [markdown]
# - [The Science of Information: From Language to Black Holes](https://www.thegreatcoursesplus.com/the-science-of-information-from-language-to-black-holes)
#
# - [Information Theory, Pattern Recognition, and Neural Networks](https://www.youtube.com/playlist?list=PLruBu5BI5n4aFpG32iMbdWoRVAA-Vcso6)
#
# * [Introduction to Information Theory](https://www.complexityexplorer.org/courses/55-introduction-to-information-theory)
#
# * [Information Theory](https://www.coursera.org/learn/information-theory)

# %% [markdown]
# ### Docs

# %% [markdown]
# - [Use Shannong Entropy Outside Computer Science and Eng](http://www.dp-pmi.org/uploads/3/8/1/3/3813936/6._figueiredo_2016.pdf)
#
# * [A brief introduction to the beauty of Information Theory](https://notamonadtutorial.com/a-brief-introduction-to-the-beauty-of-information-theory-8357f5b6a355)
#
# * [Information Theory, Inference, and Learning Algorithms](https://colab.research.google.com/github/dbremont/Notas/blob/main/Libros/Aprendisaje%20Automatico/Information%20Theory%2C%20Inference%2C%20and%20Learning%20Algorithms.ipynb#scrollTo=qDgWHoj59rhS)

# %% [markdown]
# ### Code

# %% [markdown]
# - [Kanerva Machine  - Implementation](https://github.com/Kajiyu/kanerva_machine)

# %% [markdown]
# ## Applications

# %% [markdown]
# - Data compression.
#   - Compress
#   - Discompres
#
# - Transmit, extract, utilize information.
#
# - Seismic exploration, using information theory and digital signal processing.
#
# - Thermodynamics
