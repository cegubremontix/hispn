# %% [markdown]
# - [Information Theory](https://en.wikipedia.org/wiki/Information_theory)
#
# - [Information](https://en.wikipedia.org/wiki/Information)

# %% [markdown]
# - Information is not meaning, value of significance.
# - Distinction between different messages.
#
# - Information is the abilty to distinguise reliablty between possibilies.
# - Baudot code
# - Unicode 16 bits code.
# - "It from bit".
# - Information process.
# - Connection between problems.
# - Information is all about the distinction between possible messages.
# - Etimology of the word information.
# -
