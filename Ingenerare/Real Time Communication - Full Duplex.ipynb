# %% [markdown]
# ## Be Active
#
# - Distributed Arithmetic Solver:
#    - Server
#    - Match
#    - Clientes
#
#    - Send problems to each client
#    - Client send solutions
#    - At the end of the match, when the time is over
#    - Winner, game analytics

# %% [markdown]
# - https://stackoverflow.com/questions/26003756/is-there-a-limit-practical-or-otherwise-to-the-number-of-web-sockets-a-page-op
#
# - https://dotnet.microsoft.com/apps/aspnet/signalr
#
# - https://developer.mozilla.org/en-US/docs/Web/API/WebSockets_API
#
# - https://stackoverflow.blog/2019/12/18/websockets-for-fun-and-profit/
#
# - https://stackoverflow.com/questions/11140164/signalr-console-app-example
