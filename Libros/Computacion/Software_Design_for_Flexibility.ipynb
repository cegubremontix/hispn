# %% [markdown]
# # Software Design for Flexibility
#
# How to Avoid Programming Yourself into a Corner
#
# [Why Programming Is a  Good Medium for Expressing Poorly-Undertood and Sloppily-Formulated Ideas](https://web.media.mit.edu/~minsky/papers/Why%20programming%20is--.html)
#
# [Architecting the Systems of the Future: A Research Agenda](https://www.youtube.com/watch?v=jmqdt1Tbtuc&t=7s)

# %% [markdown]
# Imaginemos que tenemos un programa, y queremos cambiar : remover/agregar.
# - ¿Por que algunas diseñós nos permiten hcer nuestro trabajo mas facil?
#
# - Espacio Vectorial del Problema:
#   - **Dificultad(Cambio) : Diseño + Cambio**
#   - Flexibilidad(Diseño, Cambios)
#   - Flexibilidad(Diseño)
#
# Closure vs Object:
# - Bundle curated data + functions
# - Closure: Functional Programming
# - Object: Object Oriented Programming
#
# This book is not a survey, or a tutorial, it is a master class. In each chapter, watch the two experts demostrate an advance technique by incrementally developing a chunk of working code, explaining the strategy as they go, occasionally pausing to point out a pitfall or to remove a limitation.

# %% [markdown]
# How to design an adaptable software system?
#
# What is an adaptable software system and What makes it adaptable?
#
# How to design system that requires only additions in order to be adapted?
# - Annotations
# - Hooks
#
# We can take inspiration from biological systems about how to make an evolvable and adaptable system?
#
# ¿Cómo nos "programamos" contra la esquina?
# - Programming yourself into a corner.
#
# ["Adaptable" vs. "flexible"](https://english.stackexchange.com/questions/63463/adaptable-vs-flexible)

# %% [markdown]
# ## Adaptability in Nature and in Design
#
# - We explore the idea of **adaptability** in nature and engineering.
#
# - Argument that **adaptability** is as important as **correctness** and **efficiency**.

# %% [markdown]
# problem domain languages
#
# information processing machine
#
# additive programming
#
# postel's law
#
# generic dispatch
#
# partial information
#
# degenerary
#
# Architecture of computation
#
# parti
#
# Smart parts for flexibility
#
# body plans
#
# combinator
#
# Redundancy and degeneracy
#
# redundant
#
# degenerate
#
# Exploratory behavior
#
# The cost of flexibility
#
# The problem with correctness

# %% [markdown]
# ## Domain-Specific Languages
#
# - Explore domain-specific languages as a way to building adaptable sytems.
# - A system as a collection of domain specific languages as a way to building each sub-system.
# - We show that sub-systems can be organized around mix-and-match parts, how they can be *flexible combined* with **combinators**,  and how **wrappers** can be used to generalized parts.

# %% [markdown]
# domain-specific language
#
# combinators
#
# function combinators
#
# arity
#
# Arity repair
#
# Arity extension
#
# combinator language
#
# Multiple values
#
# A quickie
#
# A small library
#
# Combinators and body plans
#
# As compositions?
#
# Useful combinators
#
# Regular expressions
#
# A Regular expression combinator language
#
# Implementation of the translator
#
# The moral of this story
#
# Adding * and + to regular expressions
#
# A bug, one bad joke, two tweaks, and a revelation
#
# Too much nesting
#
# Back-references
#
# Standards?
#
# Wrappers
#
# Specialization wrappers
#
# Implementing specializers
#
# Adapters
#
# Implementing unit conversions
#
# Abstracting a domain
#
# A monolithic implementation
#
# A checkers domain model
#
# A checkers referee
#
# Critique
#
# Factoring out the domain
#
# A domain model
#
# An executive
#
# evolution rule
#
# aggregate rule
#
# Critique
#
# A bit of chess
#
# More chess
#
# An advanced project

# %% [markdown]
# ## Variations on a Arithmetic Theme
#
# - We explore the technique of **generic procedures**
# - We show that generalization can be made efficient by using type tags for data
#
# Projects:
# - Generalizing Arithmetic to deal with symbolic algebraic expressions.

# %% [markdown]
# generic procedures
#
# combining arithmetics
#
# A simple ODE integrator
#
# Modulating arithemtic  operators
#
# arithmetic package
#
# problems with redifinign operators
#
# combining arithmetic
#
# An improved arithmetic abstraction
#
# Arithmetic on functions
#
# Problems with combinators
#
# Warmup with boolean arithmetic
#
# Vector arithmetic
#
# Ordering of extentions
#
# Extensible generic procedures
#
# Generic arithmetic
#
# Construction depends on order!
#
# Implementing generic procedures
#
# Making constructors for generic procedures
#
# Adding handlers to generic procedures
#
# The power of extensible generics
#
# Functional values
#
# A weird bug
#
# Matrices
#
# Literal vectors and matrices
#
# Example: Automatic differentiation
#
# How to automatic differentiation works
#
# Extending the primitives
#
# Extracting the derivative's value
#
# Derivative of n-ary functions
#
# Partial  derivatives
#
# Adding handlers
#
# Vectors and covectors
#
# Some technical details
#
# Differential algebra
#
# Finite and infinitesimal parts
#
# How extracting really works
#
# The bug!
#
# Literal functions of differential arguments
#
# Efficient generic procedures
#
# Tries
#
# Trie rules
#
# Caching
#
# Cache performace
#
# Efficient user-defined types
#
# Predicates as types
#
# Relationships between  predicates
#
# Predicates are dispatch keys
#
# Example: An adventure game
#
# The game
#
# The object types
#
# The genetic procedures
#
# Implementing properties
#
#
#
# Exercise Adventure warmup
#
# Exercise Health
#
# Exercise Medical help
#
# Exercise A palantir
#
# Exercise Indivisible
#
# Exercise Your turn
#
# Multiple Player

# %% [markdown]
# ## Patern Matching
#
# - We show how to generalize patttern matching

# %% [markdown]
# AVOID

# %% [markdown]
# ## Evaluation
#
# - We explore interpretation
# - We explore compilation
# - We explore the idea of continuation

# %% [markdown]
# interpreter
#
# call/cc
#
# generic eval/apply interpreter
#
# operator
#
# operands
#
# formal parameters
#
# special forms
#
# eval
#
# abstract syntax tree
#
# tagged list
#
# Derived expression types
#
# Effects
#
# apply
#
# Driver loop
#
# n-ary procedures
#
# Vectors of procedures
#
# Your  turn
#
# Interoperation with the underlying system
#
# Different quotation
#
# Infix notation
#
# Procedures with non-strict arguments
#
# Implementing generalized formal parameters
#
# Lazy pairs and lists
#
# Integrating differential equations
#
# Why not kons?
#
# Retricted parameters
#
# n-ary procedures, again!
#
# Compiling to execution procedures
#
# Analysis of expresions
#
# Application of procedures
#
# Implementing n-ary procedures
#
# Simplifying debugging
#
# Constant folding
#
# Other optimizations
#
# Compiling formal-parameter declarations
#
# Exploratory behavior
#
# Linguistically implicy search
#
# amb
#
# Implementing amb
#
# A puzzle
#
# Failure detection
#
# Choise ordering
#
# Exposing the underlying continuations
#
# Underlying continuations
#
# Continuations as nonlocal exits
#
# Nonlocal exits
#
# Nonlocal transfer of control
#
# From continuation to amb
#
# Other ways tro try alternatives
#
# Breadth versus depth
#
# Less deterministic nondeterminism
#
# Nesting strategies
#
# Undoable assigment
#
# Search control in the embedded system
#
# Power and responsability

# %% [markdown]
# ## Layering
#
# We explore the idea of layering(annotating) data and procedures with metadata to increase the adaptability of the system by procesing the metadata.

# %% [markdown]
# parti
#
# layered programming
#
# Using layers
#
# Implementing of layering
#
# Layered data
#
# Layered procedures
#
# Layered arithmetic
#
# Unit arithmetic
#
# Representation of unit specifications
#
# Unit arithmetic operations
#
# Derived units
#
# Annotation values with dependencies
#
# The support layer
#
# Procedural responsability
#
# Paranoid programming
#
# IDE for layered program
#
# Carraying justifications
#
# Justifications
#
# The promise of layering
#
# Dependencies mitigate inconsistency
#
# Restrictions on the use of data

# %% [markdown]
# ## Propagation
#
# This ia a [Model of Computation](https://en.wikipedia.org/wiki/Model_of_computation)
#
# We explore the idea of propagation to escape from expression-oriented paradigm of computer languages.
#
# We explore the idea of computation with multiple partial sources of information.

# %% [markdown]
# Escaping the Von Neumann straitjacket
#
# propagator
#
# Filling in details
#
# Dependencies and backtracking
#
# Degeneracy, redundancy, and parallelism
#
# An example: Distances to stars
#
# Magnitudes
#
# Making writing propagator networks easier
#
# An electrical design problem
#
# Local consistency -- a project
#
# The propagation mechanism
#
# scheduler
#
# propagators
#
# neighboards
#
# cells
#
# contraction object
#
# Multiple alternative world views
#
# Merging values
#
# Merging base values
#
# Merging supported values
#
# Merging value sets
#
# Merging with unification
#
# Searching possibe worlds
#
# An example: Pythagorean triples
#
# Dependency-directed backtracking
#
# Hypotheticals are made adn controlled by binary-amb
#
# Learning contradictions
#
# Resolving the contradiction
#
# Contradictions discovered in a cell
#
# Non-binary amb
#
# Solving combinatorial puzzles
#
# Yatch name puzzle
#
# Multiple-dwelling puzzle
#
# Card game puzzle reviseted
#
# Type inference
#
# A moral of this story
#
# Progration enables degeneracy
