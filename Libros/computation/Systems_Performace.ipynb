# %% [markdown]
# <a href="https://colab.research.google.com/github/dbremont/Notas/blob/main/Libros/Computacion/Systems_Performace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# System Performace

# %% [markdown]
# ## Introduction

# %% [markdown]
# Systems are complex
#
# Latency
#
# Dynamic tracing
#
# Cloud Computing
#
# Slow Disks
#
# Software Change

# %% [markdown]
# ## Methodology

# %% [markdown]
# IOPS
#
# Throughput
#
# Response time
#
# Latency
#
# Utilization
#
# Saturation
#
# Bottleenck
#
# Workload
#
# Cache
#
# Models
#
# System under test
#
# Queueing System
#
# Time Scales
#
# Trade-offs
#
# Tuning Efforts
#
# Layer
# - Aplication
# - Database
# - System calls
# - File system
# - Storage
#
# Level of appropriateness
#
# Point-in-Time Recommendations
#
# Load Versus Architecture
#
# Scalability
#
# Known-knowns
#
# known-unknowns
#
# unknown-unknowns
#
# Metrics
#
# - IOPS
# - Throughput
# - Utilization
# - Latency
#
# Overhead
#
# Issues
#
# Utilization
#
# Time Based
#
# Capacity Based
#
# Non-Idle Time
#
# Saturationn
#
# Profiling
#
# Catching
#
# Algorithms
#
# Hot, Cold, and Warm Caches
#
# - Cold
# - Hot
# - Warm
# - Warmth
#
# Perspectives
#
# Resource Analysis
#
# Performace issue investigations
#
# Capacity planning
#
# Metrics best suited for resource analysis include:
#
# - IOPS
# - Throughput
# - Utilization
# - Saturation
#
# Workload Analysis
#
# Requests
#
# Latency
#
# Completation
#
# Methodology
#
# - Streetlight anti-method
# - Random change anti-method
# - Blame-someone-else anti-method
# - Ad hoc checklist method
# - Problem statement
# - Scientific method
# - Diagnosis cycle
# - Tools method
# - USE method
# - Workload characterization
# - Drill-down analysis
# - Latency analysis
# - Method R
# - Event Tracing
# - Baseline Statistics
# - Performace Monitoring
# - Queueing Theory
# - Static performace tunning
# - Cache tuning
# - Micro-benchmarking
# - Capacity planning
#
# Modeling
#
# Enterprise versus Cloud
#
# Visual Idepentification
#
# Linear scalability
#
# Contention
#
# Coherence
#
# Knee point
#
# Scalability ceiling
#
# Amdahl's Law of Scalability
#
# Universal Scalability Law
#
# Queueing Theory
#
# Kendall's Notation
#
# Capacity Planning
#
# Resource Limits
#
# Factor Analysis
#
# Scalign Solutions
#
# Statistics
#
# Quantifying Performace
#
# Observation-Based
#
# Averages
#
# Geometric Mean
#
# Harmonic Mean
#
# Averages over Time
#
# Decayed Average
#
# Standard Deviations, Percentiles, Median
#
# Coefficient of Variation
#
# Multimodal Distributions
#
# Outliers
#
# MOnitoring
#
# Time-Based Patterns
#
# Monitoring Products
#
# Visualizations
#
# Line Chart
#
# Scatter Plots
#
# Heat Maps
#
# Surface Plot
#
# Visualiation Tools
#
# Exercises:
#
# - What is an IOPS?
# - What is utilization and saturation?
# - What is latency?
# - What is micro-bechmarking?
#
# - Summarize the problems when using average latency as a sole performace metric. Can these problems be solved by including  be solved by including the 99th percentile?

# %% [markdown]
# ## Operating Systems

# %% [markdown]
# Operative Systems
#
# Kernel
#
# Process
#
# Thread
#
# Task
#
# Kenerl-space
#
# User-space
#
# User-land
#
# Context switch
#
# System call (syscall)
#
# Processor
#
# Trap
#
# Interrupt
#
# 1. Answer the following questions about OS terminology
#
# - What is the difference between a process, a thread, and a task?
# - What is a context switch?
# - What is the difference between paging and swapping?
# - What is the difference between I/O-bound and CPU-bound workloads?
#
# 2. Answer the following conceptual questions:
# - Describe the role of the kernel
# - Describe the role fo system calls
# - Describe the role of VFS and its location in the I/O stack
#
# 3. Answer the following deeper questions:
# - List the reasons why a thread would leave the CPU
# - Describe the advantages of virtual memory and demand paging

# %% [markdown]
# ## Observability Tools

# %% [markdown]
# Observability tool types figure
#
# Counter
#
# System-wide
#
# vmstat
#
# mpstat
#
# iostat
#
# netstat
#
# sar
#
# Per-process
#
# ps
#
# top
#
# pmap
#
# Tracing
#
# System wide
#
# tcpdump
#
# snoop
#
# blktrace
#
# iosnoop
#
# execsnoop
#
# dtruss
#
# DTrace
#
# SystemTap
#
# perf
#
# Per-Process
#
# strace
#
# truss
#
# gdb
#
# mdb
#
# Profiling
#
# System-Wide and Per-Process
#
# oprofile
#
# perf
#
# DTrace
#
# SystemTap
#
# cachegrind
#
# Intel VTune Amplifier XE
#
# Oracle Solaris Studio
#
# Observability Sources
#
# /proc
#
# Limits statistics
#
# /sys
#
# Dtrace
#
# - Static and Dynamic Tracing
#
# - Probes
#
# - Providers
#
# - D Language
#
# Execisers
#
# 1. Answer the following questions about observability tool terminology
#
# - What is profilig?
# - What is tracing?
# - What is the difference between static and dynamic tracing?

# %% [markdown]
# ## Applications

# %% [markdown]
# To understand application activities:
#
# - Function
#
# - Operation
#
# - CPU mode
#
# - Configuration
#
# - Metrics
#
# - Logs
#
# - Version
#
# - Bugs
#
# - Community
#
# - Books
#
# - Experts
#
# Objectives
#
# - Latency
# - Throughput
# - Resource utilization
#
# Optimize the Common Case
#
# Observability
#
# Big O Notation
#
# Aplication Performace Techniques
#
# Selecting and I/O Size
#
# Caching
#
# Buffering
#
# Polling
#
# poll() system call
#
# Concurrency and Parallelism
#
# Mutext
#
# Spin locks
#
# RW Locks
#
# Hash Tables
#
# Non-Blocking I/O
#
# Processor Binding
#
# Compile Languages
#
# Interpreted Languages
#
# Virtual Machines
#
# Garbage Collection
#
# Application Performace Methodologies
#
# - Thread state analysis
# - Syscall profiling
# - I/O profiling
# - Workload characterization
# - USE method
# - Drill-down analysis
# - Lock analysis
# - Static performace tuning
#
# Exercises
#
# 1,2,3,4,5

# %% [markdown]
# ## CPUs

# %% [markdown]
# Processor
#
# Core
#
# Hardware thread
#
# CPU instruction
#
# Logical CPU
#
# Scheduler
#
# Run queue
#
# CPU Architectuer
#
# CPU Memory Caches
#
# CPU Run Queues
#
# Clock RATe
#
# Instruction Pipeline
#
# Instruction Width
#
# CPI, IPC
#
# User-time / Kernel-time
#
# Preemption
#
# Priority Inversion
#
# Multiprocess, Multithreading
#
# Compiler Optimization
#
# Hardware
#
# CPU Caches
#
# MMU
#
# Interconnects
#
# CPU Performace Counters
#
# Scheduler
#
# Idle Thread
#
# NUMA Grouping
#
# CPU performace methodology
#
# - Tools method
# - USE method
# - Workload characterization
# - Profiling
# - Cycle analysis
# - Performace monitoring
# - Static performace tuning
# - Priority tuning
# - Resource controls
# - CPU bindings
# - Micro-benchmarking
# - Scaling
#
# perf
#
# SystemTap
#
# stat
#
# Software Tracing
#
# cpustat
#
# oprofile
#
# htop
#
# atop
#
# /proc/cpuinfo
#
# getdelays.c
#
# valgrind
#
# Uitlization Heat map
#
# Subsecond-Offset Heat Map
#
# Ad Hoc
#
# SysBench
#
# Exclusive CPU Sets
#
# Process Binding
#
# Exercises
#
# 1,2,3,4,5

# %% [markdown]
# ## Memory

# %% [markdown]
# Main Memory
#
# Virtual Memory
#
# Resident Memory
#
# Anonymous memroy
#
# Address space
#
# Segment
#
# OOM
#
# Page
#
# Page fault
#
# Paging
#
# Swaping
#
# Swap
#
# Overcommit
#
# File System Cache Usage
#
# Word Size
#
# Main Memory Architecture
#
# Buses
#
# - Shared bus system
# - Direct
# - Interconnect
#
# DDR SDRAM
#
# CPU Caches
#
# MMU
#
# Multiple Page Sizes
#
# TLB
#
# Freing Memory
#
# Reaping
#
# Procees Adress Space
#
# - Executable text
# - Executable data
# - Heap
# - Stack
#
# Heap Growth
#
# slab
#
# slub
#
# glibc
#
# Memory Performace Methodology
#
# - Tools method
# - USE method
# - Chareacterizing usage
# - Cycle analysis
# - Performance monitoring
# - Leak detection
# - Static performace tuning
# - Resource controls
# - Micro-benchmarking
#
# Memory Analysis  tools
#
# vmstat
#
# sar
#
# slabtop
#
# ps
#
# pmpap
#
# Dtrace
#
# free
# dmesg
#
# valgrind
#
# swapom
#
# iostat
#
# perf
#
# /proc/zoneinfo
#
#
# Example Linux Memory Tunables
#
# Multiple Page Sizes
#
# Exercises
#
# 1,2,3,4,5,6,7

# %% [markdown]
# ## File Systems

# %% [markdown]
# File System
#
# File sytem cache
#
# Operatios
#
# I/O
#
# Logical I/O
#
# Physical I/O
#
# Throughput
#
# inode
#
# VFS
#
# Volumen manager
#
# File System Interfaces
#
# File System Cache
#
# File System Latency
#
# Caching
#
# Example of Cache Types
#
# Random vs Sequential I/O
#
# Prefetch
#
# Read-Ahead
#
# Write-Back Caching
#
# Syncrhonous Writes
#
# Raw and Direct I/O
#
# Non-Blocking I/O
#
# Memory-Mapped Files
#
# Metadata
#
# Logical Metadata
#
# Physical Metadata
#
# Logical versus Physical I/O
#
# Unrelated
#
# Inderect
#
# Deflated
#
# Infalted
#
# Operations Are Not Equal
#
# Special File Systems
#
# Acess Timestamps
#
# Capacity
#
# Architecture
#
# File System I/O Stack
#
# VFS
#
# File System Caches
#
# Old Buffer Cache
#
# Page Cache
#
# DNLC
#
# Buffer Cache
#
# Page Cache
#
# Dentry Cache
#
# Inode Cache
#
# File System Features
#
# File System Types
#
# UFS
#
# ZFS
#
# btrfs
#
# Volumnes and Pools
#
# File System Performace Methodologies
# - Disk analysis
# - Latency analysis
# - Workload characterization
# - Performace monitoring
# - Event tracing
# - Static performace tuning
# - Cache tuning
# - Workload separation
# - In-memory file systems
# - Micro-benchmarking
#
# vsstat
#
# fsstat
#
# strace, truss
#
# DTrace
#
# File Opens
#
# System Call Latency
#
# VFS Latency
#
# File System Internals
#
# Slow Event Tracing
#
# Advanced Tracing
#
# Advanced File System Tracing Scripts
#
# - sysfs.d
# - fswcount.d
# - fswtine.d
# - fstpk.d
# ...
#
# SystemTap
#
# LatencyTOP
#
# free
#
# vmstat
#
# sar
#
# /proc/meminfo
#
# kstat
#
# df
#
# mount
#
# inotify
#
# File sytem latency heat map
#
# Micro-Benchmark Tools
#
# Bonnie, Bonnie++
#
# fio
#
# Cache Flushing
#
# Tuning
#
# Applications Calls
#
# - posix_fadvise()
# - madvise
#
# ext3
#
# zfs
#
# Exercises
# 1,2,3,4,5,6,7

# %% [markdown]
# ## Disks

# %% [markdown]
# Virtual disk
#
# Transport
#
# Sector
#
# I/O
#
# Disk commands
#
# Throughput
#
# Badnwidth
#
# I/O latency
#
# Latency outliers
#
# Models
#
# Simple Disk
#
# Caching Disk
#
# Controller
#
# Concepts
#
# Measuring Time
#
# Calculting Time
#
# Time Scales
#
# Cacching
#
# Random versus Sequential I/O
#
# Read/Write Ratio
#
# I/O Size
#
# IOPS Are Not Equal
#
# Non-Data-Transfer Disk Commands
#
# Virtual Disk Utilization
#
# I/O Wait
#
# Synchonous versus Asynchonous
#
# Disk Versus Application I/O
#
# Disk Types
#
# Interfaces
#
# SCSI
#
# SAS
#
# SATA
#
# Storage Types
#
# Operating System Disk I/O Stack
#
# Disk Performace Methodologies
#
# - Tools method
# - Use method
# - Performace monitoring
# - Workload characterization
# - Latency analysis
# - Event tracing
# - Static performace tuing
# - Cache tuning
# - Resource controls
# - Micro-benchmarking
# - Scaling
#
# iostat
#
# sar
#
# pidstat
#
# Dtrace
#
# I/O Stacks
#
# SCSI Events
#
# Advanced Storage I/O Tracing Scripts
#
# SystemTap
#
# perf
#
# iotop
#
# blktrace
#
# MegaCli
#
# smartctl
#
# Line graphs
#
# Scatater polot
#
# Offset Heat Maps
#
# Latency Heat Maps
#
# Utilization Heat Maps
#
# Experimentatino
#
# Custom Load Generators
#
# Micro-Benchmark Tools
#
# Random Read Example
#
# Tuning
#
# Operating System Tunables
#
# ionice
#
# Resource Controls
#
# Tunable Paramters
#
# Disk Device Tunabbles
#
# Disk Controller Tunables
#
# Exercises
#
# 1,2,3,4,5

# %% [markdown]
# ## Network

# %% [markdown]
# Interface
#
# Packet
#
# Frame
#
# Bandwith
#
# Throughput
#
# Latency
#
# Network Interface
#
# Controller
#
# Protocol Stack
#
# Networks and Routing
#
# Protocols
#
# Encapsulation
#
# Packet Size
#
# Latency
#
# Name Resolution Latency
#
# Ping Latency
#
# Connection Latency
#
# First-Byte Latency
#
# Round-Trip Time
#
# Connection Life Span
#
# Buffering
#
# Connection Backlog
#
# Interface Negotiation
#
# Local Connections
#
# Protocols
#
# TCP
#
# Three-Way Handshake
#
# Duplicate ACK Detection
#
# Congestion Control: Reno and Tahoe
#
# Naggle
#
# Hardware
#
# Interfaces
#
# Controllers
#
# Switches, Routers
#
# Software
#
# Network stack
#
# Network Performace Methodologies
#
# - Tools method
# - USE method
# - Workload characterization
# - Latency
# - Performace monitoring
# - Packet sniffing
# - TCP analysis
# - Drill-down analysis
# - Static performace tuning
# - Resource controls
# - Micro-benchmarking
#
# netstat -i
#
# sar
#
# ifconfig
#
# ip
#
# nicstat
#
# ping
#
# traceroute
#
# pathchar
#
#
# tcpdumpt
#
# snoop
#
# Wireshark
#
# DTrace
#
# Socket Connections
#
# Socket I/O
#
# Socket Latency
#
# Socket Internals
#
# TCP Events
#
# Packet Tranmission
#
# Retrasmit Tracing
#
# Backlog Drops
#
# Advanded Network Tracing Scripts
#
# SystemTap
#
# perf
#
# Other Tools
#
# - strace
# - lsof
# - ss
# - nfsstat
# - iftop
# - /proc/net
#
# Experimentation
#
# iperf
#
# Tunning
#
# Exercises
#
# 1,2,3,4,5,6

# %% [markdown]
# ## Cloud Computing

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# Efective behcmkarking
#
# behcmkarking sins
#
# Benchmark Analysis Methodologies
#
# - passive benchmkaring
# - active benchmarking
# - CPU profiling
# - USE Method
# - Workload characterization
# - Custom benchmkarks
# - Ramping  load
# - Sanity check
# - Statistical analysis
#
# Exercises
#
# 1,2

# %% [markdown]
# ## Case Study

# %% [markdown]
# ## USE Method: Linux

# %% [markdown]
# ## USE Method: Solaris

# %% [markdown]
# ## sar Summary

# %% [markdown]
# ## DTrace One-Liners

# %% [markdown]
# ## DTrace to SystemTap

# %% [markdown]
# ## Solutions to Selected Exercises

# %% [markdown]
# ## Systems Performace Who's Who
