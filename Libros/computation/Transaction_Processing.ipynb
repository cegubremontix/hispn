# %% [markdown]
# <a href="https://colab.research.google.com/github/dbremont/Notas/blob/main/Libros/Computacion/Transaction_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transaction Processing

# %% [markdown]
# ## Preface

# %% [markdown]
# ## Introduction

# %% [markdown]
# Abusiness transaction
#
# What is a transaction?
#
# Transaction program
#
# Transaction processing application
#
# TP Systems Architecture
#
# Service Oriented Computing
#
# Hardware Architecture
#
# Atomicity
#
# Handling Real-World Operations
#
# Compensating Transactions
#
# Multistep Business Proceses
#
# Consitency
#
# Isolation
#
# Durability
#
# Two-Phase Commit
#
# Transaction Manager
#
# Transaction Processing Performace
#
# The Tpc-A And  Tpc-B Bechmarks
#
# The Tcp-C Benchmark
#
# The Tcp-E Benchmark
#
# Availability
#
# Styles of Systems
#
# Batch Processing Systems
#
# Real-Time Systems
#
# Data Warehouse Systems
#
# Other System Types
#
# Timesharing
#
# Client-Server
#
# Why Engineer  A Tp System?
#
# TP System Configurations

# %% [markdown]
# ## Transaction Processing Abstraction

# %% [markdown]
# Transactions
#
# Processes and threads
#
# Remote procedure calls
#
# Transaction context, sessions, and other techniques for managing shared state
#
# Caching, resource pooling, partitioning, and replication
#
# These abstractions involve both the application programing interface and mechanism to support it.  Understanding them is fundamental to developing and engineering a TP system
#
# Transactions
#
# Transaction Bracketing
#
# Composability problem
#
# Transaction Identifiers
#
# Chained Transactions
#
# Transaction Bracketing In Object-Oriented Programming
#
# Nested Transactions
#
# Exception Handling
#
# Savepoints
#
# using Savepoints To Support Nested Transactions
#
# Processes and Threads
#
# Why We Need Threads
#
# Implementing Threads
#
# Middleware Threads
#
# Operating System Threads
#
# Server Classes
#
# Remote Procedure Call
#
# Transactional Rpc
#
# Binding Clients And Servers
#
# Interface Definitions
#
# Marshaling
#
# Communication Binding
#
# Dispatching
#
# Application Programmer's View
#
# Object-Oriented RPC
#
# Callbacks
#
# An Rpc Walkthrough
#
# System Characteristics of Rpc
#
# Security of RPC
#
# Fault Tolerance in RPC
#
# System Management
#
# Interoperability of RPC
#
# Performace of RPC
#
# How To Compare Rpc Systems
#
# Shared State
#
# Transaction Context
#
# Sessions
#
# Communication Session
#
# Stateless Servers
#
# Stateful  Applications
#
# Scability
#
# Scaling Up  A Server
#
# Caching
#
# Resource Pooling
#
# Scaling Out A Systems
#
# Partitioning
#
# Partitioning Sessions
#
# Replication
#
# Transaction Bracketing
#
# Processes and Threads
#
# Remote Procedure Calls
#
# Shared State
#
# Scalability Techniques

# %% [markdown]
# ## Transaction Processing  Application Architecture

# %% [markdown]
# Application Architecture
#
# Multitier Architectures
#
# Stored procedures
#
# Server-Oriented Architecture
#
# Object-Oriented Design
#
# Simple Requests
#
# Front-End Program
#
# Gathering Input Using Forms and Menus'
#
# Form and Menu Technology
#
# Forms Development
#
# Constructing Requests
#
# Logging
#
# Web Servers
#
# State Management For Web Servers
#
# Authentication and Encryption
#
# Request Controller
#
# Specifying Request Controller Functions
#
# Transaction Bracketing
#
# Request Integrity
#
# Process Structure
#
# Session Structure
#
# Security
#
# Transaction Servers
#
# Process And Session Structure
#
# Transactional Middleware
#
# Database Servers Versus Transactioal Middleware

# %% [markdown]
# ## Queued Transaction Processing

# %% [markdown]
# Why Use Queues?
#
# The Queued Transaction Processing Model
#
# Client's View of Queuing
#
# Client Recovery
#
# Handling Non-Undouable Operations
#
# The Queue Manager
#
# Operations On Queued Messages
#
# Generalized Messaging
#
# Timeouts
#
# Handling Poisoned Messages
#
# Message Ordering
#
# Filter Criteria
#
# Nontransactional Queuing
#
# Journaling
#
# Queue Management
#
# Routing
#
# Dispatcher
#
# Publish-Subscribe
#
# Other Message-Oriented Middleware
#
# Broker-Based Architecture
#
# Bus-Based Architecture
#
# Comparing Brokers And Buses
#
# Queueing Products and Standards
#
# Ibm's Websphere Mq
#
# Oracle Streams Aq

# %% [markdown]
# ## Business Process Management

# %% [markdown]
# Busines process
#
# Bsiness Process Definition
#
# Business Process Execution
#
# State Management
#
# Transactional Properties
#
# Isolation
#
# Atomicy
#
# Durability
#
# Making Process State Durable
#
# Using A Special-Purporse Runtime System
#
# Using Queued Requests
#
# Pseudo-Conversations
#
# Using Logging
#
# Other Models of Business Processes
#
# Scientic Workflow
#
# Configuration Management Systems
#
# Products and Standards
#
# Web Services Business Process
#
# Execution Language
#
# Sql Server Service Broker

# %% [markdown]
# ## Locking

# %% [markdown]
# Locking
#
# Correctness And The Two-Phase Rule
#
# Transactions Interact Only Via Reads And Writes
#
# Preversing Transaction Handshakes
#
# Automatic Locking
#
# Implementation
#
# Lock Managers
#
# Setting And Releasing Locks
#
# Granularity
#
# Multigranularity Locking
#
# Deadlocks
#
# Deadlock Prevention
#
# Deadlock Detection
#
# Victim Selection
#
# Distributed Deadlock Detection
#
# Performace
#
# Lock Conversions
#
# Lock Thrashing
#
# Tuning to Reduce Lock Contention
#
# A Mathematical Model of Locking Performace
#
# Hot Spots
#
# Optimistic Methods
#
# Batching
#
# Partitioning
#
# Query-Update Problems
#
# Data Warehousing
#
# Degrees Of Isolation
#
# Multiversion Data
#
# Multiversion Implementation Details
#
# Avoiding Phantoms
#
# Performace Implications
#
# Optimistic Concurrency Control
#
# B-Tree Locking
#
# B+ Trees
#
# B+ Tree Insertions
#
# Tree Locking
#
# The B-Link Optimization
#
# Multigranularity Locking
#
# Locking Nested Transactions
#
# Basic Serializability Theory
#
# The Serializability Theorem
#
# The Two-Phase Locking Theorem

# %% [markdown]
# ## System Recovery

# %% [markdown]
# Causes of System Failure
#
# Hardering The Environment
#
# System Management
#
# Hardware
#
# Software
#
# A Model for System Recovery
#
# Detecting Proces Failures
#
# Client Recovery
#
# Server Recovery
#
# Checkpoint-Based Recovery
#
# Transaction-Based Server Reovery
#
# Stateless Servers
#
# Introduction to Database Recovery
#
# Types of Failure
#
# Recovery Strategies
#
# The System Model
#
# Locking Assumptions
#
# Page Granularity Operations
#
# Storage Model
#
# The Log
#
# Database Recovery Manager
#
# Implementing Abort
#
# Implementing Commit
#
# Shadow-paging Algorithm
#
# Log-based Algortihms Recovery Algorithms
#
# Implementing Commit
#
# Implementing Abort
#
# Implementing Restart
#
# Optimizing Restart in Log-based Algorithms
#
# Fuzzy Checkpointing
#
# Operation Logging
#
# Media Recovery
#
# Mirrored Disks
#
# Archiving

# %% [markdown]
# ## Tho-Phase Commit

# %% [markdown]
# The Two-Phase Commit Protocol
#
# The Protocol
#
# Performace
#
# Blocking
#
# Failure Handling
#
# Optimizations and Variations
#
# Reinfection
#
# Transfer of Coordination
#
# Phase Zero
#
# Presumed Abort
#
# Read-Only Transactions
#
# Cooperative Termination Protocol
#
# Process Structuing
#
# Independing Transaction Managers
#
# Enlisting In A Transaction
#
# The Tree-Of-Processes Model

# %% [markdown]
# ## Replication

# %% [markdown]
# Replicated Servers
#
# The Primary-Backup Model
#
# Replicating The Resource
#
# Replicating The Server With A Shared Resource
#
# Synchonizing Updates to Replicated Data
#
# One-Copy Serializability
#
# Replicating Updates
#
# Replicating Requests
#
# Single-Master Primary-Copy Replication
#
# Failures And Recoveries
#
# Secondary Recovery
#
# Primary Recovery with One Secondary
#
# Primary Recovery With Multiple Secondaries
#
# Majority and Quorum Consensus
#
# Reaching Consensus
#
# Establishing the Latest State
#
# Consistency, Availabilyt, And Partition-Tolerance
#
# Multimaster Replication
#
# Pertitioned Operation Can Be Useful
#
# Update Propagation With Multiple Masters
#
# Nonblind Updates
#
# Detecing Replication Conflicts Using Version Vectors
#
# Conflict Resolution
#
# Maintainign The Version Vector
#
# Version Vector Update  Rules
#
# Simplified Version Vector Update Rules
#
# Consistency, Availability, And Partition-Tolerance Reviseted
#
# Microsoft Sync Framework
#
# Other Replication Techniques
#
# Data Sharing Systems
#
# Locking
#
# Caching
#
# Logging

# %% [markdown]
# ## Transactional Middleware Products and Standards

# %% [markdown]
# Trends In Transactional Middleware
#
# Transactional Middleware Programming Models
#
# Java Ee And The .Net Framework
#
# Web Browser Front-End Programs
#
# .NET Framework
#
# Developing Front-End Programs
#
# Windows Presentation Foundations
#
# ASP.NET and Silverlight
#
# Developing Request Controllers And Transaction Servers
#
# Transactions
#
# Bindings
#
# Rest/Http Support
#
# Wcf Deployment  Options
#
# Transaction Management Using System.transactions
#
# The Explicit Programming Model
#
# Integration With Legacy Tp Monitors
#
# Java Enterprise Edition
#
# Developing Front-End Programs
#
# Servlet
#
# Rest Support
#
# Deloping Request Controllers And Trasaction Servers
#
# Transaction Management In Java
#
# The Implicit Programming Model
#
# The Explicit Programming Model
#
# Integration With Legacy Tp Monitors
#
# Spring Transactions
#
# Service-Oriented Architecture
#
# Web Services-Based Soa
#
# Rest/Http-Based Soa
#
# Persistence Abstraction Mechanisms
#
# Odbc And Jdbc
#
# Stored Procedures
#
# SQL Server Stored Procedure Examples
#
# Java Persistance Api
#
# Ado.net And Ado.net Entity Framework
#
# Legacy TP Monitors
#
# Cics Transaction Server
#
# System Architecture
#
# Front-end program
#
# TP Communications
#
# Database Access
#
# Ims
#
# Basic System Architectures
#
# Front-end program
#
# TP Communications
#
# Database Access
#
# Tuxedo
#
# System Architecture
#
# Front-end program
#
# TP Communications
#
# Database Acess
#
# Acms
#
# System Architecture
#
# Command Process
#
# Task Server
#
# TP Communication
#
# Database Acess
#
# Pathway Ts/Mp
#
# System Architecture
#
# Front-end program
#
# TP Communications
#
# Database Access
#
# TP Standards
#
# Ws-Transactions
#
# The Xa Interface
#
# Object Trnsaction Service
#
# Jta
#
# Service Component Architecture
#
# Osgi Alliance
#
# Advanced Message Queueing Protocol

# %% [markdown]
# ## Future Trends

# %% [markdown]
# Cloud Computing
#
# Multitenant Systems
#
# Scalable Distributed Computing
#
# Memory  Technology
#
# Streams and Event Processing

# %% [markdown]
# ## Glosary of Acronyms
