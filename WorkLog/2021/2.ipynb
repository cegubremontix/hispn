# %% [markdown]
# <a href="https://colab.research.google.com/github/dbremont/Notas/blob/main/WorkLog/2022/MonthNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **diciembre**

# %% [markdown]
# - **set a variable**: asignar valor a una variable

# %% [markdown]
# - How lambdas are implemented.
#
# - I only just noticed that python, unlike C, had the mod operator always return a positive number, even if the first argument is negative, which is great for wrapping buffers! Who ever wanted negative mod results?

# %% [markdown]
# **Todo**:
#
# - Verificar todos los articulos de dbremont/Notas
#   - Apache kafka papers
#   - Tips for system design
#
# - Anify
#   - Add to anki System Design Premer
#     - Add to anki System Design Premer - https://github.com/donnemartin/system-design-primer
#
# - Process Months Notes

# %% [markdown]
# [Collective Learning and Economic Complexity](https://centerforcollectivelearning.org/complexitycourse)
#
# [Who is Scott Alexander and what is he about?](https://jasoncrawford.org/guide-to-scott-alexander-and-slate-star-codex)
#
# [25 Essential skills Java Programmers and Architects can learn in 2022](https://medium.com/javarevisited/top-22-skills-professional-java-programmers-can-learn-in-2022-to-upgrade-themselves-bc3da73d7491)
#
# [Domain (software engineering)](https://en.wikipedia.org/wiki/Domain_(software_engineering))
#
# [Comparison](https://en.wikipedia.org/wiki/Comparison)
#
# [Iterativo](http://etimologias.dechile.net/?iterativo)
#
# [SDK Man](https://sdkman.io/)
#
# [The JPA and Hibernate first-level cache](https://vladmihalcea.com/jpa-hibernate-first-level-cache/)
#
# [blog.acolyer.org](https://blog.acolyer.org/)
#
# [Some of my favorite technical papers](https://lethain.com/some-of-my-favorite-technical-papers/)
#
# [How to safely think in systems](https://lethain.com/how-to-safely-think-in-systems/)
#
# [Metrics for the unmeasurable](https://lethain.com/metrics-for-the-unmeasurable/)
#
# [Introduction to systems thinking](https://lethain.com/systems-thinking/)
#
# [10 Papers Every Developer Should Read](https://michaelfeathers.silvrback.com/10-papers-every-developer-should-read-at-least-twice)
#
# [Dynamo: Amazon’s Highly Available Key-value Store](https://www.allthingsdistributed.com/files/amazon-dynamo-sosp2007.pdf)
#
# [Flash: An Efficient and Portable Web Server](https://www.usenix.org/legacy/events/usenix99/full_papers/pai/pai.pdf)
#
# [How to Read a Paper](https://web.stanford.edu/class/ee384m/Handouts/HowtoReadPaper.pdf)

# %% [markdown]
# [Table Oriented Programming](https://web.archive.org/web/20121024051826/http://www.geocities.com/tablizer/top.htm)
#
# [GraalVM Papers](https://github.com/oracle/graal/blob/master/docs/Publications.md)
#
# [ReactiveX Introductions](https://reactivex.io/tutorials.html)
#
# [GraalVM](https://en.wikipedia.org/wiki/GraalVM)
#
# [My first impressions about Graal VM](https://blog.frankel.ch/first-impressions-graalvm/)
#
# [Truffle Language Implementation Framework](https://www.graalvm.org/graalvm-as-a-platform/language-implementation-framework/)
#
# [CSCC69 Operating systems](https://thierrysans.me/CSCC69/)
#
# [Augmenting Long-term Memory](http://augmentingcognition.com/ltm.html)
#
# [Pure function](https://en.wikipedia.org/wiki/Pure_function)
#
# [Designing Netflix](http://highscalability.com/blog/2021/12/13/designing-netflix.html)
#
# [awesome-system-design](https://github.com/madd86/awesome-system-design)
#
# [Readings in Databases](https://github.com/rxin/db-readings)
#
# [System Design Interview Questions – Concepts You Should Know](https://www.freecodecamp.org/news/systems-design-for-interviews/)
#
# [You can’t copy code with memcpy; code is more complicated than that](https://devblogs.microsoft.com/oldnewthing/20211229-00/?p=106061)
#
# [You're probably using the wrong dictionary](https://jsomers.net/blog/dictionary)
#
# [Databases in 2021: A Year in Review](https://ottertune.com/blog/2021-databases-retrospective/)
#
# [text - An experiment with WebSockets and the human condition](https://github.com/g105b/text)
#
# [Lesser known C features](https://d3s.mff.cuni.cz/legacy/~holub/c_features.html)
#
# [Creating a Circular Buffer in C and C++](https://embeddedartistry.com/blog/2017/05/17/creating-a-circular-buffer-in-c-and-c/)
#
# [Circular buffer](https://en.wikipedia.org/wiki/Circular_buffer)
#
# [Postgresql SQL](https://www.postgresql.org/)
#
# [String](https://docs.oracle.com/javase/7/docs/api/java/lang/String.html)
#
# [Atlr Grammars V4](https://github.com/antlr/grammars-v4)
#
# [Class Lexer](https://www.antlr.org/api/Java/org/antlr/v4/runtime/Lexer.html)
#
# [Class Parser](https://www.antlr.org/api/Java/org/antlr/v4/runtime/Parser.html)
#
# [Reading 18: Parser Generators](https://ocw.mit.edu/ans7870/6/6.005/s16/classes/18-parser-generators/index.html)
#
# [Sytem Desing primer - Learn how to design large-scale systems. Prep for the system design interview. Includes Anki flashcards](https://github.com/donnemartin/system-design-primer)

# %% [markdown]
# - Java null check why use == instead of .equals()
#
#
# - Mirar
#
# Util.UNO_CON_2_DECIMALES.compareTo(operacion) == 0 ?
# 						General.getIdDestinoContable(modelo.getCodDestinoContable()) // int
# 						: modelo.getDestinoAnterior(), // Integer
# - true ? (int) 0 ? Integer.value(null)
#    - null ?
#    - null pointer exception?
#
# [JVM Internals](https://blog.jamesdbloom.com/JVMInternals.html)
#
# [Neo-charismatic movement](https://en.wikipedia.org/wiki/Neo-charismatic_movement)
#
# [Writing Fast Async Http Request in PYthon](https://blog.jonlu.ca/posts/async-python-http?ref=hn)
#
# [geohot configuration](https://github.com/geohot/configuration)
#
# [Locuciones latinas](https://es.wikipedia.org/wiki/Anexo:Locuciones_latinas)
#
# [Ora et Labora](https://es.wikipedia.org/wiki/Ora_et_labora)
#
# [Plus Ultra Lemma](https://es.wikipedia.org/wiki/Plus_ultra_(lema))
#
# [Fideicomiso](https://es.wikipedia.org/wiki/Fideicomiso)
#
# [Anti-Catholicism](https://en.wikipedia.org/wiki/Anti-Catholicism)
#
# [calamify - self-hosted GPT playground](https://github.com/thesephist/calamity)

# %% [markdown]
# [The Tao of Boyd: How to Master the OODA Loop](https://www.artofmanliness.com/character/behavior/ooda-loop/)
#
# [Top 16 Profitable Business Ideas for Developing Countries](https://www.99businessideas.com/developing-countries/)
#
# [Visualizing and Understanding Code Duplication in Large Software Systems](https://uwspace.uwaterloo.ca/handle/10012/2630)
#
# [Visual exploration of software code duplication](https://www.cs.rug.nl/svcg/SoftVis/Duplication)
#
# [Java String](http://tutorials.jenkov.com/java/strings.html)
#
# [Everything you need to know about OpenTelemetry Java agent](https://signoz.io/opentelemetry/java-agent/)
#
# [Apache dubbo](https://github.com/apache/dubbo)
#
# [Seata - Seata is an easy-to-use, high-performace, open so urce distribution transaction solution](https://github.com/seata/seata)
#
# [RocketMQ](https://github.com/apache/rocketmq)
#
# [Alibaba Sentinel](https://github.com/alibaba/Sentinel)
#
# [Hutool - A set of tools that keep Java sweet](https://github.com/dromara/hutool)
#
# [OpenTelemetry Java SDK](https://github.com/open-telemetry/opentelemetry-java)
#
# [Uptrace](https://uptrace.dev/open-source/)
#
# [Open Telemetry](https://opentelemetry.io/)
#
# [Jakarta EE](https://en.wikipedia.org/wiki/Jakarta_EE)
#
# [Go at Google: Language Design in the Service of Software Engineering](https://go.dev/talks/2012/splash.article#TOC_14.)
#
# [Type system](https://en.wikipedia.org/wiki/Type_system)
#
# [SQL parser library for Java [closed]](https://stackoverflow.com/questions/660609/sql-parser-library-for-java)
# - For the problem of transpiling sql to java syntax
# - sqltoj (sql to java)
# - sqltoj /sql/script/path --replace-tokens-with=/path/to/file
#
# [The Year in Biology](https://www.quantamagazine.org/the-year-in-biology-20211221/)
#
# [The Year in Physics](https://www.quantamagazine.org/the-year-in-physics-20211222/)
#
# [The Year in Math and Computer Science](https://www.quantamagazine.org/the-year-in-math-and-computer-science-20211223/)
#
# [Go (programming language)](https://en.wikipedia.org/wiki/Go_(programming_language))
#
# [Evaluating the GO Programming Language with Design Patterns](https://ecs.wgtn.ac.nz/foswiki/pub/Main/TechnicalReportSeries/ECSTR11-01.pdf)
#
# [List of companies of New Zealand](https://en.wikipedia.org/wiki/List_of_companies_of_New_Zealand)
#
# [Xero (company](https://en.wikipedia.org/wiki/Xero_(company))
#
# [Vend (software)](https://en.wikipedia.org/wiki/Vend_(software))
#
# [T Pago](https://tpago.com/)
#
# [SLI Systems](https://en.wikipedia.org/wiki/SLI_Systems)
#
# [Trade Me](https://en.wikipedia.org/wiki/Trade_Me)
#
# [Make Java REST development easier with the Jareto library](https://blogs.oracle.com/javamagazine/post/make-java-rest-development-easier-with-the-jareto-library)
#
# [Jakata EE - The Java Magazine](https://blogs.oracle.com/javamagazine/category/jm-jakarta-ee)
#
# [Medios de pago en internet disponibles en la republica dominicana](https://www.impulsapopular.com/finanzas/medios-de-pago-en-internet-disponibles-en-republica-dominicana/)
#
# [Machine tool](https://en.wikipedia.org/wiki/Machine_tool)

# %% [markdown]
# **ankifi**
#
# - Computer systems
#
# What are the main different between designing an **algorithm** vs a **computer system**?
#
# - External Interface (Requirements), the requirements of **computer systems** ...,
# - Internal Structure, **computer systems**  have more internal structure than algorithms, so they also need internal interfaces,
# - Measure of Success, the measure of sucess in **algorithms** is much easier than the measure of sucess in computer systems.
#
# Meaning of the **STEADY by AID with ART**
# - What?       **Goals**       STREADY: - Simple, Timely, Efficient, Adaptable, Dependable, Yummy
# - How?        **Techniques**  by AID:  - Approximate, Incremental, Divide & Conquer
# - When, who?  **Process**   with ART: - Architecture, Automate, Review, Techniques, Test

# %% [markdown]
# log4j2.xml
# - Try to implement log4js,
# -

# %% [markdown]
# [Ask HN: Favorite Podcast Episode of 2021?](https://news.ycombinator.com/item?id=29703564)
#
# [Noam Chomsky’s Theory of the Good Life](https://podcasts.apple.com/podcast/the-ezra-klein-show/id1548604447?i=1000518312313)
#
# [Joel on Software - Things You Should Never Do, Part I](https://www.joelonsoftware.com/2000/04/06/things-you-should-never-do-part-i/)
#
# [Metrics-driven product development is hard](https://blog.doubleloop.app/metrics-driven-product-development-is-hard/)
#
# [Bug Detection and Repair with ML](https://miltos.allamanis.com/files/slides/2021mila_rg.pdf)
#
# [A New Coefficient of Correlation](https://arxiv.org/pdf/1909.10140.pdf)
#
# [A javac plugin for extracting a feature graph for plugging in to machine learning models](https://github.com/acr31/features-javac)
#
# [A Review of the Zig Programming Language (using Advent of Code 2021)](https://www.duskborn.com/posts/2021-aoc-zig/)
#
# [The Background for CAR and CDR](http://www.howardism.org/Technical/Clojure/origin-of-car-and-cdr.html)
#
# [Find which process is modifying a file [duplicate]](https://unix.stackexchange.com/questions/99074/find-which-process-is-modifying-a-file)
#
# [How to setup and Install Auditd on Ubuntu](https://dev.to/ajaykdl/how-to-setup-auditd-on-ubuntu-jfk)
#
# [Joel Spolsky](https://en.wikipedia.org/wiki/Joel_Spolsky)
#
# [CPSC 539K - What Do Programs Mean?](https://www.cs.ubc.ca/~gregor/teaching/cpsc539k-08-09-t1/index.html#readings)
#
# [Towards a New Model of Abstraction in the Engineering of Software Gregor Kiczales](https://web.archive.org/web/20110604013045/http://www2.parc.com/csl/groups/sda/publications/papers/Kiczales-IMSA92/for-web.pdf)
#
# **Point of Sale**
# - [Erp Next](https://erpnext.com/)
#
# - [oddo](https://github.com/odoo/odoo)
#
# - [Oddo Punto de Venta](https://www.odoo.com/es_ES/app/point-of-sale-shop)
#
# - [Apache OFBiz](https://ofbiz.apache.org/index.html)
#
# - [Odoo Install](https://www.odoo.com/documentation/15.0/administration/install/install.html)
#
# - [Punto de Venta Claro](https://www.clarocloud.com.do/portal/do/cld/productos/colaboracion/punto-de-venta/)
#
# - [Barcode Reader](https://www.corotos.com.do/k/lector%20codigo%20de%20barra)
#
# - [Barcode sticker printer](https://www.alibaba.com/premium/barcode_sticker_printer.html?src=sem_ggl&from=sem_ggl&cmpgn=9773474059&adgrp=101172345553&fditm=&tgt=kwd-2275993116&locintrst=&locphyscl=9069760&mtchtyp=p&ntwrk=g&device=c&dvcmdl=&creative=428995788621&plcmnt=&plcmntcat=&p1=&p2=&aceid=&position=&localKeyword=barcode%20sticker%20printer&gclid=Cj0KCQiA5aWOBhDMARIsAIXLlkfCH4TSHK4SISzDk90kpKBzJW8_6lSjM59aW8KP8YDQ9C9FiLe7EHAaArdnEALw_wcB)
#
# - [Point of sale](https://en.wikipedia.org/wiki/Point_of_sale)
#
# - Gestionar pedidos por what-apps web
#
# - Máquina de Imprimir Recibos
#
# - Solución para el raestro de animales
#   - [WildLife Monitoring](https://atstrack.com/animal-class/mammals.aspx)
#
#   - [Radio Telemetry](https://atstrack.com/customer-support/how-to-radio-track-telemetry.html)
#
#   - [Low-cost DIY GPS trackers improve upland game bird monitoring](https://bioone.org/journals/wildlife-biology/volume-2020/issue-2/wlb.00653/Low-cost-DIY-GPS-trackers-improve-upland-game-bird-monitoring/10.2981/wlb.00653.full)
#
# - [Split screen in Kitty](https://stackoverflow.com/questions/66127831/split-screen-in-kitty)

# %% [markdown]
# So much of AI is compressing reality to a small vector space, like a video game in reverse. - Elon Musk
#
# [Ten Years of Logging My Life](https://chaidarun.com/ten-years-of-logging-my-life)
#
# [Ports](https://pbs.twimg.com/media/FHjwLVNX0AQBRut?format=jpg&name=small)
#
# [An Oxford Interview Question](https://twitter.com/jdhamkins/status/1475088789701726208)
#
#
# [Sequencing you DNA with a USB dongle and open source code](https://stackoverflow.blog/2021/12/24/sequencing-your-dna-with-a-usb-dongle-and-open-source-code/)
#
# [Targeted nanopore sequencing by real-time mapping of raw electrical signal with UNCALLED](https://www.nature.com/articles/s41587-020-0731-9)
#
# Code Bases to Explore in PYthon
#
# - [tiangolo - To Read Code](https://github.com/tiangolo)
# - [Encode](https://github.com/encode)

# %% [markdown]
# [Learning in double time: The effect of lecture video speed on immediate and delayed comprehension](https://onlinelibrary.wiley.com/doi/10.1002/acp.3899?af=R)
#
# [Most advice is pretty bad - How to give good advice](https://atis.substack.com/p/most-advice-is-pretty-bad)
#
# [The Benjamin Franklin Method of Reading Programming Books](https://www.pathsensitive.com/2018/01/the-benjamin-franklin-method-of-reading.html)
#
# [Infrequently Ask Questions about C](https://www.seebs.net/faqs/c-iaq.html)
#
# [Patterns of Distributed Systems](https://martinfowler.com/articles/patterns-of-distributed-systems/)
#
# [Albert O. Hirschman - Hispanidad](https://en.wikipedia.org/wiki/Albert_O._Hirschman)
#
# [Powerful Ideas Need Love Too!](http://worrydream.com/refs/Kay%20-%20Powerful%20Ideas%20Need%20Love%20Too.html)
#
# [Programming and Programming Languages](http://worrydream.com/refs/Kay%20-%20Programming%20and%20Programming%20Languages.pdf)
#
# [Glossary of computer science](https://en.wikipedia.org/wiki/Glossary_of_computer_science)
#
# [Natalie Programming Language](https://natalie-lang.org/)
#
# [What scientists must know about hardware to write fast code](https://biojulia.net/post/hardware/)
#
# [Thread Safety in C++ and Rust](https://blog.reverberate.org/2021/12/18/thread-safety-cpp-rust.html)
#
# [Creating a .desktop file for a new application](https://askubuntu.com/questions/281293/creating-a-desktop-file-for-a-new-application)
#
# [How to check if Ubuntu Desktop or Server is installed?](https://askubuntu.com/questions/12562/how-to-check-if-ubuntu-desktop-or-server-is-installed)
#
# [The new paradigm of economic complexity](https://www.sciencedirect.com/science/article/pii/S0048733321002420?via%3Dihub)
#
# [Every Programmer Should Know - A collection of (mostly) technical things every software developer should know  about](https://github.com/mtdvio/every-programmer-should-know)
#
# Estudiar el funcionamineto de Jakarta EE
#
# - javax.servlet.Filter
#
#
# [DLL Hell](https://en.wikipedia.org/wiki/DLL_Hell)
#
# AspectJ problem caused will using multiple versions, to correct he mistake specifiy the version in the build file, and also you just can delete the versions in the maven directory  ".m2".
#
# [Aspectj bad version number warning in maven build](https://stackoverflow.com/questions/40884561/aspectj-bad-version-number-warning-in-maven-build)
#
# While using aspectj,  can be  the case that some aspects are not process, causing problems at runtime.
#
# [AspectJ & Maven warning: "Advice defined in ... has not been applied?"](https://stackoverflow.com/questions/15795630/aspectj-maven-warning-advice-defined-in-has-not-been-applied)
#
# [Intro to AspectJ](https://www.baeldung.com/aspectj)
#
# [Aspect weaver](https://en.wikipedia.org/wiki/Aspect_weaver)
#
# - Tratamiento conección

# %% [markdown]
# **Making money this year**
#
# - [How to Start Investing in Stocks: A Beginner's Guide](https://www.investopedia.com/articles/basics/06/invest1000.asp)
#
# - [How To Invest In ETFs](https://www.forbes.com/advisor/investing/how-to-invest-in-etfs/)
#
# - [How To Make Money In Stocks](https://www.forbes.com/advisor/investing/how-to-make-money-in-stocks/)
#
# - [What Are Index Funds?](https://www.forbes.com/advisor/investing/what-are-index-funds/)

# %% [markdown]
# **Algorithm Trading**

# %% [markdown]
# [txtai.java - Build AI-Powered semantic search applications in Java](https://github.com/neuml/txtai.java)
#
# [qubu - QuBU is a Java query buider inspired to PyPika](https://github.com/henryx/qubu)
#
# [Primitive Collections Library](https://www.reddit.com/r/java/comments/rg30a0/primitive_collections_library/?utm_source=share&utm_medium=web2x&context=3)
#
# [An Empirical Lower Bound on the Overheads of Production Garbage Collectors](https://arxiv.org/pdf/2112.07880.pdf)
#
# [Eclipse Jifa - Web application based on Eclipse Mmeory Tooling that provided HTTP services so that users can view the heap dump](https://github.com/eclipse/jifa)
#
# [Primitive Collections Library](https://www.reddit.com/r/java/comments/rg30a0/primitive_collections_library/)
#
# [basic conceptual model - "how data looks/works iside a running Java program today"](https://mail.openjdk.java.net/pipermail/valhalla-spec-experts/2021-December/001715.html)
#
# [Democratic domestic product - Student trained  in ergodicity  thinks about GDP ](https://ergodicityeconomics.com/2020/02/26/democratic-domestic-product/)
#
# [Java Anonymous inner class](https://www.javatpoint.com/anonymous-inner-class)

# %% [markdown]
# **Program Syntesis:**
#
# - [Armando Solar-Lezama](https://people.csail.mit.edu/asolar/)
# - [Introduction to Program Synthesis](https://people.csail.mit.edu/asolar/SynthesisCourse/index.htm)

# %% [markdown]
# Hoy he utilizado awk, para filtrar un numero de registros de un archivo, me resulto útil, `awk -F"-" '{  if ($2 < 1) {print}}' out.txt`
# - Todas las lineas cuyo segundo campo sea menor que uno, del archivo `out.txt`
# - Los campos estaban separados por `-`
#
# Hoy utilize `echo -n` para  decirle a `echo` que no imprima una nueva linea.

# %% [markdown]
# [The Unix Shell](https://swcarpentry.github.io/shell-novice/)
#
# [Important Things To Do Before the Market Bubble Bursts](https://behavioralvalueinvestor.com/blog/bubbleburst)
#
# [DNA seen through the eyes of a coder (or, If you are a hammer, everything looks like a nail)](https://berthub.eu/articles/posts/amazing-dna/)
#
# [tabby.sh](https://tabby.sh/)
#
# [How can I  use grep to show just filenames on Linux?](https://stackoverflow.com/questions/6637882/how-can-i-use-grep-to-show-just-filenames-on-linux)
#
# [Cómo crear tu propio escudo de armas](https://es.wikihow.com/crear-tu-propio-escudo-de-armas)
#
# Maven no detecta todos los errores, ej: declaracion paquete no encabezado clase no corresponde con lo fisico
#
# [Class ServiceLoader>](https://docs.oracle.com/javase/7/docs/api/java/util/ServiceLoader.html)
#
# [Bio-O Cheat Sheet](https://www.bigocheatsheet.com/)
#
# [Cleaning ThreadLocals](https://www.javaspecialists.eu/archive/Issue229-Cleaning-ThreadLocals.html)
#
# [Hamcrest Tutorial](http://hamcrest.org/JavaHamcrest/tutorial)
#
# [Invoking C Code from Golang](https://tech-lessons.in/invoking-C-code-from-golang/)
#
# Hamcrest Matcher signer information does not match signer information of other classes in the same package
# -
#
#
# [How to solve InaccessibleObjectException ("Unable to make {member} accessible: module {A} does not 'opens {package}' to {B}") on Java 9?](https://stackoverflow.com/questions/41265266/how-to-solve-inaccessibleobjectexception-unable-to-make-member-accessible-m)
#
# [Orden del Císter](https://es.wikipedia.org/wiki/Orden_del_C%C3%ADster)
#
# [Regla de san Benito](https://es.wikipedia.org/wiki/Regla_de_san_Benito)
#
# [ACID](https://en.wikipedia.org/wiki/ACID)
#
# [pre commit - A framework for managing and maintaining multi-language pre-commit hooks](https://pre-commit.com/)
#
# [The Science of Visual Data Communication: What Works](https://journals.sagepub.com/stoken/default+domain/10.1177%2F15291006211051956-FREE/full#.YbpbbYlu2Xw.twitter)
#
# [Continuations Java Implmentation](https://github.com/vsilaev/tascalate-javaflow)
#
# [Accounting Basics](https://www.accountingcoach.com/accounting-basics/explanation)
#
# [Let’s Continuation.resume()](https://vsilaev.com/2016/05/20/javaflow-fork-intro/)
#
# [The Economics of AI](https://www.coursera.org/learn/economics-of-ai)
#
# [A mental model of decentralization](https://jacobobryant.com/p/mental-model-decentralization/)
#
# [Fixing Memory Leaks In Popular Python Libraries](https://www.paulsprogrammingnotes.com/2021/12/python-memory-leaks.html)
#
# [On Bullshit](http://www2.csudh.edu/ccauthen/576f12/frankfurt__harry_-_on_bullshit.pdf)
#
# [QEMU, a Fast and Portable Dynamic Translator](https://www.usenix.org/legacy/event/usenix05/tech/freenix/full_papers/bellard/bellard.pdf)
#
# [Documentation/Networking](https://wiki.qemu.org/Documentation/Networking)
#
# [Great Reading List With Commentary](http://bactra.org/notebooks/)
#
# [Bret Victor Readign List](http://worrydream.com/refs/)
#
# [Driven by Compression Progress: A Simple Principle Explains Essential Aspects of Subjective Beauty, Novelty, Surprise, Interestingness, Attention, Curiosity, Creativity, Art, Science, Music, Jokes](https://arxiv.org/abs/0812.4360)
#
# [Crypto Reading](https://danromero.org/crypto-reading/)
#
# [How To Understand Things](https://nabeelqu.co/understanding)
#
# [Daf Yomi](https://en.wikipedia.org/wiki/Daf_Yomi)
#
# [How Complex Systems Fail](https://how.complexsystems.fail/)
#
# [Quotes](http://worrydream.com/quotes/)
#
# [Intellectual Gluttony](https://www.ribbonfarm.com/2010/05/19/intellectual-gluttony/)
#
# [Entropy Explained, With Sheep](https://aatishb.com/entropy/)
#
# [Research Debt](https://distill.pub/2017/research-debt/)
#
# [How Life Sciences Actually Work: Findings of a Year-Long](https://guzey.com/how-life-sciences-actually-work/)
#
# [Market Research, Wireframing, and Design Idea, Execution, and Market](https://spark-public.s3.amazonaws.com/startup/lecture_slides/lecture5-market-wireframing-design.pdf)
#
# [What's Wrong with Social Science and How to Fix It: Reflections After Reading 2578 Papers](https://fantasticanachronism.com/2020/09/11/whats-wrong-with-social-science-and-how-to-fix-it/)
#
# [Computation graphs and graph computation](https://breandan.net/2020/06/30/graph-computation/)
#
# [Java Coroutines](https://ssw.jku.at/Research/Projects/JVM/Coroutines.html)
#
# [The rise and fall of rationality in language](https://www.pnas.org/content/118/51/e2107848118)
#
# [Java Continuations](https://ssw.jku.at/Research/Projects/JVM/Continuations.html)
#
# [Mining Idioms from Source Code](https://homepages.inf.ed.ac.uk/csutton/publications/idioms.pdf)
#
# [Unicorn - The Ultimate CPU Emulator](https://www.unicorn-engine.org/)
#
# [Can a Turing machine perform Quicksort?](https://stackoverflow.com/questions/29566714/can-a-turing-machine-perform-quicksort)
#
# [Java in real-time applications](https://ieeexplore.ieee.org/document/710972)
#
# [Data Structures & Algorithms for Beginners II 8 top time complexities & Examples](https://adrianmejia.com/most-popular-algorithms-time-complexity-every-programmer-should-know-free-online-tutorial-course/)
#
# [Industria](https://es.wikipedia.org/wiki/Industria)
#
# [Software entropy](https://en.wikipedia.org/wiki/Software_entropy)
#
# [Economic Complexity and Inflation: An Empirical Analysis](https://link.springer.com/article/10.1007/s11293-021-09727-0)
#
#
# [Desing Patterns in Dynamic Programming](http://www.norvig.com/design-patterns/design-patterns.pdf)
#
# [A Guide to REST-assured](https://www.baeldung.com/rest-assured-tutorial)
#
# [JVM Advent - The JVM Programming Advent Calentar](https://www.javaadvent.com/calendar)
#
# [An Empirical Lower Bound on the Overheads of Production Garbage Collectors](https://arxiv.org/pdf/2112.07880.pdf)
#
# [bucket4j - Java rate limiting library based on token/leaky-bucket algorithm](https://github.com/vladimir-bukhtoyarov/bucket4j)
#
# [Rate Limiting a Spring API Using Bucket4j](https://www.baeldung.com/spring-bucket4j)
#
# Try to set up a distributed in-memory databsae with
#   - Apache Ignite,
#   - Hanzelcast
#   - Try to make an example with rate limiting
#
# [On Understanding Data Abstraction, Revisited](https://www.cs.utexas.edu/~wcook/Drafts/2009/essay.pdf)
#
# [Account (bookkeeping)](https://en.wikipedia.org/wiki/Account_(bookkeeping)):
# - Pages of a ledger, to which changes in value are crhonologically recorded with a **debit** and **credit**.
# - Taxonomy of accounts
#
# [Bank reconciliation](https://en.wikipedia.org/wiki/Bank_reconciliation)
# - Buy the book "Survey of Accounting"
# - Buy a book on "Governmental Accounting"
#
# [How is Java's ThreadLocal implemented under the hood?](https://stackoverflow.com/questions/1202444/how-is-javas-threadlocal-implemented-under-the-hood/15653015)
#
# [Thread.getId() global uniqueness question](https://stackoverflow.com/questions/591627/thread-getid-global-uniqueness-question)
#
# [OBS Studio - Free and open source software for live streaming and screen recording](https://github.com/obsproject/obs-studio)
#
# [What is the native keyword in Java for](https://stackoverflow.com/questions/6101311/what-is-the-native-keyword-in-java-for)
#
# [Lists of typographical symbols and punctuation marks](https://en.wikipedia.org/wiki/List_of_typographical_symbols_and_punctuation_marks)
#
# [What are the Unity Launcher .desktop files?](https://askubuntu.com/questions/40931/where-are-the-unity-launcher-desktop-files)
#
# [Continuations from Generalized Stack Inspection](https://www2.ccs.neu.edu/racket/pubs/icfp05-pcmkf.pdf)
#
# [Project Loom: Fibers and Continuations for the Java Virtual Machine](https://cr.openjdk.java.net/~rpressler/loom/Loom-Proposal.html)
#
# [Continuations in the Java Virtual Machine](https://core.ac.uk/download/pdf/147933197.pdf)
#
# [Control flow](https://en.wikipedia.org/wiki/Control_flow)
#
# [No log4j2 configuration file found. Using default configuration: logging only errors to the console](https://newbedev.com/no-log4j2-configuration-file-found-using-default-configuration-logging-only-errors-to-the-console)
#
# [An Introduction to ThreadLocal in Java](https://www.baeldung.com/java-threadlocal)
#
# [Class ThreadLocal<T>](https://docs.oracle.com/javase/7/docs/api/java/lang/ThreadLocal.html)
#
# [List of model checking tools](https://en.wikipedia.org/wiki/List_of_model_checking_tools)
#
# [Java Pathfinder](https://en.wikipedia.org/wiki/Java_Pathfinder)
#
# [Class Loaders in Java](https://www.baeldung.com/java-classloaders)
#
# [How to use URLClassLoader to load a *.class file?](https://stackoverflow.com/questions/738393/how-to-use-urlclassloader-to-load-a-class-file)
#
# [Class MalformedURLException](https://docs.oracle.com/javase/7/docs/api/java/net/MalformedURLException.html)
#
# [Class Class<T>](https://docs.oracle.com/javase/7/docs/api/java/lang/Class.html)
#
# [Trial Paywall Challenge](https://growth.design/case-studies/trial-paywall-challenge)
#
# [The Phychology of Design - 100 Cognitive Biases & Principles That Effect Your UX](https://growth.design/psychology)
#
# [The Albany NanoTech Complex is the most advanced research facility its kind at any university](https://sunypoly.edu/research/albany-nanotech-complex.html)
#
# [A brief history of code search at GitHub](https://github.blog/2021-12-15-a-brief-history-of-code-search-at-github/)
#
# [A brief history of code search at GitHub](https://github.blog/2021-12-15-a-brief-history-of-code-search-at-github/)
#
# [An Introduction to ThreadLocal in Java]()
#
# [fail safe iterators and weakly consistent iterators](https://stackoverflow.com/questions/20142493/fail-safe-iterators-and-weakly-consistent-iterators)
#
# [pyinstrument - Call stack profiler for Python. Shows why your code is slow](https://github.com/joerick/pyinstrument)
#
# [What is the maximum recursion depth in Python, and how to increase it?](https://stackoverflow.com/questions/3323001/what-is-the-maximum-recursion-depth-in-python-and-how-to-increase-it)
#
# [Amortized analysis](https://en.wikipedia.org/wiki/Amortized_analysis)
#
# [Entropy](https://en.wikipedia.org/wiki/Entropy)
#
# [20 Things I've Learned in my 20 Years as a Software Developer](https://www.simplethread.com/20-things-ive-learned-in-my-20-years-as-a-software-engineer/)
#
#
# "The purpose of abstraction is not to be vague, but to create a new semantic level in which one can be absolutely precise" - Edsger Dijkstra
#
# Everyone should learn a bit modeling and simulation so that they can become appropriately skeptical of it
#
# Software is never finished and business never sleeps
#
# The eight fallacies of distributed computing:
# 1. The network is reliable;
# 2. Latency is zero;
# 3. Bandwidth is infinite;
# 4. The network is secure;
# 5. Topology doesn’t change;
# 6. There is one administrator;
# 7. Transport cost is zero;
# 8. The network is homogeneous.
# — L Peter Deutsch
#
# [Ask HN: What programming tutorial/course/article/blog would you like to see?](https://news.ycombinator.com/item?id=29528305)
#
# [Prevayler - Open Source object persistance libarry for Java](https://prevayler.org/)
#
# [Signal Identification Guide](https://www.sigidwiki.com/wiki/Signal_Identification_Guide)
#
# [Why Tacit Knowledge is More Important Than Deliberate Practice](https://commoncog.com/blog/tacit-knowledge-is-a-real-thing/)
#
#
# [Distributed sequence number generation?](https://stackoverflow.com/questions/2671859/distributed-sequence-number-generation/2671912)
#
# [Distributed UUID Generation](http://horicky.blogspot.com/2007/11/distributed-uuid-generation.html)
#
# [Scalable System Design Patterns](http://horicky.blogspot.com/2010/10/scalable-system-design-patterns.html)
#
# [Scalable System Design](http://horicky.blogspot.com/2008/02/scalable-system-design.html)
#
# [Concurrent computing](https://en.wikipedia.org/wiki/Concurrent_computing)
#
# [Java Distributed Computing](https://docstore.mik.ua/orelly/java-ent/dist/index.htm)
#
# [Preemption (computing)](https://en.wikipedia.org/wiki/Preemption_(computing))
#
# [Concurrent Models for Function Execution](https://arxiv.org/pdf/1111.5170.pdf)
#
# [Models for Concurrency](https://www.cl.cam.ac.uk/~gw104/winskel-nielsen-models-for-concurrency.pdf)
#
# [Different models of concurrency](https://www.tedinski.com/2018/11/06/concurrency-models.html)
#
# [Concurency in Java](https://web.mit.edu/6.005/www/fa14/classes/17-concurrency/)
#
# [Classifying models of concurrency](http://theory.stanford.edu/~rvg/models.html)
#
# [Synchronized keyword internal implementation](https://stackoverflow.com/questions/25949145/synchronized-keyword-internal-implementation)
#
# [Writing a self-modifying x86 factorial program](https://brianstadnicki.github.io/posts/asm-self-modifying-factorial/)
#
# [faiss - A library for efficient similarity search and clustering of dense vectors](https://github.com/facebookresearch/faiss)
#
# [HTTP/3 is Fast](https://requestmetrics.com/web-performance/http3-is-fast)
#
# [Writing a self-modifying x86 factorial program](https://brianstadnicki.github.io/posts/asm-self-modifying-factorial/)
#
# [Plans you're not supposed to talk about](https://dynomight.net/plans/)

# %% [markdown]
# [How to define temporary table values in a subquery in Oracle](https://stackoverflow.com/questions/39782135/how-to-define-temporary-table-values-in-a-subquery-in-oracle)
#
# [I blew $720 on 100 notebooks from Alibaba and started a Paper Website business](https://daily.tinyprojects.dev/paper_website)
#
# [Preventing extreme polarization of political attitudes](https://www.pnas.org/content/118/50/e2102139118)
#
# [drgn: How the Linux Kernel Team at Meta Debugs the Kernel at Scale](https://developers.facebook.com/blog/post/2021/12/09/drgn-how-linux-kernel-team-meta-debugs-kernel-scale/)
#   - [HN Discussion](https://news.ycombinator.com/item?id=29537594)
#   - [Github](https://github.com/osandov/drgn)
#
# [The Scientific Paper is Obsolete](https://news.ycombinator.com/item?id=29545061)
#
# [Argus: Debugging Performance Issues in Modern Desktop Applications with Annotated Causal Tracing](https://www.usenix.org/conference/atc21/presentation/weng)
#
# [Partial functions and total functions](https://www.johndcook.com/blog/2021/12/06/partial-functions/)
#
# [Tamizado](https://es.wikipedia.org/wiki/Tamizado)
#
# [What does a Principal Software Engineer do?](https://blog.devgenius.io/what-does-a-principal-engineer-do-2e6af918ff28)

# %% [markdown]
# [Deployment from Scratch](https://deploymentfromscratch.com/)
#
# [Log4Shell log4j vulnerability (CVE-2021-44228) - cheat-sheet reference guide](https://www.techsolvency.com/story-so-far/cve-2021-44228-log4j-log4shell/)
#
# [Evolución de la Economía de Navarra en el Período 1960-2007](https://www.revistaiuravasconiae.eus/sites/default/files/revista/10.%20IURA_5_231-255.pdf)
#
# [Software bill of materials](https://en.wikipedia.org/wiki/Software_bill_of_materials)
#
# [How Much Does Education Improve Intelligence? A Meta-Analysis](https://labs.la.utexas.edu/tucker-drob/files/2019/08/Ritchie-Tucker-Drob-2018-Psych-Science-How-Much-Does-Education-Improve-Intelligence.pdf)
#
# [Apache  Log4j Vulnerability Shows the Important of SBOMS](https://codenotary.com/blog/apache-log4j-vulnerability-shows-the-importance-of-sboms/)
#
# [Cheating at a Company Group Activity Using Unix Tools](https://medium.com/fundbox-engineering/cheating-at-a-company-group-activity-using-unix-tools-5c1d706f3d58)
#
# [Chemical emitted by babies could make men more docile, women more aggressive](https://www.science.org/content/article/chemical-emitted-babies-could-make-men-more-docile-women-more-aggressive)
#
# [La Economía del País Vasco - Diagnóstico Estratégico](https://www.caixabankresearch.com/sites/default/files/content/file/2016/09/CA-PV-es.pdf)
#
# [Radiografía de la industria manufacturera española](https://www.caixabankresearch.com/es/analisis-sectorial/industria/radiografia-industria-manufacturera-espanola?1074)

# %% [markdown]
# GlowRoot Example
#
# [opentelmetry-java-instrumentation](https://github.com/open-telemetry/opentelemetry-java-instrumentation*)
#
# [Continuations in Java](https://stackoverflow.com/questions/1456083/continuations-in-java)
#
# [Javaflow descargar](https://repo1.maven.org/maven2/com/google/code/maven-play-plugin/org/apache/commons/commons-javaflow/1590792/)
#
# [Arbitary Cide Execution](https://en.wikipedia.org/wiki/Arbitrary_code_execution)
#
# [Plural mayestático](https://es.wikipedia.org/wiki/Plural_mayest%C3%A1tico)
#
# [Remote Code Execution with XStream](https://www.baeldung.com/java-xstream-remote-code-execution)
#
# [Golem](https://es.wikipedia.org/wiki/Golem)
#
# [Arrays of Wisdom of the Ancients](https://shipilev.net/blog/2016/arrays-wisdom-ancients/)
#
# [Get to Know Jakarta MVC](https://www.agilejava.eu/2021/12/09/get-to-know-jakarta-mvc/)
#
# [remote-code-execution-sample](https://github.com/shawnmckinney/remote-code-execution-sample)
#
# [Remote Code Execution (RCE)  Primer For Delopers](https://www.reshiftsecurity.com/remote-code-execution/)
#
# [Continuations in Java A Conversation with Geert Bevin](https://www.artima.com/articles/continuations-in-java)
#
# [Advanced NLP with spaCy](https://course.spacy.io/en)
#
# [A Surprisingly Common Mistake Involving Wildcards & The Find Command](https://blog.robertelder.org/find-command-wildcard-globbing/)
#
# [The the Encapsulate Context Pattern](https://accu.org/journals/overload/12/63/kelly_246/)
#
# [Can you explain the Context design pattern?](https://stackoverflow.com/questions/986865/can-you-explain-the-context-design-pattern)
#
# Para matar los procesos wildfly
# ps -aux | grep wildfly | awk -F' ' '{print $2}' | xargs -I {} echo {}
#
# - Hay un proceso estraño que cuando lo mato, velve a aparecer con wildfly **Interesante(4)**
#
# [Context Object A Design Pattern for Efficient Information Sharing  across Multiple System Layers ](https://www.dre.vanderbilt.edu/~schmidt/PDF/Context-Object-Pattern.pdf)
#
# [Ask HN: I'm looking for a good book on the fundamentals of CS. Any suggestions?](https://news.ycombinator.com/item?id=29498220)
#
# [Parallel Logic Programming: A Sequel](https://arxiv.org/abs/2111.11218)
#
# [Sending files over Samba with comand line](https://unix.stackexchange.com/questions/206415/sending-files-over-samba-with-command-line)
#
# [Samba (software)](https://en.wikipedia.org/wiki/Samba_(software))
#
# [Samba](https://www.samba.org/)
#
# **Software Design Book** : Context Objects
#
# **Man Glob** - Globing is something to explore more off

# %% [markdown]
# **Virtualization**
#
# - Alpine OS
#
# - Ubuntu Core
#
# - Slitaz
#
# - Fedora Core OS
#
# - Tiny Core OS
#
# - [Build a minimal LInux with only Busybox in 1 hour](https://www.youtube.com/watch?v=asnXWOUKhTA)
#
# - QEMU
#
#   - [Gentoo](https://wiki.gentoo.org/wiki/QEMU)
#   - [Arch Linux](https://wiki.archlinux.org/title/QEMU#Network)
#   - []()
#
# - KVM

# %% [markdown]
# [The business of extracting knowledge from academic publications](https://markusstrasser.org/extracting-knowledge-from-literature/)
#
# [Writing a simple 16 bit VM in less than 125 lines of C](https://www.andreinc.net/2021/12/01/writing-a-simple-vm-in-less-than-125-lines-of-c)
#
# [Improving GitHub code search](https://github.blog/2021-12-08-improving-github-code-search/)
#
# [What Design Pattern to use to implement transaction or chaining mechanism](https://stackoverflow.com/questions/33593767/what-design-pattern-to-use-to-implement-transaction-or-chaining-mechanism)
#
# [Recurse Center Day 24: Hacking Go compiler to add a new keyword](https://avi.im/blag/2021/rc-day-24/)
#
# [You Can't Buy Integration](https://martinfowler.com/articles/cant-buy-integration.html)
#
# [Player of Games](https://arxiv.org/abs/2112.03178)
#
# [Postgres, Kafka, and the Mysterious 100 GB](https://www.mattritter.me/?p=398)
#
# [Reintegro](https://economipedia.com/definiciones/reintegro.html)
#
# [Queue Despair: Ordering and Poison Messages](https://www.openmymind.net/Queue-Despair-Ordering-And-Poison-Messages/)

# %% [markdown]
# [How a Kalman filter works, in pictures](https://www.bzarg.com/p/how-a-kalman-filter-works-in-pictures/)
#
# Try to to install
# - [Ubuntu Minimal Image](https://ubuntu.com/server/docs/virtualization-qemu)
# - The idea with this project is to develop small and simples virtual machines to act as a node:
#  - apache zookeper,
#  - apache flink,
#  - apache spark,
#  - apache kafka,
#  - Apache beam,
#  - This is for easy the playing with some systems
#
# [virt-manager](https://virt-manager.org/)
#
# [Unikraft: Fast, Specialized Unikernels the Easy Way](https://arxiv.org/pdf/2104.12721.pdf)
#
# [Use QEMU to Play with Linux Kernel](https://flusp.ime.usp.br/others/use-qemu-to-play-with-linux/)
#
# [Predictive Test Selection](https://research.fb.com/wp-content/uploads/2020/12/Predictive-Test-Selection.pdf)
#
# [Unikernels](http://unikernel.org/)
#
# Se hizo una prueba con Simian tratando de buscar codigo duplicado.
# - Habia muchas cosas interesantes hay, pero habria que realizarce una interfaz.

# %% [markdown]
# [The Reactive Manifesto](https://www.reactivemanifesto.org/)
#
# [Model-driven engineering](https://en.wikipedia.org/wiki/Model-driven_engineering)
#
# [Learning Quick Fixes from Code Repositories](https://dl.acm.org/doi/10.1145/3474624.3474650)
#
# [Testing Firefox more efficiently with machine learning](https://hacks.mozilla.org/2020/07/testing-firefox-more-efficiently-with-machine-learning/)
#
# [How the GNU coreutils are tested](https://www.pixelbeat.org/docs/coreutils-testing.html)
#
# [Guide to Spring 5 WebFlux](https://www.baeldung.com/spring-webflux)
#
# [Web on Reactive Stack](https://docs.spring.io/spring-framework/docs/current/reference/html/web-reactive.html)
#
# [Spring MVC Tutorial](https://www.baeldung.com/spring-mvc-tutorial)
#
# [Getting Started Guide](http://127.0.0.1:8080/auth/realms/master/account/#/)
#
# [How To Set Up a Hadoop 3.2.1 Multi-Node Cluster on Ubuntu 18.04 (2 Nodes)](https://medium.com/@jootorres_11979/how-to-set-up-a-hadoop-3-2-1-multi-node-cluster-on-ubuntu-18-04-2-nodes-567ca44a3b12)
#
# [Apache Kafka](https://kafka.apache.org/)
#
# [Apache Spark](https://spark.apache.org/)
#
# [Apeche Ignite](https://ignite.apache.org/)
#
# [Jakarta Enterprise Beans](https://en.wikipedia.org/wiki/Jakarta_Enterprise_Beans)
#
# [Lazy evaluation](https://en.wikipedia.org/wiki/Lazy_evaluation)
#
# [The actor model in 10 minutes](https://www.brianstorti.com/the-actor-model/)
#
# [How the GNU coreutils are tested](https://www.pixelbeat.org/docs/coreutils-testing.html)
#
# [Quant Connect - Research, Backtest and Trade Your Investments](https://www.quantconnect.com/)
#
# [Leveraging Lambda Expressions for Lazy Evaluation in Java](https://dzone.com/articles/leveraging-lambda-expressions-for-lazy-evaluation)
#
# [Apache Dubbo](https://dubbo.apache.org/en/)
#
# [Apache Airflow](https://airflow.apache.org/)
#
# [Example to Modified github user page](https://github.com/ImGabreuw)
#
# [Question Answering Sofwerare](https://github.com/jonhoo/icebreaker)
# - Try to reuse this functionality, to make questions, answers real-time local tool, that run from my computer.
# - Try to make the level-up more interative
#
# [Java Technical Analysis Library](www.ta4j.com)
#
# [What is the difference between java.lang.Void and void?](https://stackoverflow.com/questions/10839042/what-is-the-difference-between-java-lang-void-and-void/12630665)
#
# [Apache Mesos](https://mesos.apache.org/)
#
# [Programming Paradigms for Dummies: What Every Programmer Should Know](https://www.info.ucl.ac.be/~pvr/VanRoyChapter.pdf)
#
# [Java Concurrency and Multithreading Tutorial](http://tutorials.jenkov.com/java-concurrency/index.html)
#
# [Awaitility is a small Java DSL for synchronizing asynchronous operations](https://github.com/awaitility/awaitility)
#
# [What is a stateful computation?](https://cs.stackexchange.com/questions/52841/what-is-a-stateful-computation)
#
# [Managing a stateful computation system in Haskell](https://stackoverflow.com/questions/6835777/managing-a-stateful-computation-system-in-haskell)
#
# [Performace Tracking on Zigs](https://ziglang.org/perf/)
#
# - Remap vim: (jkl;) -> (hjkl)
# - Unmap (hjkl)
#
# [Taxonomy of Programming Paradims](https://miro.medium.com/max/1200/1*wS8DsmEejvsswkQjNA-BoQ.png)
#
# [nixtla](https://github.com/Nixtla/nixtla)
#
# [¿CÓMO SE DIAGNOSTICA UN ANEURISMA CEREBRAL?](https://hospital.uillinois.edu/es/primary-and-specialty-care/neurolog%C3%ADa-y-neurocirug%C3%ADa/condiciones-neurologicas-que-tratamos/aneurisma-cerebral/como-se-diagnostica-un-aneurisma-cerebral)
#
# [You don’t need an application server to run Jakarta EE applications](https://blogs.oracle.com/javamagazine/post/you-dont-always-need-an-application-server-to-run-jakarta-ee-applications)
#
# [helidon.io](https://helidon.io/)
#
# [Companie to Study](https://www.lightbend.com/)
#
# [Mozart Documentation](http://mozart2.org/mozart-v1/doc-1.4.0/index.html)
#
# Todo:
# - jvtudes
# - Apache Flink
# - Generate dashboard using d3, example `zig programming language`

# %% [markdown]
# [Brazil's Pioneering Solution to Vaccine Shortages](https://www.project-syndicate.org/commentary/brazilian-solution-vaccine-ip-waiver-stuck-at-wto-by-joseph-e-stiglitz-et-al-2021-12)
#
# [“What gets measured gets managed” — It’s wrong and Drucker never said it](https://medium.com/centre-for-public-impact/what-gets-measured-gets-managed-its-wrong-and-drucker-never-said-it-fe95886d3df6)
#
#
# [Async I/O for Dummies](https://www.alwaysrightinstitute.com/async-io-by-example/)
#
# [Nanos](https://nanos.org/)

# %% [markdown]
# systemd  - System
#
# systemcl - System Control
#
# Domain Specific Language in Java
#
# [The Hitchhiker's Guide to javac](https://openjdk.java.net/groups/compiler/doc/hhgtjavac/index.html)
#
# [Further Java](https://www.cl.cam.ac.uk/teaching/1920/FJava/)
#
# [Advanced Topics in Mobile Systems and Mobile Data Machine Learning](https://www.cl.cam.ac.uk/teaching/1920/R249/)
#
# [Concurrent and Distributed Systems](https://www.cl.cam.ac.uk/teaching/1920/ConcDisSys/)
#
# [Programming in C and C++](https://www.cl.cam.ac.uk/teaching/1920/ProgC/)
#
# [Advanced Topics in Computer Systems](https://www.cl.cam.ac.uk/teaching/1920/R01/)
#
# [Cloud Computing](https://www.cl.cam.ac.uk/teaching/1920/CloudComp/)
#
# [Concurrent and Distributed Systems](https://www.cl.cam.ac.uk/teaching/1920/ConcDisSys/)
#
# [Unix](https://www.cl.cam.ac.uk/teaching/1920/UnixTools/unixtools-slides.pdf)
# - [Others](https://www.cl.cam.ac.uk/teaching/1920/UnixTools/notes.pdf)
#
# [Shell Style Guide](https://google.github.io/styleguide/shellguide.html)
#
# [Coreutils - GNU core utilities](https://www.gnu.org/software/coreutils/)
#
# [Concepts in Programming Languages](https://www.cl.cam.ac.uk/teaching/1920/ConceptsPL/)
#
# [Machine Learning and Real-world Data](https://www.cl.cam.ac.uk/teaching/1920/MLRD/)
#
# [Machine Learning and Real-world Data](https://www.cl.cam.ac.uk/teaching/1920/MLRD/)
#
# [Advanced topics in machine learning and natural language processing](https://www.cl.cam.ac.uk/teaching/1920/R250/)
#
# [Java Concurrency](http://tutorials.jenkov.com/java-concurrency/index.html)
#
# [Dining philosophers problem](https://en.wikipedia.org/wiki/Dining_philosophers_problem)
#
# [Multithreaded Programming (POSIX pthreads Tutorial)](https://randu.org/tutorials/threads/)
#
# [Reactive programming](https://en.wikipedia.org/wiki/Reactive_programming)
#
# [Programming paradigm](https://en.wikipedia.org/wiki/Programming_paradigm)
#
# [Fast CSV processing with SIMD](https://nullprogram.com/blog/2021/12/04/)
#
# [Programming Reactive Systems](https://www.coursera.org/learn/scala-akka-reactive)

# %% [markdown]
# **Grand Centarl Dispath**
#
# [Grand Central Dispatch](https://en.wikipedia.org/wiki/Grand_Central_Dispatch)
#
# [Grand Central Dispatch Now Open to All (macresearch.org)](https://news.ycombinator.com/item?id=817416)
#
# [Grand Central Dispatch: The Sleeping Barber Problem (madebysofa.com)](https://news.ycombinator.com/item?id=848476)
#
# [Grand Central Dispatch vs OpenMP](http://www.idryman.org/blog/2012/08/05/grand-central-dispatch-vs-openmp/)
#
# [A quick look at Grand Central Dispatch and Swift 3](https://medium.com/swift-and-ios-writing/a-quick-look-at-gcd-and-swift-3-732bef6e1838#.93w1wfm9o)
#
# [Grand Central Dispatch (GCD) Tutorial in Swift 5](https://www.vadimbulavin.com/grand-central-dispatch-in-swift/)
#
# [Grand Central Dispatch: Threads vs Queues, Sync vs Async, Serial vs Concurrent](https://medium.com/macoclock/grand-central-dispatch-threads-vs-queues-sync-vs-async-serial-vs-concurrent-eb4f0075a21d)
#
# [nickhutchinson / libdispatch](https://github.com/nickhutchinson/libdispatch)

# %% [markdown]
# [How we create](https://linus.zone/latest)
#
# [Java Pathfinder (JPF)](https://github.com/javapathfinder/jpf-core)
#
# [On Parallelism and Concurrency](https://inside.java/2021/11/30/on-parallelism-and-concurrency/)
#
# [Writing a simple Filesystem using Fuse and java 17](https://www.davidvlijmincx.com/posts/writing_a_simple_filesystem_using_fuse_and_java_17/)
#
# [Serverless Java Functions on OpenShift](https://piotrminkowski.com/2021/11/30/serverless-java-functions-on-openshift/)
#
# [Automatically unlocking concurrent builds and fine-grained caching on the JVM with dependency inference](https://blog.pantsbuild.org/automatically-unlocking-concurrent-builds-and-fine-grained-caching-on-the-jvm-with-dependency-inference/)
#
# [5 Mundane Java Performance Tips](https://richardstartin.github.io/posts/5-java-mundane-performance-tricks)
#
# [9 High-Performance Tips when using MySQL with JPA and Hibernate](https://vladmihalcea.com/9-high-performance-tips-when-using-mysql-with-jpa-and-hibernate/)
#
# [The Deadlock Empire Slay dragons, master concurrency!](https://deadlockempire.github.io/)
#
# [Where is the CRDT for syntax trees](https://writer.zohopublic.com/writer/published/grcwy5c699d67b9c444219b60cdb90ccbabc7)
#
# [Zinc Search Engine](https://github.com/prabhatsharma/zinc)

# %% [markdown]
# - Byte Code Weaving
#
# - How to make a great  software engineering environment:
#   - Code search,
#   - Telemetry,
#   - Logs with search,
#   - Play ground,
#   - Code review
#
# - Aprender a utilizar el corrector de vim
#
# - Integrar la guia de commit message a "Mis Notas"
#
# - NotClassDefFoundError
#
#   - Se intento cargar la clase dio un error ejecutando la parte stactc, pero eso cuando la volvemos a usar no da 'NoClassDefFoundError'
#
# - Static final and lazy initialization
#
# - Las variables statics solo se pueda inicializar en 'static initializer'
#
# - How to Use a Language to crate new primitives
#   - Lazy variables in Java,
#   - Closures,
#   - Distributed Processing Abstractions,
#   - Apache Beam,
#   - Apache Flink,
#   - Redis,
#   - DataFlow,
#   - JVM Process,
#
# Event Driven System (Game), The Cherno Project
#
# edit-command-line
#
# Rango de Comprobante
#
# Cuales es el monitor que inserta 'Pago de Deducciones'
#
# Disonancia Cognitiva
#
# Check Result
#
# Predict Result
#
# Go Memory Model
#
# - Reads of a variable in one go routine can be guaranteted to
#
# - Observed values produces by writes to the same variable in a different 'go-routine'
#
# - DAPR,
#
# - Stream Travesal Operations,
#
# - Overlead of 'functional programming' in Java,
#
# - CheckResult,
#
# - Platforms Specific vs Lambda Functions,
#
# - Cartago,
#
# - Crontab para 'avisar' sobre la situación de los recursos de la máquina,

# %% [markdown]
# [The main purpose of this project is to visualize the jmh benchmark result and all the jmh sample code were forked from https://github.com/danielmitterdorfer/benchmarking-experiments.git](https://github.com/henryceowzm/visualize-jmh-benchmark-result)
#
# [Microbenchmarking with Java](https://www.baeldung.com/java-microbenchmark-harness)
#
# [Writing Maintainable Code is a Communication Skill](https://max.engineer/maintainable-code)
#
# [Static context cannot access non-static in Collectors](https://stackoverflow.com/questions/40172551/static-context-cannot-access-non-static-in-collectors)
#
# [How to use shell commands in Makefile](https://stackoverflow.com/questions/10024279/how-to-use-shell-commands-in-makefile)
#
# [Snippet (programming)](https://en.wikipedia.org/wiki/Snippet_(programming))
#
# [Code Snippped](http://fuentes.sigef.gov.do/-/snippets/3/edit)
#
# [Does a lambda expression create an object on the heap every time it's executed?](https://stackoverflow.com/questions/27524445/does-a-lambda-expression-create-an-object-on-the-heap-every-time-its-executed/27524543#27524543)
#
# [Identify duplicates in a List](https://stackoverflow.com/questions/7414667/identify-duplicates-in-a-list)
#
# [How can I convert a char to int in Java?](https://stackoverflow.com/questions/46343616/how-can-i-convert-a-char-to-int-in-java)
#
# []()

# %% [markdown]
# - Try To Remember the Monty Hall Problem
#
# - Formulario Unico -> Deducciones Beneficiario
#
# - Beneficio Formulario
#
# - Beneficiario Deduccion
#
# - ¿Cuales son los formulario con deduccione para ese beneficiario?
#
# - Ordenamiento: En que punto se genrar los ordenamientos
#
# - Como saber si un usuario tiene restriccion por tesoreria
#   -  Yo hice una investigacion sobre el funcionamiento de la seguridad
#
#
# - Tesoreria: Adminsitrator de los flujos monetarios de una empresa
#
# - Problemas al limpiar los Json
#   - JSON Validos, Encodings
#
# - How to improve my skills as a programmer
#  - Tools,
#  - Reading Code,
#  - Replicating Code
#
# [Daniel P. Friedman: A Celebration](https://legacy.cs.indiana.edu/dfried_celebration.html)
#
# [Memorization Strategies](https://learningcenter.unc.edu/tips-and-tools/enhancing-your-memory/)
#
# [11 Methods for Improving Your Memory](https://www.verywellmind.com/great-ways-to-improve-your-memory-2795356)
#
# [A powerful way to improve learning and memory](https://www.apa.org/science/about/psa/2016/06/learning-memory)
#
# [Can brain stimulation boost memory performance?](https://journals.plos.org/plosbiology/article?id=10.1371/journal.pbio.3001404)
#
# [Memory improvement](https://en.wikipedia.org/wiki/Memory_improvement)
#
# [Working memory capacity is enhanced by distributed prefrontal activation and invariant temporal dynamics](https://www.pnas.org/content/116/14/7095)
#
# [How can modify the .code segment at runtime?](https://stackoverflow.com/questions/21990055/how-can-modify-the-code-segment-at-runtime)
#
# [A Runtime Code Modification Method for Application Programs](https://www.kernel.org/doc/ols/2008/ols2008v2-pages-245-254.pdf)
#
# [Is there any way to compile additional code at runtime in C or C++?](https://stackoverflow.com/questions/10564670/is-there-any-way-to-compile-additional-code-at-runtime-in-c-or-c)
#
# [C: How to change my own program in my program in runtime?](https://stackoverflow.com/questions/52238441/c-how-to-change-my-own-program-in-my-program-in-runtime)
#
# [Dynamic Instrumentation of C++ Applications on IA-64](https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.92.1495&rep=rep1&type=pdf)
#
# [API tracing framework for Linux C/C++ applications](https://github.com/yotamr/traces)
#
# [Higher-order thinking](https://www.cloudsavvyit.com/7517/how-to-mount-a-qemu-virtual-disk-image/)
#
# [How to mount a QEMU virtual disk image](https://www.cloudsavvyit.com/7517/how-to-mount-a-qemu-virtual-disk-image/)
#
# [Java Working with bits](https://stackoverflow.com/questions/4032327/java-working-with-bits)
#
# [How to use Sets as keys in Java Maps](https://stackoverflow.com/questions/2393296/how-to-use-sets-as-keys-in-java-maps)
#
# [How to count frequency of characters in a string?](https://stackoverflow.com/questions/6712587/how-to-count-frequency-of-characters-in-a-string)
#
# [Want to create a stream of characters from char array in java](https://stackoverflow.com/questions/31554025/want-to-create-a-stream-of-characters-from-char-array-in-java)
#
# [unikernel](http://unikernel.org/projects/)
#
# [osV](http://osv.io/)
#
# [The big idea around unikernels](https://changelog.com/posts/the-big-idea-around-unikernels)
#
# [How to rest well](https://psyche.co/guides/how-to-rest-well-and-enjoy-a-more-creative-sustainable-life)
