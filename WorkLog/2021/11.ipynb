# %% [markdown]
# **noviembre**

# %% [markdown]
# Monty Hall Problem
#
# [Some guidelines for writing web scrapers](https://cushychicken.github.io/rules-for-web-scrapers/)
#
#
# [Scaling teams like parallel computing systems](https://getsturdy.com/blog/2021-11-29-scaling-teams)
#
# [Risc V greatly underperforms](https://gmplib.org/list-archives/gmp-devel/2021-September/006013.html)
#
# [Class Period](https://docs.oracle.com/javase/8/docs/api/java/time/Period.html)
#
# [How to calculate the number of days in a period?](https://stackoverflow.com/questions/30833582/how-to-calculate-the-number-of-days-in-a-period)
#
# [Functions & DAGs: introducing Hamilton, a microframework for dataframe generation](https://multithreaded.stitchfix.com/blog/2021/10/14/functions-dags-hamilton/)
#
# [The Fastest FizzBuzz Implementation](https://tech.marksblogg.com/fastest-fizz-buzz.html)
#
# [Unix/Linux find and sort by date modified](https://superuser.com/questions/294161/unix-linux-find-and-sort-by-date-modified)
#
# [java.util.Date.getTime](https://stackoverflow.com/questions/13745252/issue-with-java-util-date-gettime)
#
# [Calculating the difference between two Java date instances](https://stackoverflow.com/questions/1555262/calculating-the-difference-between-two-java-date-instances)
#
# [Calculating the difference between two Java date instances](https://stackoverflow.com/questions/1555262/calculating-the-difference-between-two-java-date-instances)
#
# [Java Code for calculating Leap Year](https://stackoverflow.com/questions/1021324/java-code-for-calculating-leap-year)
#
# [Validating UTF-8 bytes (Java edition)](https://lemire.me/blog/2018/10/16/validating-utf-8-bytes-java-edition/)
#
# [How to convert byte\[\] array to String in Java](https://mkyong.com/java/how-do-convert-byte-array-to-string-in-java/)
#
# [Delimiter with Java line of Input](https://stackoverflow.com/questions/17356213/delimiter-with-java-line-of-input)
#
# [Java : How to determine the correct charset encoding of a stream](https://stackoverflow.com/questions/499010/java-how-to-determine-the-correct-charset-encoding-of-a-stream)
#
# [How to check if a file is plain text?](https://stackoverflow.com/questions/6559127/how-to-check-if-a-file-is-plain-text)
#
# [Calculating days between two dates with Java](https://stackoverflow.com/questions/20165564/calculating-days-between-two-dates-with-java)
#
# [How can I stop Java from shortening large double?](https://stackoverflow.com/questions/21955078/how-can-i-stop-java-from-shortening-large-double)
#
# [Leap Year](https://en.wikipedia.org/wiki/Leap_year)
#
# [Class Date](https://docs.oracle.com/javase/7/docs/api/java/util/Date.html)

# %% [markdown]
# [kythe](https://kythe.io/)
#
# [Class Files](https://docs.oracle.com/javase/7/docs/api/java/nio/file/Files.html)
#
# [Check given file is Simple Text File using Java](https://stackoverflow.com/questions/17192770/check-given-file-is-simple-text-file-using-java)
#
# [Summing values of a column using awk command](https://stackoverflow.com/questions/28445020/summing-values-of-a-column-using-awk-command)
#
# [battleships](https://github.com/KanegaeGabriel/battleships)
#
# [The Command Pattern in Java](https://www.baeldung.com/java-command-pattern)

# %% [markdown]
# [24 Pull Requests : Giving back little gifts of code for Christmas](https://medium.com/@eudris/24-pull-requests-giving-back-little-gifts-of-code-for-christmas-3cf6de7c20a0)
#
# [24 pull requests](https://24pullrequests.com/)
#
# [ZoiPer](https://www.zoiper.com/)
#
# [Asterisk](https://www.asterisk.org/)
#
# [DevDocs: API Documentation Browser](https://github.com/freeCodeCamp/devdocs)
#
# [Rust Docs](https://devdocs.io/rust/)
#
# How to make money with blog:
# - [enkov](http://tutorials.jenkov.com/)
# - [mkyong](https://mkyong.com/)
#
#
# [Binance](https://www.binance.com/en)
#
# [Google Software Engineering](https://abseil.io/resources/swe_at_google.2.pdf)
#
# [Google Summer Code Archive 2021](https://summerofcode.withgoogle.com/archive/2021/projects/)
#
# [ElasticSearch, Sphinx, Lucene, Solr, Xapian. Which fits for which usage?](https://stackoverflow.com/questions/2271600/elasticsearch-sphinx-lucene-solr-xapian-which-fits-for-which-usage/2288211)

# %% [markdown]
# [Backtesting Crypto Trading Strategies with Python & C++ 2021](https://www.udemy.com/course/backtesting-crypto-trading-strategies-with-python-c/)
#
# [Cryptocurrency Algorithmic Trading with Python and Binance](https://www.udemy.com/course/backtesting-crypto-trading-strategies-with-python-c/)
#
# [Cryptocurrency Trading: A Comprehensive Survey](https://arxiv.org/pdf/2003.11352.pdf)
#
# [The Complete Cryptocurrency Investment Course](https://www.udemy.com/course/complete-cryptocurrency-investing-course-passive-active)

# %% [markdown]
# [Introducing MBeans](https://docs.oracle.com/javase/tutorial/jmx/mbeans/index.html)
#
# [Do It Yourself (OpenJDK) Garbage Collector](https://shipilev.net/jvm/diy-gc/)
#
# [JVM Garbage Collectors](https://www.baeldung.com/jvm-garbage-collectors)
#
# [Supabase](https://github.com/supabase/supabase)
#
# [100 Lessons from 1 Year of AI Research](https://jetnew.notion.site/100-Lessons-from-1-Year-of-AI-Research-cf431d0f43764750acb83462de06979b)
#
# [Some thoughts on Microservices](https://filipnikolovski.com/posts/thoughts-on-microservices/)
#
# [Backpressure explained — the resisted flow of data through software](https://medium.com/@jayphelps/backpressure-explained-the-flow-of-data-through-software-2350b3e77ce7)

# %% [markdown]
# [GDB: The GNU Project Debugger](https://www.gnu.org/software/gdb/)
#
# [GDB: The User Manuel](https://sourceware.org/gdb/current/onlinedocs/gdb/)
#
# [GDB: Internals](https://sourceware.org/gdb/wiki/Internals)
#
# [Debugging with GDB (GNU Debugger)](https://www.youtube.com/watch?v=iZmhn2Kgqyw)
#
# [CMake](https://cmake.org/)
#
# [Order of operations](https://en.wikipedia.org/wiki/Order_of_operations)
#
# [Tesorería](https://es.wikipedia.org/wiki/Tesorer%C3%ADa)
#
# [POSIX Bracket Expressions](https://www.regular-expressions.info/posixbrackets.html)
#
# [Design Issues for Foreign Function Interfaces](http://web.archive.org/web/20170315194527/http://autocad.xarch.at/lisp/ffis.html)
#
# [Don't Let the Internet Dupe You, Event Sourcing is Hard](https://chriskiehl.com/article/event-sourcing-is-hard)
#
# [Quiz yourself: Functional interfaces and error handling in Java](https://blogs.oracle.com/javamagazine/post/java-functional-interfaces-checked-exceptions)
#
# [Quiz yourself: Break and continue in Java’s for loop](https://blogs.oracle.com/javamagazine/post/java-for-loop-break-continue)

# %% [markdown]
# [The Inherent Limitations of GPT-3](https://news.ycombinator.com/item?id=29382887)
#
# [Music Is Not A Positive Superstimulus – It's A Negative Superstimulus](https://whatismusic.info/blog/MusicIsNotAPositiveSuperstimulusItsANegativeSuperstimulus.html)
#
# [Measuring Software Complexity: What Metrics to Use?](https://thevaluable.dev/complexity-metrics-software/)
#
# [What's The Vim Runtime? A Guide With Examples](https://thevaluable.dev/vim-runtime-guide-example/)
#
# [Programming Side Project Ideas: How To Generate Them](https://thevaluable.dev/generate-programming-side-project-ideas/)
#
# [Deconstructing the Garbage-First Collector∗](https://users.cecs.anu.edu.au/~steveb/pubs/papers/g1-vee-2020.pdf)
#
# [Permutation-Invariant Neural Networks for Reinforcement Learning](https://blog.otoro.net/2021/11/18/attentionneuron/)
#
# [The Blue Book](https://lyz-code.github.io/blue-book/)
# - Examples of dbremont/notes
#
# [activitywatch - Track computer use](https://github.com/ActivityWatch/activitywatch)

# %% [markdown]
# [Cucumber](https://cucumber.io/)
#
# [OpenTTD : open source simulation game based upon Transport Tycoon Deluxe](https://github.com/OpenTTD/OpenTTD)
#
# [Exiting the Vietnam of Programming: Our Journey in Dropping the ORM (in Golang)](https://alanilling.medium.com/exiting-the-vietnam-of-programming-our-journey-in-dropping-the-orm-in-golang-3ce7dff24a0f)
#
# [Is ORM an Anti-Pattern?](https://softwareengineering.stackexchange.com/questions/120321/is-orm-an-anti-pattern)
#
# [eSpeak text to speech](http://espeak.sourceforge.net/)
#
# [Roman citizenship](https://en.wikipedia.org/wiki/Roman_citizenship)
#
# [A small scheme VM, compiler, and REPL in 4k](https://dl.acm.org/doi/10.1145/3486606.3486783)
#  - [Code](https://github.com/udem-dlteam/ribbit)
#
# [notify-send](https://manpages.ubuntu.com/manpages/xenial/man1/notify-send.1.html)
#
# [Embed a Executable Binary in a shell script](https://stackoverflow.com/questions/10491704/embed-a-executable-binary-in-a-shell-script)
#
# [How to base64 encode image in linux bash / shell](https://stackoverflow.com/questions/16918602/how-to-base64-encode-image-in-linux-bash-shell)
#
# [How do you convert a base64 utf-8 encoded string to a binary file from bash?](https://unix.stackexchange.com/questions/454176/how-do-you-convert-a-base64-utf-8-encoded-string-to-a-binary-file-from-bash)
#
# [How to decode an image string using base64 in command line?](https://askubuntu.com/questions/907540/how-to-decode-an-image-string-using-base64-in-command-line)
#
# [How create a temporary file in shell script?](https://unix.stackexchange.com/questions/181937/how-create-a-temporary-file-in-shell-script)
#
# [What does DISPLAY=:0.0 actually mean?](https://unix.stackexchange.com/questions/16815/what-does-display-0-0-actually-mean)
#
# [Theoretical Computer Science Cheat Sheet](https://www.tug.org/texshowcase/cheat.pdf)
#
# [Assigning default values to shell variables with a single command in bash](https://stackoverflow.com/questions/2013547/assigning-default-values-to-shell-variables-with-a-single-command-in-bash)
#
# [Appending to crontab with a shell script on Ubuntu](https://stackoverflow.com/questions/8579330/appending-to-crontab-with-a-shell-script-on-ubuntu)
#
# [How can I get the source directory of a Bash script from within the script itself?](https://stackoverflow.com/questions/59895/how-can-i-get-the-source-directory-of-a-bash-script-from-within-the-script-itsel)
#
# [Bash printf literal verbatim string](https://stackoverflow.com/questions/40423203/bash-printf-literal-verbatim-string)
#
# [How to exclude a directory in find . command](https://stackoverflow.com/questions/4210042/how-to-exclude-a-directory-in-find-command)
#
# [Search for a cronjob with crontab -l](https://stackoverflow.com/questions/14450866/search-for-a-cronjob-with-crontab-l)
#
# [How do I create a crontab through a script](https://stackoverflow.com/questions/4880290/how-do-i-create-a-crontab-through-a-script)
#
# [SL(1): Cure your bad habit of mistyping](https://github.com/mtoyoda/sl)
#
#  - Modified the code, for print forever until recieved a signal to kill and stop
#
# [Cool, but obscure Unix tools (kkovacs.eu)](https://news.ycombinator.com/item?id=2567186)
#
# [A little collection of cool unix terminal/console/curses tools](https://kkovacs.eu/cool-but-obscure-unix-tools)
#
# [Cool, but obscure X11 tools](https://cyber.dabamos.de/unix/x11/)
#
# [Cannot run a GUI app from cron](https://askubuntu.com/questions/471479/cannot-run-a-gui-app-from-cron)

# %% [markdown]
# [gnuspeech](https://www.gnu.org/software/gnuspeech/)
#
# [How do I set up a Cron job?](https://askubuntu.com/questions/2368/how-do-i-set-up-a-cron-job)
#
# [How to show a GUI message box from a bash script in linux?](https://stackoverflow.com/questions/7035/how-to-show-a-gui-message-box-from-a-bash-script-in-linux)
#
# [Java Specialists Superpack 21](https://javaspecialists.teachable.com/p/superpack21?coupon_code=BLACK-FRIDAY-2021)
#
# [Ask HN: How to learn to write a compiler and interpreter?](https://news.ycombinator.com/item?id=18988994)
#
# [What does it mean if JVM is suspended?](https://stackoverflow.com/questions/12474153/what-does-it-mean-if-jvm-is-suspended)
#
# [Transatlantic ping faster than sending a pixel to the screen?](https://superuser.com/questions/419070/transatlantic-ping-faster-than-sending-a-pixel-to-the-screen)
#
# [How do I revert all local changes in Git managed project to previous state?](https://stackoverflow.com/questions/1146973/how-do-i-revert-all-local-changes-in-git-managed-project-to-previous-state)
#
# [Undo a Git merge that hasn't been pushed yet](https://stackoverflow.com/questions/2389361/undo-a-git-merge-that-hasnt-been-pushed-yet)
#
# [Resolve Git merge conflicts in favor of their changes during a pull](https://stackoverflow.com/questions/10697463/resolve-git-merge-conflicts-in-favor-of-their-changes-during-a-pull)
#
# [How can I discard remote changes and mark a file as "resolved"?](https://stackoverflow.com/questions/2073841/how-can-i-discard-remote-changes-and-mark-a-file-as-resolved)
#
# [Is there a way to make Git mark a file as conflicted?](https://stackoverflow.com/questions/2780483/is-there-a-way-to-make-git-mark-a-file-as-conflicted)
#
# [Virtual Log-Structured Storage for High-Performance Streaming](https://hal.inria.fr/hal-03300796/file/virtual_log_KerA30072021.pdf)
#
# [Faster software through register based calling](https://menno.io/posts/golang-register-calling/)
#
# [SymSpell vs. BK-tree: 100x faster fuzzy string search & spell checking](https://towardsdatascience.com/symspell-vs-bk-tree-100x-faster-fuzzy-string-search-spell-checking-c4f10d80a078)
#
# [Transformers from Scratch](https://e2eml.school/transformers.html)

# %% [markdown]
# [MLOps Core](https://ml-ops.org/content/references.html)
#
# [FreeBSD](https://en.wikipedia.org/wiki/FreeBSD)
#
# [aio -- asynchronous I/O - freebsd](https://www.freebsd.org/cgi/man.cgi?query=aio&sektion=4)
#
# [FreeBSD jail](https://es.wikipedia.org/wiki/FreeBSD_jail)
#
# [Docker vs Jails](https://www.reddit.com/r/freebsd/comments/5vfj3w/docker_vs_jails/)
#
# [Linux Containes](https://linuxcontainers.org/)
#
# [Java 8 – Find duplicate elements in a Stream](https://mkyong.com/java8/java-8-find-duplicate-elements-in-a-stream/)
#
# [Java Lambda Expressions Basics](https://dzone.com/articles/java-lambda-expressions-basics)
#
# [Java Lambda Expressions](http://tutorials.jenkov.com/java/lambda-expressions.html)
#
# [java how expensive is a method call](https://stackoverflow.com/questions/6495030/java-how-expensive-is-a-method-call)
#
# [Java 8: performance of Streams vs Collections](https://stackoverflow.com/questions/22658322/java-8-performance-of-streams-vs-collections)
#
# [What is the recommended way to escape HTML symbols in plain Java?](https://stackoverflow.com/questions/1265282/what-is-the-recommended-way-to-escape-html-symbols-in-plain-java)
#
# [JW Archives: How the Java virtual machine performs thread synchronization](https://www.infoworld.com/article/2078602/jw-archives--how-the-java-virtual-machine-performs-thread-synchronization.html)
#
# [Copy a stream to avoid "stream has already been operated upon or closed"](https://stackoverflow.com/questions/23860533/copy-a-stream-to-avoid-stream-has-already-been-operated-upon-or-closed)
#
# [CRLF](https://es.wikipedia.org/wiki/CRLF)
#
# [Guide to Hazelcast with Java](https://www.baeldung.com/java-hazelcast)
#
# [Alpine Linux](https://alpinelinux.org/)
#
# [Racket (programming language)](https://en.wikipedia.org/wiki/Racket_(programming_language))
#
# [The Racket Reference](https://docs.racket-lang.org/reference/index.html)
#
# [Apache Commons](https://commons.apache.org/sandbox/commons-javaflow/tutorial.html)
#
# [Runtime system](https://en.wikipedia.org/wiki/Runtime_system)
#
# [Tail call](https://en.wikipedia.org/wiki/Tail_call)
#
# [Design by contract](https://en.wikipedia.org/wiki/Design_by_contract)
#
# [Is it possible for a computer language to exist without built-in data types?](https://www.quora.com/Is-it-possible-for-a-computer-language-to-exist-without-built-in-data-types)
#
#
# ctlr + k

# %% [markdown]
# [peritext - A CRDT for asynchronous rich-text collaboration, where authors can work independently and then merge their changes](https://github.com/inkandswitch/peritext)
#
# [folly - An open-source C++ library developed and used at Facebook](https://github.com/facebook/folly)
#
# [zstd -  A fast compression algorithm](https://github.com/facebook/zstd)
#
# [proxygen - A collection of C++ HTTP libraries including an easy to use HTTP server](https://github.com/facebook/proxygen)
#
# [CacheLib - Pluggable in-process caching engine to build and scale high performance services](https://github.com/facebook/CacheLib)
#
# [Bistro is a flexible distributed scheduler, a high-performance framework supporting multiple paradigms while retaining ease of configuration, management, and monitoring](https://github.com/facebook/bistro)
#
# [Apache Thrift](https://thrift.apache.org/)
#
# [watchman - A file watching service](https://github.com/facebook/watchman)
#
# [Check if String contains only letters](https://stackoverflow.com/questions/5238491/check-if-string-contains-only-letters)
#
# [AWK And Regular Expressions To Filter Text Or String In Files](https://sysadmin.lk/awk-regular-expressions-filter-text-string-files/)
#
# [More Tiny Habits Recipes](https://tinyhabits.com/1000recipes/)
#
# [ARP cache](https://en.wikipedia.org/wiki/ARP_cache)
#
# [Staged Abstract Interpreters](https://www.cs.purdue.edu/homes/rompf/papers/wei-oopsla19.pdf)
#
# [Representational state transfer](https://en.wikipedia.org/wiki/Representational_state_transfer)
#
# [Golang Internals, Part 1: Main Concepts and Project Structure](https://www.altoros.com/blog/golang-internals-part-1-main-concepts-and-project-structure/)
#
# [Go Design Documents](https://github.com/golang/go/wiki/DesignDocuments)
#
# [Using LSTMs to Model the Java Programming Language](https://arxiv.org/pdf/1908.11685.pdf)
#
# [A simple autosuggest library based on a Java Trie implementation](https://github.com/nomemory/jasuggest)
#
# [Java and scala's type systems are unsound: the existential crisis of null pointers](https://dl.acm.org/doi/10.1145/2983990.2984004)
#
# [wangle](https://github.com/facebook/wangle)
#
# [qemu](https://github.com/qemu/qemu)
#
# [fatal](https://github.com/facebook/fatal)
#
# [SPARTA](https://github.com/facebook/SPARTA)
#
# [reagera](https://github.com/google/reagera)
#
# [benchmark](https://github.com/google/benchmark)
#
# [orbit](https://github.com/google/orbit)
#
# [leveldb](https://github.com/google/leveldb)
#
# [googletest](https://github.com/google/googletest)
#
# [flatbuffers](https://github.com/google/flatbuffers)
#
# [re2](https://github.com/google/re2)
#
# [skia](https://github.com/google/skia)
#
# [snappy](https://github.com/google/snappy)
#
# [liquidfun](https://github.com/google/liquidfun)
#
# [nsjail](https://github.com/google/nsjail)
#
# [zetasql](https://github.com/google/zetasql)
#
# [fruit](https://github.com/google/fruit)
#
# [marl](https://github.com/google/marl)
#
# [libtool](https://www.gnu.org/software/libtool/)
#
# [Cuckoo Index: A Lightweight Secondary Index Structure](https://github.com/google/cuckoo-index)
#
# [InFact: An easy way to construct C++ objects dynamically](https://github.com/google/infact)
#
# [A Java serialization/deserialization library to convert Java Objects into JSON and back](https://github.com/google/gson)
#
# [guava](https://github.com/google/guava)
#
# [guice](https://github.com/google/guice)
#
# [auto](https://github.com/google/auto)
#  - There is a similar project for java - forget the
#
# [agera](https://github.com/google/agera)
#
# [RxJava](https://github.com/ReactiveX/RxJava)
#
# [error-prone](https://github.com/google/error-prone)
#
# [allocation-instrumenter - A Java agent that rewrites bytecode to instrument allocation sites](https://github.com/google/allocation-instrumenter)
#
# [thread-weaver - A Java framework for testing multithreaded code]( https://github.com/google/thread-weaver)
#
# [java-monitoring-client-library - A java idiomatic monitoring client for collecting metrics](https://github.com/google/java-monitoring-client-library)
#
# [Go Does Not Need a Java Style GC](https://erik-engheim.medium.com/go-does-not-need-a-java-style-gc-ac99b8d26c60)
#
# [Bash Patterns I Use Weekly](https://will-keleher.com/posts/5-Useful-Bash-Patterns.html)

# %% [markdown]
# [Foreign Language Training](https://www.state.gov/foreign-language-training/)
#
# [I have 16GB RAM. Do I need 32GB swap?](https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/8/html/managing_storage_devices/getting-started-with-swap_managing-storage-devices)
#
# [Generality—or Not—in a Domain-Specific Language (A Case Study)](https://labs.oracle.com/pls/apex/f?p=94065:10:100821342808417:7110)
#
# [Computers and Hacking: A 50-Year View](https://labs.oracle.com/pls/apex/f?p=94065:10:100821342808417:5793)
#
# [It's Time for a New Old Language](https://labs.oracle.com/pls/apex/f?p=94065:10:100821342808417:4986)
#
# [How to Tell a Compiler What We Think We Know?](https://labs.oracle.com/pls/apex/f?p=94065:10:100821342808417:5352)
#
# [Great Readings for Researchers and Scholars](http://www.cs.virginia.edu/~robins/CS_readings.html)
#
# [What Is a Good Typing Speed Per Minute?](https://smallbusiness.chron.com/good-typing-speed-per-minute-71789.html)
#
# [X server](https://github.com/freedesktop/xorg-xserver)
#
# [Chrome OS D-Bus Best Practices](https://chromium.googlesource.com/chromiumos/docs/+/master/dbus_best_practices.md)
#
# [dbus lightweight ipc mechanism](https://github.com/freedesktop/dbus)
#
# [ioctl - control device](https://man7.org/linux/man-pages/man2/ioctl.2.html)
#
# [evdev](https://en.wikipedia.org/wiki/Evdev)
#
# [Windowing system](https://en.wikipedia.org/wiki/Windowing_system)
#
# [Direct Rendering Manager](https://en.wikipedia.org/wiki/Direct_Rendering_Manager)
#
# [Xlib - C Language X Interface](https://www.x.org/releases/current/doc/libX11/libX11/libX11.html)
#
# [E313 - Compilers (DR.Racket)](https://iucompilercourse.github.io/IU-P423-P523-E313-E513-Fall-2020/)
#
# [Unix/Linux find and sort by date modified](https://superuser.com/questions/294161/unix-linux-find-and-sort-by-date-modified)
#
# [jnode - Code for the JNode operating system](https://github.com/jnode/jnode)
#
# [How is a tag different from a branch in Git? Which should I use, here?](https://stackoverflow.com/questions/4017508/what-is-the-difference-between-tag-and-branch-with-git)

# %% [markdown]
# [Collective Learning and Economic Complexity](https://centerforcollectivelearning.org/complexitycourse)
#
# [Kernel Virtual Machine](https://www.linux-kvm.org/page/Main_Page)
#
# [Qemu ̇ψ Tools]( https://www.qemu.org/docs/master/tools/index.html)
#
# [Qemu](https://gitlab.com/qemu-project/qemu)
#
# [Open Stack](https://www.openstack.org/)
#
# [Proxmox vs OpenStack](https://www.reddit.com/r/Proxmox/comments/lca6cv/proxmox_vs_openstack/)
#
# [How to implement autocomplete on a massive dataset](https://stackoverflow.com/questions/678987/how-to-implement-autocomplete-on-a-massive-dataset)
#
# [Radix tree](https://en.wikipedia.org/wiki/Radix_tree)
#
# [How to run Ubuntu desktop on QEMU?](https://askubuntu.com/questions/884534/how-to-run-ubuntu-desktop-on-qemu)
#
# [littlexm 𝝫 lA very quick and dirty XML library in C](https://github.com/jonahisadev/littlexml)

# %% [markdown]
# Advent of Code
# - [2020](https://adventofcode.com/2020)
# - [2021](https://adventofcode.com/2021)
#
#
# [Notes on Software Development Waste](https://hcarvalhoalves.github.io/software-development-waste/)
#
# [littlexml](https://github.com/jonahisadev/littlexml)

# %% [markdown]
# [Open-source intelligence](https://en.wikipedia.org/wiki/Open-source_intelligence)
#
# [A simplified (in memory) example of Event Sourcing implementation for banking domain](https://github.com/Pragmatists/eventsourcing-java-example)
#
# [Axon Framework and Axon Server (Enterprise) for event-driven microservices](https://axoniq.io/)
#
# [Awesome Domain-Driven Design](https://github.com/heynickc/awesome-ddd)
#
# [Kubernetes](https://en.wikipedia.org/wiki/Kubernetes)
#
# [awesome-algorithmic-trading](https://github.com/joelowj/awesome-algorithmic-trading)
#
# [Awesome-Quant-Machine-Learning-Trading](https://github.com/grananqvist/Awesome-Quant-Machine-Learning-Trading)
#
# [Hash Function](https://en.wikipedia.org/wiki/Hash_function)
#
# [Event stream processing](https://en.wikipedia.org/wiki/Event_stream_processing)
#
# [Event Modeling](https://eventmodeling.org/)
#
# [Builiding Modular monoliths that can scale to microservices](https://www.slideshare.net/dgomezg/builiding-modular-monoliths-that-can-scale-to-microservices-jbcnconf-2021-249860117)
#
# [Event Storming](https://www.eventstorming.com/)
#
# [Social Capital](https://en.wikipedia.org/wiki/Social_capital)
#
# [Interpretations of Probability](https://plato.stanford.edu/entries/probability-interpret/)
#
# [Amazon Ion](https://amzn.github.io/ion-docs/)

# %% [markdown]
# [How can we develop transformative tools for thought?](https://numinous.productions/ttft/)
#
# [Why books donʼt work](https://andymatuschak.org/books/)
#
# [Is tasking developers with creating detailed estimates a waste of company money?](https://iism.org/article/is-tasking-developers-with-creating-detailed-estimates-a-waste-of-company-money-42)
#
# [TIFF - Wikipedia, la enciclopedia libre -  ](https://es.wikipedia.org/wiki/TIFF)
#
# [ZoneMinder - Home -  ](https://zoneminder.com/)
#
# [Worldometer - real time world statistics -  ](https://www.worldometers.info/)
#
# [Pi-hole – Network-wide protection -  ](https://pi-hole.net/)
#
# [Pull requests · tldr-pages/tldr -  ](https://github.com/tldr-pages/tldr/pulls)
#
# [Effekt Language: Home -  ](https://effekt-lang.org/)
#
# [Transformers from scratch | peterbloem.nl -  ](http://peterbloem.nl/blog/transformers)
#
#
#
# [Debugging a weird 'file not found' error](https://jvns.ca/blog/2021/11/17/debugging-a-weird--file-not-found--error/)
#
# [What is the place of libtool, when to use it?](https://stackoverflow.com/questions/29610440/what-is-the-place-of-libtool-when-to-use-it)
#
# [libtool](https://www.gnu.org/software/libtool/manual/libtool.html#Top)
#
# [Nona – A German Search Engine](https://news.ycombinator.com/item?id=29267455)
#
# [Nona ist eine private und werbefreie Suchmaschine](https://www.nona.de/)

# %% [markdown]
# [google/guice: Guice (pronounced 'juice') is a lightweight dependency injection framework for Java 6 and above, brought to you by Google](https://github.com/google/guice)
#
# [Guide to Google Guice](https://www.baeldung.com/guice)
#
# [Java JMH Benchmark Tutorial](https://mkyong.com/java/java-jmh-benchmark-tutorial/) `Me funciono hay que agregar build`
#
# [JMH - Java Microbenchmark Harness](http://tutorials.jenkov.com/java-performance/jmh.html)

# %% [markdown]
# [Examples - OpenAI API](https://beta.openai.com/examples)
#
# [google/caliper: Micro-benchmarking library for Java](https://github.com/google/caliper)
#
# [Dask: Scalable analytics in Python](https://dask.org/)
#
# [What is the difference between Builder Design pattern and Factory Design pattern?](https://stackoverflow.com/questions/757743/what-is-the-difference-between-builder-design-pattern-and-factory-design-pattern)
#
# [A Busy Beaver Champion Program Derived from Scratch](https://nickdrozd.github.io/2021/10/31/busy-beaver-derived.html)
#
# [Consumption of coffee and tea and risk of developing stroke, dementia, and poststroke dementia: A cohort study in the UK Biobank](https://journals.plos.org/plosmedicine/article?id=10.1371/journal.pmed.1003830)
#
# [pxs](https://brooker.co.za/blog/2021/11/16/paxos.html)

# %% [markdown]
# [Video game play is positively correlated with well-being](https://psyarxiv.com/qrjza/)
#
# [bat](https://github.com/sharkdp/bat/releases)
#
# [LISTER PANEL Q&A](https://caseymuratori.com/blog_0023)
#
# [Command-line environment](https://missing.csail.mit.edu/2019/command-line/)
#
# [greenfiled - wayland compositor for the browser](https://github.com/udevbe/greenfield)
#
# Mini-Idea: Obtener datos de la bateria, para ver el consumo de electricidad grabar esa serie de tiempo en influxdb y visualizarla en Grafana
#
# - [Grafana](https://grafana.com/)
#
# - [InfluxDB](https://www.influxdata.com)
#
# [Proxmox Virtual Environment](https://www.proxmox.com/en/proxmox-ve)
# - [Code](https://github.com/proxmox)
#
# [How to Join Multiple Lines Into One](https://www.baeldung.com/linux/join-multiple-lines)
#
# [How do I tell if a regular file does not exist in Bash?](https://stackoverflow.com/questions/638975/how-do-i-tell-if-a-regular-file-does-not-exist-in-bash)
#
# [How to edit command line in full screen editor in ZSH?](https://unix.stackexchange.com/questions/6620/how-to-edit-command-line-in-full-screen-editor-in-zsh)
#
# [Removing non-alphanumeric characters with sed](https://stackoverflow.com/questions/20007288/removing-non-alphanumeric-characters-with-sed)
#
# [How to match whitespace in sed?](https://superuser.com/questions/112834/how-to-match-whitespace-in-sed)
#
# [No more data to read from socket error](https://stackoverflow.com/questions/7839907/no-more-data-to-read-from-socket-error)
#
# [Shell Script to remove double quotes within the column value](https://unix.stackexchange.com/questions/236154/shell-script-to-remove-double-quotes-within-the-column-value)
#
# [What does 2>/dev/null mean?](https://askubuntu.com/questions/350208/what-does-2-dev-null-mean)
#
# [8 Ways to Fine-Tune Your SQL Queries (for Production Databases)](https://www.sisense.com/blog/8-ways-fine-tune-sql-queries-production-databases/)
#
# [chjj/mako - full bitcon implementation in C](https://github.com/chjj/mako)
#
# [Processing billions of events in real time at Twitte](https://blog.twitter.com/engineering/en_us/topics/infrastructure/2021/processing-billions-of-events-in-real-time-at-twitter-)
#
# [Ergonomics of the Symbolics Lisp Machine](http://lispm.de/symbolics-lisp-machine-ergonomics)
#
# [JEP draft: Virtual Threads (Preview)](https://openjdk.java.net/jeps/8277131)
#
# [Are You Smarter Than a Random Expert? The Robust Aggregation of Substitutable Signals](https://arxiv.org/abs/2111.03153)

# %% [markdown]
# [Jerónimo de Uztáriz](https://es.wikipedia.org/wiki/Jer%C3%B3nimo_de_Uzt%C3%A1riz)
#
# [Vale S.A.](https://en.wikipedia.org/wiki/Vale_S.A)
#
# [miparnisari/apuntesfiuba: 📚📚Resúmenes de varias materias para la carrera de Licenciatura en Análisis de Sistemas de la UBA](https://github.com/miparnisari/apuntesfiuba)
#
# [cgit - A hyperfast web frontend for git repositories written in C](https://git.zx2c4.com/cgit/about/)
#
# [Understanding the Linux Graphics Stack](https://bootlin.com/doc/training/graphics/graphics-slides.pdf)
#
# [Tornado and Grand Central Dispatch: a quick look](https://lwn.net/Articles/352978/)
#
# [Summary of the most complete knowledge of the underlying principles of JVM](https://doocs.github.io/jvm/)
#
# [Document type definition](https://en.wikipedia.org/wiki/Document_type_definition)
#
# [Why Programmers Should(n't) Learn Theory](https://www.pathsensitive.com/2021/03/why-programmers-shouldnt-learn-theory.html)
#
# [Free Your Objects, Design Without Regret](https://mailchi.mp/e161d79bfa47/free-your-objects-design-without-regret?e=fb2105760e)
#
# [What are Free Objects?](https://math.stackexchange.com/questions/131389/what-are-free-objects)
#
# [The Renaissance of Code Documentation: Introducing Code Walkthrough](https://www.infoq.com/articles/code-walkthrough-documentation/)
#
# [Optical Storage  The Future of Long Term Data Preservation](https://www.snia.org/sites/default/orig/DSI2015/presentations/ColdStorage/DougFerguson_Optical_Storage_Future%20Long_Term_Data.pdf)

# %% [markdown]
# [What is a monad?](https://stackoverflow.com/questions/44965/what-is-a-monad)
#
# [The Ruby Compiler Survey Rubinius](https://ruby-compilers.com/rubinius/)
#
# [IntelliTrace for Visual Studio Enterprise (C#, Visual Basic, C++)](https://docs.microsoft.com/en-us/visualstudio/debugger/intellitrace?view=vs-2022)
#
# [Experiments for Enough java.lang.String to Hang Ourselves ...](https://github.com/kabutz/string-performance)
#
# [Deconstructing Functional Programming](https://www.infoq.com/presentations/functional-pros-cons/)
#
# [Iniciativas Cluster Colombia](https://www.youtube.com/watch?v=JEBkn7avusk)
#
# [Introduction - The Edition Guide](https://doc.rust-lang.org/edition-guide/introduction.html)
#
# [The Cargo Book](https://doc.rust-lang.org/cargo/index.html)
#
# [Event-driven Applications | Apache Flink](https://nightlies.apache.org/flink/flink-docs-release-1.14/)
#
# [Go (programming language)](https://en.wikipedia.org/wiki/Go_(programming_language))
#
# [Join-pattern](https://en.wikipedia.org/wiki/Join-pattern)
#
# [Programming with Something](https://tomstu.art/programming-with-something)
#
# [Twister2 · High Performance Data Analytics](https://twister2.org/)
#
# [List of concurrent and parallel programming languages](https://en.wikipedia.org/wiki/List_of_concurrent_and_parallel_programming_languages)
#
# [Comparison of programming languages](https://en.wikipedia.org/wiki/Comparison_of_programming_languages)
#
# [Async Cancellation I](https://blog.yoshuawuyts.com/async-cancellation-1/)
#
# [file URI scheme](https://en.wikipedia.org/wiki/File_URI_scheme)

# %% [markdown]
# [Introduction to Special Relativity](https://ocw.mit.edu/courses/physics/8-20-introduction-to-special-relativity-january-iap-2021/)
#
# [Distributing binary with dependencies in Linux](https://superuser.com/questions/164767/distributing-binary-with-dependencies-in-linux)
#
# [CIVETS](https://en.wikipedia.org/wiki/CIVETS)
#
# [Welcome to the GHC User’s Guide](https://downloads.haskell.org/~ghc/latest/docs/html/users_guide/index.html)
#
# [The Haskell Tool Stack](https://docs.haskellstack.org/en/stable/README/)
#
# [How to write a Haskell program](https://wiki.haskell.org/How_to_write_a_Haskell_program)
#
# [Learning Haskell](https://www.haskell.org/documentation/)
#
# [Real World Haskell](http://book.realworldhaskell.org/read/)
#
# [CIS 194: Introduction to Haskell ](https://www.seas.upenn.edu/~cis194/fall16/)
#
# [Wayland Architecture](https://wayland.freedesktop.org/architecture.html)
#
# [Why is Wayland better?](https://askubuntu.com/questions/11537/why-is-wayland-better)
#
# [Logs and tracing: not just for production, local development too](https://incident.io/blog/tracing)
#
# [Initializing a final variable in a method called from class constructor](https://stackoverflow.com/questions/49236300/initializing-a-final-variable-in-a-method-called-from-class-constructor)
#
# [How to force a class to be initialised?](https://stackoverflow.com/questions/3560103/how-to-force-a-class-to-be-initialised)
#
# [Can a final variable be initialized when an object is created?](https://stackoverflow.com/questions/18584674/can-a-final-variable-be-initialized-when-an-object-is-created)
#
# [ Why does .class not invoke the static block in a Class?](https://stackoverflow.com/questions/39504847/why-does-class-not-invoke-the-static-block-in-a-class)
#
# [Why am I getting a NoClassDefFoundError in Java?](https://stackoverflow.com/questions/34413/why-am-i-getting-a-noclassdeffounderror-in-java)
#
#
# [Git Techniques at Risk Ledger](https://riskledger.com/blog/git-basics-at-risk-ledger/)
#
# [Logs and tracing: not just for production, local development too](https://incident.io/blog/tracing)
#
# [The Ruby Compiler Survey](https://ruby-compilers.com/rubinius/)
#
# [java 8 - Lazy field initialization with lambdas](https://stackoverflow.com/questions/29132884/lazy-field-initialization-with-lambdas)
#
# [Java static code analysis: Lazy initialization of "static" fields should be "synchronized"](https://rules.sonarsource.com/java/RSPEC-2444)
#
# [LCK10-J. Use a correct form of the double-checked locking idiom - SEI CERT Oracle Coding Standard for Java](https://wiki.sei.cmu.edu/confluence/display/java/LCK10-J.+Use+a+correct+form+of+the+double-checked+locking+idiom)
#
# [Chapter 12. Execution](https://docs.oracle.com/javase/specs/jls/se8/html/jls-12.html#jls-12.4.1)
#
# [Throwable (Java Platform SE 7 )](https://docs.oracle.com/javase/7/docs/api/java/lang/Throwable.html)
#
# [AtomicBoolean (Java Platform SE 7 )](https://docs.oracle.com/javase/7/docs/api/java/util/concurrent/atomic/AtomicBoolean.html)
#
# [java - How to handle transient Class Loading error such as thread interrupt](https://stackoverflow.com/questions/56866573/how-to-handle-transient-class-loading-error-such-as-thread-interrupt)
#
# [BurntSushi/ripgrep: ripgrep recursively searches directories for a regex pattern while respecting your gitignore](https://github.com/BurntSushi/ripgrep)
#
# [Class loading exceptions](https://www.ibm.com/docs/en/was-nd/8.5.5?topic=loaders-class-loading-exceptions)
#
# [How can I use grep to show just filenames on Linux?](https://stackoverflow.com/questions/6637882/how-can-i-use-grep-to-show-just-filenames-on-linux)
#
# [zsh - Conditional Expressions](https://www.csse.uwa.edu.au/programming/linux/zsh-doc/zsh_11.html)
#
# [Types and Programming Languages (2002) ](https://news.ycombinator.com/item?id=29182480)
#
# [Lecture Notes on Parametric Polymorphism](https://www.cs.cmu.edu/~fp/courses/15814-f18/lectures/11-polymorphism.pdf)
#
# [SFI AutoShip - NTNU](https://www.ntnu.edu/sfi-autoship)
# *  8 Years Research Program to help `Norway players` to play a key role in the global `autonomous ships market`
#
# [How to copy files from one machine to another using ssh](https://unix.stackexchange.com/questions/106480/how-to-copy-files-from-one-machine-to-another-using-ssh)
#
# [Welcome to freedesktop.org](https://www.freedesktop.org/wiki/)
#
# [EXTRACT (datetime)](https://docs.oracle.com/cd/B19306_01/server.102/b14200/functions050.htm)

# %% [markdown]
# [command line - How to set a proxy for terminal?](https://askubuntu.com/questions/583797/how-to-set-a-proxy-for-terminal)
#
# [bash - replace all non alphanumerics with underscore](https://unix.stackexchange.com/questions/473514/replace-all-non-alphanumerics-with-underscore)
#
# [Foreign Function Interface](https://doc.rust-lang.org/nomicon/ffi.html)
#
# [Building a Single-Threaded Web Server](https://doc.rust-lang.org/book/ch20-01-single-threaded.html)
#
# [7.1 Connecting to MySQL Using the JDBC](https://dev.mysql.com/doc/connector-j/8.0/en/connector-j-usagenotes-connect-drivermanager.html)
#
# [MySQL - Data Types](https://www.tutorialspoint.com/mysql/mysql-data-types.htm)
#
# [How to run unit test with Maven](https://mkyong.com/maven/how-to-run-unit-test-with-maven/)
#
# [Runlevel](https://en.wikipedia.org/wiki/Runlevel)
#
# [How To Check The Runlevel In Linux](https://ostechnix.com/check-runlevel-linux/)
#
# [Why Alt+F2 Is the Ultimate Linux Keyboard Shortcut](https://www.makeuseof.com/tag/alt-f2-ultimate-linux-keyboard-shortcut/)
#
# [7.1 Connecting to MySQL Using the JDBC DriverManager Interface](https://dev.mysql.com/doc/connector-j/8.0/en/connector-j-usagenotes-connect-drivermanager.html)
#
# [Class DriverManager](https://docs.oracle.com/javase/8/docs/api/java/sql/DriverManager.html)
#
# [MySQL refuses to accept remote connections](https://serverfault.com/questions/586651/mysql-refuses-to-accept-remote-connections)
#
# [How to bind MySQL server to more than one IP address?](https://serverfault.com/questions/139323/how-to-bind-mysql-server-to-more-than-one-ip-address)
#
# [4.2.2.2 Using Option Files](https://dev.mysql.com/doc/refman/8.0/en/option-files.html)
#
# [B.3.2.2 Can't connect to local MySQL server](https://dev.mysql.com/doc/refman/8.0/en/can-not-connect-to-server.html)
#
# [How to check what port mysql is running on](https://serverfault.com/questions/116100/how-to-check-what-port-mysql-is-running-on)
#
# [How do I find out what my IP Address of my MySQL host is?](https://serverfault.com/questions/129635/how-do-i-find-out-what-my-ip-address-of-my-mysql-host-is)
#
# [Changing host permissions for MySQL users](https://serverfault.com/questions/483339/changing-host-permissions-for-mysql-users)
#
# [How can I resolve a hostname to an IP address in a Bash script?](https://unix.stackexchange.com/questions/20784/how-can-i-resolve-a-hostname-to-an-ip-address-in-a-bash-script)
#
# [How to check what port mysql is running on](https://serverfault.com/questions/116100/how-to-check-what-port-mysql-is-running-on)
#
# [Creating a Linux service with systemd](https://medium.com/@benmorel/creating-a-linux-service-with-systemd-611b5c8b91d6)
#
# [MySQL: Access denied for user 'test'@'localhost' (using password: YES) except root user](https://stackoverflow.com/questions/20353402/mysql-access-denied-for-user-testlocalhost-using-password-yes-except-ro)
#
# [How do I turn off the mysql password validation?](https://stackoverflow.com/questions/36301100/how-do-i-turn-off-the-mysql-password-validation)
#
# [Adding new host entries to existing mysql users](https://stackoverflow.com/questions/19281305/adding-new-host-entries-to-existing-mysql-users)
#
# [6.2.4 Specifying Account Names](https://dev.mysql.com/doc/refman/5.7/en/account-names.html)
#
# [Create and edit users in MySQL](https://docs.rackspace.com/support/how-to/create-and-edit-users-in-mysql/)
#
# [How to Delete Millions of Rows Fast with SQL](https://blogs.oracle.com/sql/post/how-to-delete-millions-of-rows-fast-with-sql)
#
# [How to print to stderr in Python?](https://stackoverflow.com/questions/5574702/how-to-print-to-stderr-in-python)
#
# [Running programs in parallel using xargs](https://stackoverflow.com/questions/28357997/running-programs-in-parallel-using-xargs)
#
# [What is Velocity?](https://velocity.apache.org/)
#
# [CGLIB and Java Security](https://github.com/cglib/cglib/wiki/How-To)
#
# [Guice (pronounced 'juice') is a lightweight dependency injection framework for Java 6 and above, brought to you by Google](https://github.com/google/guice)
#
# [cglib](https://github.com/cglib/cglib/wiki)
#
# [Javassist](https://www.javassist.org/)
#
# [Apache Commons OGNL - Object Graph Navigation Library](https://commons.apache.org/proper/commons-ognl/)

# %% [markdown]
# [Home - SDKMAN! the Software Development Kit Manager](https://sdkman.io/)
#
# [Improving a Machine Learning System (Part 1 - Broken Abstractions)](https://danshiebler.com/2021-11-06-ml-systems-1/)
#
# [mysql/mysql-connector-java/8.0.27](https://repo1.maven.org/maven2/mysql/mysql-connector-java/8.0.27/)
#
# [zsh](https://sourceforge.net/p/zsh/code/ci/master/tree/)
#
# [NAP Framework](https://www.napframework.com/)
#
# [How We Saved Millions in SSD Costs by Upgrading Our Filesystem](https://heap.io/blog/how-we-saved-millions-in-ssd-costs-by-upgrading-our-filesystem)
#
#
# [Why Alt+F2 Is the Ultimate Linux Keyboard Shortcut](https://www.makeuseof.com/tag/alt-f2-ultimate-linux-keyboard-shortcut/)
#
# [ufrisk/pcileech: Direct Memory Access (DMA) Attack Software](https://github.com/ufrisk/pcileech)
#
# [Foreign function interface](https://en.wikipedia.org/wiki/Foreign_function_interface)
#
# [memflow - physical memory introspection library](https://memflow.github.io/#/home)
#
# [ufrisk/pcileech: Direct Memory Access (DMA) Attack Software](https://github.com/ufrisk/pcileech)
#
# [Rust (programming language)](https://en.wikipedia.org/wiki/Rust_(programming_language))
#
# [Tokio - An asynchronous Rust runtime](https://tokio.rs/)
#
# [Building a Single-Threaded Web Server - The Rust Programming Language](https://doc.rust-lang.org/book/ch20-01-single-threaded.html)

# %% [markdown]
# [Game Hacking Academy](https://gamehacking.academy/GameHackingAcademy.pdf)
#
# [Introduction to Special Relativity](https://ocw.mit.edu/courses/physics/8-20-introduction-to-special-relativity-january-iap-2021/)
#
# [tutorials/persistence-modules/spring-mybatis/src/test/java/com/baeldung at master · eugenp/tutorials -  ](https://github.com/eugenp/tutorials/tree/master/persistence-modules/spring-mybatis/src/test/java/com/baeldung)
#
# [java - Can MyBatis create the database schema? - Stack Overflow -  ](https://stackoverflow.com/questions/25282540/can-mybatis-create-the-database-schema)
#
# [How To Create a New User and Grant Permissions in MySQL | DigitalOcean -  ](https://www.digitalocean.com/community/tutorials/how-to-create-a-new-user-and-grant-permissions-in-mysql)
#
# [Why can Java not connect to MySQL 5.7 after the latest JDK update and how should it be fixed? (ssl.SSLHandshakeException: No appropriate protocol) - Stack Overflow -  ](https://stackoverflow.com/questions/67332909/why-can-java-not-connect-to-mysql-5-7-after-the-latest-jdk-update-and-how-should)
#
# [How To Install MySQL on Ubuntu 20.04 | DigitalOcean -  ](https://www.digitalocean.com/community/tutorials/how-to-install-mysql-on-ubuntu-20-04)
#
# [Running a Spring Boot App with Maven vs an Executable Jar | Baeldung -  ](https://www.baeldung.com/spring-boot-run-maven-vs-executable-jar)
#
# [spring-boot-example/application.properties at master · shangguanhao/spring-boot-example -  ](https://github.com/shangguanhao/spring-boot-example/blob/master/mybatis/src/main/resources/application.properties)
#
# [Spring Boot integrates Mybatis and completes CRUD operations -  ](https://programmer.help/blogs/spring-boot-integrates-mybatis-and-completes-crud-operations.html)
#
# [mybatis/mybatis-3: MyBatis SQL mapper framework for Java -  ](https://github.com/mybatis/mybatis-3)

# %% [markdown]
# [List](https://docs.oracle.com/javase/8/docs/api/java/util/List.html)
#
# [InterruptedException](https://docs.oracle.com/javase/7/docs/api/java/lang/InterruptedException.html)
#
# [Runnable](https://docs.oracle.com/javase/7/docs/api/java/lang/Runnable.html)
#
# [Callable](https://docs.oracle.com/javase/7/docs/api/java/util/concurrent/Callable.html)
#
# [TimeUnit](https://docs.oracle.com/javase/7/docs/api/java/util/concurrent/TimeUnit.html)
#
# [Executors](https://docs.oracle.com/javase/7/docs/api/java/util/concurrent/Executors.html)
#
# [ExecutorService](https://docs.oracle.com/javase/7/docs/api/java/util/concurrent/ExecutorService.html)
#
# [Fork/Join](https://docs.oracle.com/javase/tutorial/essential/concurrency/forkjoin.html)
#
# [Java Concurrency and Multithreading Tutorial](http://tutorials.jenkov.com/java-concurrency/index.html)
#
# [Java concurrency](https://en.wikipedia.org/wiki/Java_concurrency)
#
# [Fork–join model](https://en.wikipedia.org/wiki/Fork%E2%80%93join_model)
#
# [A Guide to the Java ExecutorService](https://www.baeldung.com/java-executor-service-tutorial)

# %% [markdown]
# [Flightradar24: Live Flight Tracker](https://www.flightradar24.com/15.43,91.3/3)
#
# [mybatis/mybatis-3: MyBatis SQL mapper framework for Java](https://github.com/mybatis/mybatis-3)
#
# [mrniko/netty-socketio: Socket.IO server implemented on Java](https://github.com/mrniko/netty-socketio)
#
# [Maven Quickstart Archetype – Maven Quickstart Archetype](https://maven.apache.org/archetypes/maven-archetype-quickstart/)
#
# [Java-WebSocket by TooTallNate ](http://tootallnate.github.io/Java-WebSocket/)

# %% [markdown]
# [Websockets and scalability](https://stackoverflow.com/questions/47268038/websockets-and-scalability)
#
# [The WebSocket Protocol](https://datatracker.ietf.org/doc/html/rfc6455)
#
# [vi/websocat: Command-line client for WebSockets, like netcat (or curl) for ws:// with advanced socat-like functions](https://github.com/vi/websocat)
#
# [WebSocket](https://en.wikipedia.org/wiki/WebSocket)
#
# [Comet (programming)](https://en.wikipedia.org/wiki/Comet_%28programming%29)
#   - Server-send events
#   - long polling
#
# [BDD Testing & Collaboration Tools for Teams](https://cucumber.io/)
#
# [TooTallNate/Java-WebSocket: A barebones WebSocket client and server implementation written in 100% Java](https://github.com/TooTallNate/Java-WebSocket)
#
# [mstrobel/procyon: Procyon is a suite of Java metaprogramming tools, including a rich reflection API, a LINQ-inspired expression tree API for runtime code generation, and a Java decompiler](https://github.com/mstrobel/procyon)
#
# [Futures and promises](https://en.wikipedia.org/wiki/Futures_and_promises)

# %% [markdown]
# [José María Arguedas](https://en.wikipedia.org/wiki/Jos%C3%A9_Mar%C3%ADa_Arguedas)
#
# [Elite Underproduction](https://troynikov.io/elite-underproduction/)
#
# [Chaining, or Why You Should Stop Returning Void](http://jamie-wong.com/2012/02/01/stop-returning-void/)
#
# [ReactiveX](http://reactivex.io/)
#
# [Avian](https://readytalk.github.io/avian/)
#
# [Wobaka | Simple CRM and Sales Automation for Small Teams](https://wobaka.com/)
#
# [How does a Game Engine work? An Overview — Harold Serrano - Game Engine Developer](https://www.haroldserrano.com/blog/how-do-i-build-a-game-engine)
#
# [The Joy of Concurrent Logic Programming](http://www.call-with-current-continuation.org/articles/the-joy-of-concurrent-logic-programming.txt)
#
# [The illustrated guide to a Ph.D](https://matt.might.net/articles/phd-school-in-pictures/)
#
# [How To Learn Stuff Quickly](https://www.joshwcomeau.com/blog/how-to-learn-stuff-quickly/#%2F%2F%2F%2F%2F%2F/)
#
# [Instituto de Innovación y Transferencia de Tecnología ](https://i2t2.org.mx/economia-sociedad-conocimiento.php)
#
# [Israel Innovation](https://innovationisrael.org.il/en/)
#
# [Khazanah Nasional Berhad](https://www.khazanah.com.my/)
#
# [Research, Innovation and Enterprise Council (RIEC)](https://www.nrf.gov.sg/about-nrf/governance/research-innovation-and-enterprise-council-(riec))
#
# [Temasek](https://www.temasek.com.sg/en/index)
#
# [Singapore Technologies Engineering | ST Engineering](https://www.stengg.com/)
#
# [SGInnovate Helps Entrepreneurial Scientists Build Deep Tech Startups](https://www.sginnovate.com/)

# %% [markdown]
# [vim-airline
# Public](https://github.com/vim-airline/vim-airline)
#
# [Accretion (astrophysics)](https://en.wikipedia.org/wiki/Accretion_(astrophysics))
#
# [ohmyz](https://ohmyz.sh/)
#
# [Xmonad/Frequently asked questions - HaskellWiki](https://wiki.haskell.org/Xmonad/Frequently_asked_questions)
#
# [xmobar - a minimalistic status bar](https://xmobar.org/)
#
# [Compiler Explorer](https://godbolt.org/)
#
# [Dotfiles](https://gitlab.com/dwt1/dotfiles)
#
# [“What gets measured gets managed” — It’s wrong and Drucker never said it | by Danny Buerkli | Centre for Public Impact](https://medium.com/centre-for-public-impact/what-gets-measured-gets-managed-its-wrong-and-drucker-never-said-it-fe95886d3df6)
#
# [Latin America and its Era of Discontent? - CERAWeek Conversations](https://ondemand.ceraweek.com/cwc/detail/video/6266404201001?hsid=b8ab5511-7f9f-46b7-be23-dbadf072613f)
#
# [The Rust Programming Language - The Rust Programming Language](https://doc.rust-lang.org/book/title-page.html)
#
# [shell - How can I find broken symlinks - Unix & Linux Stack Exchange](https://unix.stackexchange.com/questions/34248/how-can-i-find-broken-symlinks)
#
# [symlink - How to find all symbolic links pointing to any file/directory inside a given directory - Unix & Linux Stack Exchange](https://unix.stackexchange.com/questions/301717/how-to-find-all-symbolic-links-pointing-to-any-file-directory-inside-a-given-dir)

# %% [markdown]
# [Understand foreign function interface (FFI) and language binding](https://stackoverflow.com/questions/5440968/understand-foreign-function-interface-ffi-and-language-binding)
#
#
# [Foreign function interface](https://en.wikipedia.org/wiki/Foreign_function_interface)
#
# [A list of cache providers](https://blog.frankel.ch/choose-cache/2/)
#
# [How loveholidays used a Cloud Native event-driven system to cut hotel content publishing time from 5 days to less than 1 minute](https://tech.loveholidays.com/how-loveholidays-used-cloud-native-event-driven-system-to-cut-hotel-content-publishing-time-from-5-690f690d1b5)
#
# [Consider Adding Thread Affinity](https://mail.openjdk.java.net/pipermail/loom-dev/2020-December/001898.html)
#
# [Threaded code](https://en.wikipedia.org/wiki/Threaded_code)
#
# [Is it possible to create a function dynamically, during runtime in C++? - Stack Overflow](https://stackoverflow.com/questions/11016078/is-it-possible-to-create-a-function-dynamically-during-runtime-in-c)
#
# [Threaded Code](http://home.claranet.nl/users/mhx/Forth_Bell.pdf)
#
# [ThreadPoolExecutor.java](https://github.com/openjdk/jdk/blob/master/src/java.base/share/classes/java/util/concurrent/ThreadPoolExecutor.java)
#
# [Favorite Sayings - John Ousterhout](https://web.stanford.edu/~ouster/cgi-bin/sayings.php)
#
# [In C, how do you know if the dynamic allocation succeeded?](https://lemire.me/blog/2021/10/27/in-c-how-do-you-know-if-the-dynamic-allocation-succeeded/)
#
# [Things to say when you are losing a tech argument](http://web.archive.org/web/20050131033632/http://www.skirsch.com/humor/techarg.htm)
#
# [An Incremental Approach to Compiler Construction](http://scheme2006.cs.uchicago.edu/11-ghuloum.pdf)
#
# [The Promise and Paradox of Decentralization](https://www.thediff.co/p/the-promise-and-paradox-of-decentralization)
#
# [UPDATE statement](https://docs.oracle.com/javadb/10.8.3.0/ref/rrefsqlj26498.html)
#
# [Oracle EXTRACT Function Demonstrated with Practical Examples](https://www.oracletutorial.com/oracle-date-functions/oracle-extract/)
#
# [TO_CHAR (datetime)](https://docs.oracle.com/cd/B19306_01/server.102/b14200/functions180.htm)
#
# [Vim Spell-Checking](https://thoughtbot.com/blog/vim-spell-checking)
#
# [Vim documentation: spell](http://vimdoc.sourceforge.net/htmldoc/spell.html)
#
# [Spanish spelling checker for Vim?](https://stackoverflow.com/questions/16778016/spanish-spelling-checker-for-macvim)
#
# [On autoloading](https://erock.io/2021/11/01/on-autoloading.html)
#
# [What Memory Model Should the Rust Language Use?](https://paulmck.livejournal.com/66175.html)
#
# [How to learn compilers: LLVM Edition - Low Level Bits](https://lowlevelbits.org/how-to-learn-compilers-llvm-edition/)
#
# [What are the realtime communication protocols available for the web?](https://stackoverflow.com/questions/14499282/what-are-the-realtime-communication-protocols-available-for-the-web)
#
# [Grand Central Dispatch](https://en.wikipedia.org/wiki/Grand_Central_Dispatch)
#
# [apple/swift-corelibs-libdispatch: The libdispatch Project, (a.k.a. Grand Central Dispatch), for concurrency on multicore hardware](https://github.com/apple/swift-corelibs-libdispatch)
#
# [libdispatch for Linux by nickhutchinson](http://nickhutchinson.github.io/libdispatch/)
#
# [Using Grand Central Dispatch on macOS](https://apple.github.io/swift-corelibs-libdispatch/tutorial/)
#
# [The JVM Architecture Explained](https://dzone.com/articles/jvm-architecture-explained)
#
#
# [How we deconstructed the Postgres planner to find indexing opportunities](https://pganalyze.com/blog/deconstructing-the-postgres-planner)
#
#
# [bombomby/optick: C++ Profiler For Games](https://github.com/bombomby/optick)

# %% [markdown]
# [What are the realtime communication protocols available for the web?](https://stackoverflow.com/questions/14499282/what-are-the-realtime-communication-protocols-available-for-the-web)
#
# [Linux x86 Program Start Up](http://dbp-consulting.com/tutorials/debugging/linuxProgramStartup.html)
#
# [Code Spell Checker](https://marketplace.visualstudio.com/items?itemName=streetsidesoftware.code-spell-checker)
#
# [Evaluating Large Language Models Trained on Code](https://arxiv.org/pdf/2107.03374.pdf)
#
# [GitHub Copilot AI Spawns Open Source Alternatives -- Visual Studio Magazine](https://visualstudiomagazine.com/articles/2021/09/24/github-copilot-alternatives.aspx)
#
# [GitHub Copilot · Your AI pair programmer](https://copilot.github.com/)
#
# [Creando un microservicio CRUD con Java 11, Jakarta EE (Payara Micro) y GitHub Copilot](https://www.youtube.com/watch?v=v7E69x7BlA8)
#
# [Computational Memory Lab](http://memory.psych.upenn.edu/Main_Page#Computational_models_of_human_memory)
#
#
# [Bentley's Rules from Writing Efficient Programs](http://www.dsc.ufcg.edu.br/~jacques/cursos/2003.2/gr/recursos/Bentley%27s%20Rules%20from%20Writing%20Efficient%20Programs.htm)

# %% [markdown]
# [OCaml Labs Consultancy](https://ocamllabs.io/)
#
# [postgres/knapsack.c at master · postgres/postgres](https://github.com/postgres/postgres/blob/master/src/backend/lib/knapsack.c)
#
# [Build optimized websites quickly, focus on your content](https://docusaurus.io/)
#
# [How can I check if a directory exists in a Bash shell script?](https://stackoverflow.com/questions/59838/how-can-i-check-if-a-directory-exists-in-a-bash-shell-script)
#
# [Arrow (symbol)](https://en.wikipedia.org/wiki/Arrow_(symbol))
#
# [What could Go wrong with a mutex, or the Go profiling story](https://evilmartians.com/chronicles/what-could-go-wrong-with-a-mutex-or-the-go-profiling-story)
#
# [The boring technology behind a one-person internet company](https://www.listennotes.com/blog/the-boring-technology-behind-a-one-person-23/)
#
# [Apache Thrift](https://thrift.apache.org/)
#
# [class - What is the use of ClassValue<T> in java?](https://stackoverflow.com/questions/38180687/what-is-the-use-of-classvaluet-in-java?noredirect=1&lq=1)
#
# [String.format() 3x faster in Java 17](https://www.javaspecialists.eu/archive/Issue294-String.format-3x-faster-in-Java-17.html)
#
# [How X Window Managers Work, and How to Write One](https://news.ycombinator.com/item?id=29091070)
#
# - [How X Window Managers Work, And How To Write One (Part I)](https://jichu4n.com/posts/how-x-window-managers-work-and-how-to-write-one-part-i/)
#
# - [How X Window Managers Work, And How To Write One (Part II)](https://jichu4n.com/posts/how-x-window-managers-work-and-how-to-write-one-part-ii/)
#
# - [How X Window Managers Work, And How To Write One (Part III)](https://jichu4n.com/posts/how-x-window-managers-work-and-how-to-write-one-part-iii/)
#
# [jichu4n/bash-command-timer: Bash extension for printing execution time for each command](https://github.com/jichu4n/bash-command-timer)
#
# [jichu4n/jfbview: PDF and image viewer for the Linux framebuffer](https://github.com/jichu4n/jfbview)
#
# [xmonad - the tiling window manager that rocks](https://xmonad.org/)
#
# [java - What is sun.awt.windows.WToolkit?](https://stackoverflow.com/questions/21523883/what-is-sun-awt-windows-wtoolkit)
#
# [awt for X11](https://github.com/AdoptOpenJDK/openjdk-jdk11/tree/master/src/java.desktop/unix/classes/sun/awt/X11)
#
# [Language binding](https://en.wikipedia.org/wiki/Language_binding)
#
# [glossary - What is a language binding?](https://stackoverflow.com/questions/25865/what-is-a-language-binding)
#
# [libdill](http://libdill.org/index.html)
#
# [Markup language](https://en.wikipedia.org/wiki/Markup_language)
#
# **Architecture of Open Source Applications**
#
# - [The Glasgow Haskell Compiler](http://aosabook.org/en/ghc.html)
#
# - [Firefox Release Engineering](http://aosabook.org/en/ffreleng.html)
#
# - [Scalable Web Architecture and Distributed Systems](http://aosabook.org/en/distsys.html)
#
# - [matplotlib](http://aosabook.org/en/matplotlib.html)
#
# - [nginx](http://aosabook.org/en/nginx.html)
#
# - [PyPy](http://aosabook.org/en/pypy.html)
#
# - [Yesod](http://aosabook.org/en/yesod.html)
#
# - [ZeroMQ](http://aosabook.org/en/zeromq.html)
#
# - [Twisted](http://aosabook.org/en/twisted.html)
#
# - [SQLAlchemy](http://aosabook.org/en/sqlalchemy.html)
#
# - [OSCAR](http://aosabook.org/en/oscar.html)
#
# - [OSCAR](http://aosabook.org/en/oscar.html)
#
# - [The Bourne-Again Shell](http://aosabook.org/en/bash.html)
#
# - [Berkeley DB](http://aosabook.org/en/bdb.html)
#
# - [Graphite](http://aosabook.org/en/graphite.html)
#
# - [The Hadoop Distributed File System](http://aosabook.org/en/hdfs.html)
#
# - [Continuous Integration](http://aosabook.org/en/integration.html)
#
# - [Jitsi](http://aosabook.org/en/jitsi.html)
#
# - [LLVM](http://aosabook.org/en/llvm.html)
#
# - [Python Packaging](http://aosabook.org/en/packaging.html)
#
# - [Selenium WebDriver](http://aosabook.org/en/selenium.html)
#
# - [SocialCalc](http://aosabook.org/en/socialcalc.html)
#
# - [VisTrails](http://aosabook.org/en/vistrails.html)
#
# - [Battle for Wesnoth](http://aosabook.org/en/wesnoth.html)

# %% [markdown]
# [How Learning Works: Components, Systems, and Loops](https://romandesign.co/how-learning-works-components-systems-and-loops/)
#
# [C++ Coroutines Do Not Spark Joy](https://probablydance.com/2021/10/31/c-coroutines-do-not-spark-joy/)
#
# [They don't even know the fundamentals](https://blog.royalsloth.eu/posts/they-dont-even-know-the-fundamentals/)
#
# [Cached connection manager in jboss/wildfly](https://stackoverflow.com/questions/28365722/cached-connection-manager-in-jboss-wildfly)
#
# [Software Engineer Backend at PedidosYa](https://stackoverflow.com/jobs/474123/software-engineer-backend-pedidosya)
#
# [scripting - How to find the gateway IP address in Linux](https://serverfault.com/questions/31170/how-to-find-the-gateway-ip-address-in-linux)
#
# [The Personal Analytics of My Life (2012)](https://news.ycombinator.com/item?id=29063410)
#
# [List of FTP commands](https://en.wikipedia.org/wiki/List_of_FTP_commands)
#
# [Hooking](https://en.wikipedia.org/wiki/Hooking)
#
# [What is meant by the term "hook" in programming?](https://stackoverflow.com/questions/467557/what-is-meant-by-the-term-hook-in-programming)
#
# [Building an Intuitive DSL in Java](https://dzone.com/articles/building-a-dsl-in-java)
#
# [Policitemia vera - Diagnóstico y tratamiento](https://www.mayoclinic.org/es-es/diseases-conditions/polycythemia-vera/diagnosis-treatment/drc-20355855)
#
# [The Reading Obsession - by Neckar - Neckar’s Insecurity Analysis](https://neckar.substack.com/p/the-reading-obsession)
#
# [The exit status of a command](https://bash.cyberciti.biz/guide/The_exit_status_of_a_command)
#
# [Core scheduling lands in 5.14](https://lwn.net/Articles/861251/)
#
# [CacheLib | Puggable caching engine to build and scale high performace web services](https://cachelib.org/)
#
# [Tree List Recursion Problem](http://cslibrary.stanford.edu/109/TreeListRecursion.html)
#
# [Complexity is killing software developers](https://www.infoworld.com/article/3639050/complexity-is-killing-software-developers.html)
#
# [The Linux Kernel](https://tldp.org/LDP/tlk/tlk-toc.html)
#
# [‘Trojan Source’ Bug Threatens the Security of All Code](https://krebsonsecurity.com/2021/11/trojan-source-bug-threatens-the-security-of-all-code/)
#
# [What does Statement.setFetchSize(nSize) method really do in SQL Server JDBC driver?](https://stackoverflow.com/questions/1318354/what-does-statement-setfetchsizensize-method-really-do-in-sql-server-jdbc-driv)
#
# [Computation graphs and graph computation](https://breandan.net/2020/06/30/graph-computation/)
#
# [java - Is it possible to view bytecode of Class file?](https://stackoverflow.com/questions/3315938/is-it-possible-to-view-bytecode-of-class-file)
#
# [javap - The Java Class File Disassembler](https://docs.oracle.com/javase/7/docs/technotes/tools/windows/javap.html)
#
# [Anonymous Classes (The Java™ Tutorials](https://docs.oracle.com/javase/tutorial/java/javaOO/anonymousclasses.html)
#
# [how to close all panes but the current pane in tmux](https://unix.stackexchange.com/questions/15449/how-to-close-all-panes-but-the-current-pane-in-tmux)
#
# [Java Thread Models](https://www.cs.wcupa.edu/rkline/os/java-thread-models.html)
#
# [editor - How do I move to end of line in Vim?](https://stackoverflow.com/questions/105721/how-do-i-move-to-end-of-line-in-vim)
#
# [How to decompile a jar into .java files from command prompt](https://stackoverflow.com/questions/35564270/how-to-decompile-a-jar-into-java-files-from-command-prompt/49906852)

# %% [markdown]
# ## Notas

# %% [markdown]
# - How to buy amazon books
#
# **wazuh**
#  - recopilar, (agent wazuh)
#  - analizar, (servidor wazuh)
#  - indexar (servidor wazuh)
#
# supervision de integridad de archivos
#   - quien borro archivos,
#   - quien modifo archivos
#
# alertas
#
# respuesta a incidentes
#
#   - blockear ip
#
# Normativas
# - pic css (Nommativa para pagos)
#
# ¿Cómo detecta wasuh que una IP tiene mala reputación?
#
#
# **Microservicios**
#
# - Problems seem easier to solve when you have enough context
# - Event Storming
# - CQRS
#   - Queries  (Agentes)
# - DDD (Model with boundaries)
#   - Proyections (Projectios maintain the structure of information .. ) Vistas
#   - Aggregates (A set of objects, relantionship and invariant that are considered as one unit with regard to data changes)
#     - `ChatRoom + User`-
#   - Command model: process command
#   - Event Store
#   - Events: represent that something has happend
#     - represents command
# - Modelo / Representación de una Pipa
# - Location transparency: modelos, coupling, cohesion
# - keep independent models,
# - modulos <--> agregados
# - Eventos para coordinar modelos
# - CQRS + DDDD
# - Sincronixar los moduelo (event sourcing)
#   - enviar comamndos,
#   - enviar los queries
#     - event store  +  message bus
#
#
# Agregado
#  - Entidades
#  - Comandos
#   -  Crear un evento representando el comando y enviarlo en el message bus.
#   -

# %% [markdown]
# NoClassDefFoundError
#
# When an static block is executed in java
#
# **PDS**
#
# - Seguridad del Usuario
#
# Lazy initizalization
#
# AtomicBoolean getAndSet -as a method for synchonizatino when doing one action
#
# - getAndSet is a wrapper that defaults to VarHandle getAndSet, but it seams that that has a native implementation, check the native labraries by which the jvm is link against.
#
# How to Use the Language to Create new primitives
#
# Lazy Evaluation
#
# Deman Driven vs Data Driven
#
# Delayed Computation
# - Can be useful to avoid synchonization problems
#
# Closures
#
# Distributed Processing Abstractions
#
# Dataflow
#
# Event Drive Systems
#
# The cherno project code reviews
#
# Mmap memory
#
# Windowing System Implementation in Linux
#
# Linux Directories Combentions
#
# On Threading
#
# - Thread Group
# - Thraed Group Security Model
# - Thread Priority
# - Threads Scheduling
# - Synchonized
# - Atomically
#
# Concurency Models
#
# - Performace Benchmarks
# - Events
# - Pthreads
#
#
# **PDS**
#
# - [Cadena de Firmas](https://www.argentina.gob.ar/sites/default/files/dgsiaf-2014_guia_para_usuarios_esidif_cadena_firmas.pdf)

# %% [markdown]
# **Corrector de vim**
#
# [Vim documentation: spell](https://www.cs.auckland.ac.nz/references/gnu/vim/spell.html)
#
# [Vim Spell-Checking](https://thoughtbot.com/blog/vim-spell-checking)
#
# [Vim documentation: spell](http://vimdoc.sourceforge.net/htmldoc/spell.html)
#
# [Using Spell Checking in Vim - Linux.com -  ](https://www.linux.com/training-tutorials/using-spell-checking-vim/)
#
# - :setlocal spell spelllang=en_us
# - :set spell
# -
# - `[ s` -> next word that need spell correction.
# - `] s` -> pervious word that need spell correction.
# - `z=` -> show me the suggestions
#
# -  :set nospell

# %% [markdown]
# - XDG (Cross (X) Desktop Group)

# %% [markdown]
#   ls /etc/init.d

# %% [markdown]
# ```xrandr --output eDP-1  --rate 60.00 --output HDMI-1 --rate 60.00 --right-of eDP-1 --output HDMI-1 --rate 60.00```

# %% [markdown]
# [RESTEasy - JBoss Community](https://resteasy.github.io/)
#
# [REST Assured](https://rest-assured.io/)
#
# Schema
#
# Apache Avro
#
# Probuffers
#
# Nombramientos de los endpoints:
#
# endpoint en plural con varios metodos:
# - /contratos en lugar de /contrato
# - GET /beneficiarios/123
# - POST /beneficiarios
# ...
#
# - **URI**: Universal Uniform Identifier

# %% [markdown]
# - Skills (75 WPM)
# - ispell integrated with vim

# %% [markdown]
# Finding suggestions for bad words spell vim:
#  - `z=`

# %% [markdown]
# **Que hacer para cuando no tengamos la contraseña de un usuario?**
#
# - Con el usuario de 00101231983 - Vicente Gonzalez Andujar   (Manejo de los Permisos), buscar el usuario, editar y ejecutar.
#
#   - Para buscar la clave,
#
#   - ```sql
#   SELECT *
#   FROM RP_PARAMETRO rp
#   ORDER BY COD_REPORTE  DESC
#   ```,
#
#   - Entrar con el usuario que no tenemos la contrase na con esa clave, y luego modificar la clave y ponerle helpdesk.

# %% [markdown]
# **Modern Software Engineering**
# - RAD Tools
#
# - WorkFlow Tools
#
# - [No-Code Platforms]((https://en.wikipedia.org/wiki/No-code_development_platform)
#
# - [metabase/metabase: The simplest, fastest way to get business intelligence and analytics to everyone in your company](https://github.com/metabase/metabase)
#
# - [baserow](https://gitlab.com/bramw/baserow)
#
# - [Top 18 Open-source Free Low- and No-Code platforms for enterprise](https://medevel.com/os-18-lowcode/#18-metabase)

# %% [markdown]
# Debug Instrumentation: Java Assists
#
# - Class Loading System
# - Class Loading Hierarchy
# - System Class Loader
# - Custom Class Loaders

# %% [markdown]
# - REF_CL : Clasificador no periodico
# - CL     : Clasificador periodico

# %% [markdown]
# - Contenedor  = Servidor Web + Contenedor Enterprise
#
# - Servidor Web de Wildfly es Undertow
#
# - Sprint tinee Apache Tomcat como un framework interno
#
# - Maven
#
# - Perfiles

# %% [markdown]
# Language to describe a workflow -> Workflow representation
#
# Does Garbage Collectors tracks references?

# %% [markdown]
# Expressions en Eclipse
# - Tenía `System.exit(...)`, en expressions y se me suspendia la maquina.

# %% [markdown]
# What Java classes/packages are automatically imported?
#
# - Everything in java.lang is imported by default - here you are using java.lang.System and java.lang.String
#
# - There is an implicit import of `java.lang.*.`
#
#   - From the Java **specification**:
#
#   - `A compilation unit automatically has access to all types declared in its package and also automatically imports all of the public types declared in the predefined package java.lang.`

# %% [markdown]
# dpkg -L net-tools | less
#
# net tools
#
# route  -n
#
# **Print Screens**:
#
# One Monitor:
# - Copy to cleapboard: CTRL + ALT + PrtScn
# - Save to Pictures: ALT + PrtScn
#
# Dual Monitor:
# - Copy to cleapboard: CTRL + PrtScn
# - Save to Pictures: PrtScn
#
# sudo dmidecode -t processor
#
# - Thread Worker Pattern
# - Verificar implementacion del executor service
#
# - Select a column: awk -F'\t' '{ print $7 }'
#
# - `System.exit(1);`
